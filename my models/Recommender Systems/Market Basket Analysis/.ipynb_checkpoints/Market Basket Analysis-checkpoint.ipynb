# %%
import pandas as pd
import numpy as np

from pandas.plotting import parallel_coordinates

import matplotlib.pyplot as plt
import seaborn as sns

from itertools import permutations

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Cross-selling products
#
# The small grocery store has decided to cross-sell chewing gum with either coffee, cereal, or bread. To determine which of the three items is best to use, the store owner has performed an experiment. For one week, she sold chewing gum next to the register and recorded all transactions where it was purchased with either coffee, cereal, or bread. The transactions from that day are available as a list of lists named transactions. Each transaction is either ['coffee','gum'], ['cereal','gum'], or ['bread','gum'].

# %%
transactions = [['bread', 'gum'],
 ['bread', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['cereal', 'gum'],
 ['bread', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['bread', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['cereal', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['bread', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['cereal', 'gum'],
 ['cereal', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['bread', 'gum'],
 ['coffee', 'gum'],
 ['coffee', 'gum']]

# %%
# Count the number of transactions with coffee and gum
coffee = transactions.count(['coffee', 'gum'])
coffee
# Out:
# 40

# %%
# Count the number of transactions with cereal and gum
cereal = transactions.count(['cereal', 'gum'])
cereal
# Out:
# 25

# %%
# Count the number of transactions with bread and gum
bread = transactions.count(['bread', 'gum'])
bread
# Out:
# 20

# %% [markdown]
# Preparing data for market basket analysis
#
# Throughout this course, you will typically encounter data in one of two formats: a pandas DataFrame or a list of lists. DataFrame objects will be constructed by importing a csv file using pandas. They will consist of a single column of data, where each element contains a string of items in a transaction, separated by a comma, as in the table below.
#
# In this exercise, you will practice loading the data from a csv file and will prepare it for use as a list of lists.

# %%
groceries_path = 'https://assets.datacamp.com/production/repositories/5654/datasets/5992818fd324b0de7d48311ee43fa038f7614ee5/small_grocery_store.csv'

# %%
# Load transactions from pandas
groceries = pd.read_csv(groceries_path)
groceries
# Out:
#                      Transaction
# 0             milk,bread,biscuit
# 1      bread,milk,biscuit,cereal
# 2                      bread,tea
# 3                 jam,bread,milk
# 4                    tea,biscuit
# 5                      bread,tea
# 6                     tea,cereal
# 7              bread,tea,biscuit
# 8                  jam,bread,tea
# 9                     bread,milk
# 10  coffee,orange,biscuit,cereal
# 11  coffee,orange,biscuit,cereal
# 12                  coffee,sugar
# 13           bread,coffee,orange
# 14           bread,sugar,biscuit
# 15           coffee,sugar,cereal
# 16           bread,sugar,biscuit
# 17            bread,coffee,sugar
# 18            bread,coffee,sugar
# 19        tea,milk,coffee,cereal

# %%
# Split transaction strings into lists
transactions = groceries['Transaction'].apply(lambda t: t.split(','))
transactions
# Out:
# 0                [milk, bread, biscuit]
# 1        [bread, milk, biscuit, cereal]
# 2                          [bread, tea]
# 3                    [jam, bread, milk]
# 4                        [tea, biscuit]
# 5                          [bread, tea]
# 6                         [tea, cereal]
# 7                 [bread, tea, biscuit]
# 8                     [jam, bread, tea]
# 9                         [bread, milk]
# 10    [coffee, orange, biscuit, cereal]
# 11    [coffee, orange, biscuit, cereal]
# 12                      [coffee, sugar]
# 13              [bread, coffee, orange]
# 14              [bread, sugar, biscuit]
# 15              [coffee, sugar, cereal]
# 16              [bread, sugar, biscuit]
# 17               [bread, coffee, sugar]
# 18               [bread, coffee, sugar]
# 19          [tea, milk, coffee, cereal]
# Name: Transaction, dtype: object

# %%
# Convert DataFrame column into list of strings
transactions = list(transactions)
transactions
# Out:
# [['milk', 'bread', 'biscuit'],
#  ['bread', 'milk', 'biscuit', 'cereal'],
#  ['bread', 'tea'],
#  ['jam', 'bread', 'milk'],
#  ['tea', 'biscuit'],
#  ['bread', 'tea'],
#  ['tea', 'cereal'],
#  ['bread', 'tea', 'biscuit'],
#  ['jam', 'bread', 'tea'],
#  ['bread', 'milk'],
#  ['coffee', 'orange', 'biscuit', 'cereal'],
#  ['coffee', 'orange', 'biscuit', 'cereal'],
#  ['coffee', 'sugar'],
#  ['bread', 'coffee', 'orange'],
#  ['bread', 'sugar', 'biscuit'],
#  ['coffee', 'sugar', 'cereal'],
#  ['bread', 'sugar', 'biscuit'],
#  ['bread', 'coffee', 'sugar'],
#  ['bread', 'coffee', 'sugar'],
#  ['tea', 'milk', 'coffee', 'cereal']]

# %% [markdown]
# Generating association rules
#
# As you saw, the function permutations from the module itertools can be used to quickly generate the set of all one-antecedent, one-consequent rules. You do not, of course, know which of these rules are useful. You simply know that each is a valid way to combine two items.
#
# Let's practice generating and counting the set of all rules for a subset of the grocery dataset: coffee, tea, milk, and sugar.

# %%
# Define the set of groceries
flattened = [i for t in transactions for i in t]
flattened
# Out:
# ['milk',
#  'bread',
#  'biscuit',
#  'bread',
#  'milk',
#  'biscuit',
#  'cereal',
#  'bread',
#  'tea',
#  'jam',
#  'bread',
#  'milk',
#  'tea',
#  'biscuit',
#  'bread',
#  'tea',
#  'tea',
#  'cereal',
#  'bread',
#  'tea',
#  'biscuit',
#  'jam',
#  'bread',
#  'tea',
#  'bread',
#  'milk',
#  'coffee',
#  'orange',
#  'biscuit',
#  'cereal',
#  'coffee',
#  'orange',
#  'biscuit',
#  'cereal',
#  'coffee',
#  'sugar',
#  'bread',
#  'coffee',
#  'orange',
#  'bread',
#  'sugar',
#  'biscuit',
#  'coffee',
#  'sugar',
#  'cereal',
#  'bread',
#  'sugar',
#  'biscuit',
#  'bread',
#  'coffee',
#  'sugar',
#  'bread',
#  'coffee',
#  'sugar',
#  'tea',
#  'milk',
#  'coffee',
#  'cereal']

# %%
groceries = list(set(flattened))

groceries
# Out:
# ['coffee',
#  'sugar',
#  'cereal',
#  'biscuit',
#  'jam',
#  'milk',
#  'orange',
#  'bread',
#  'tea']

# %%
# Generate all possible rules from groceries list
rules = list(permutations(groceries, 2))

# Print the set of rules
print(rules)

# Print the number of rules
print(len(rules))
# Out:
# [('coffee', 'sugar'), ('coffee', 'cereal'), ('coffee', 'biscuit'), ('coffee', 'jam'), ('coffee', 'milk'), ('coffee', 'orange'), ('coffee', 'bread'), ('coffee', 'tea'), ('sugar', 'coffee'), ('sugar', 'cereal'), ('sugar', 'biscuit'), ('sugar', 'jam'), ('sugar', 'milk'), ('sugar', 'orange'), ('sugar', 'bread'), ('sugar', 'tea'), ('cereal', 'coffee'), ('cereal', 'sugar'), ('cereal', 'biscuit'), ('cereal', 'jam'), ('cereal', 'milk'), ('cereal', 'orange'), ('cereal', 'bread'), ('cereal', 'tea'), ('biscuit', 'coffee'), ('biscuit', 'sugar'), ('biscuit', 'cereal'), ('biscuit', 'jam'), ('biscuit', 'milk'), ('biscuit', 'orange'), ('biscuit', 'bread'), ('biscuit', 'tea'), ('jam', 'coffee'), ('jam', 'sugar'), ('jam', 'cereal'), ('jam', 'biscuit'), ('jam', 'milk'), ('jam', 'orange'), ('jam', 'bread'), ('jam', 'tea'), ('milk', 'coffee'), ('milk', 'sugar'), ('milk', 'cereal'), ('milk', 'biscuit'), ('milk', 'jam'), ('milk', 'orange'), ('milk', 'bread'), ('milk', 'tea'), ('orange', 'coffee'), ('orange', 'sugar'), ('orange', 'cereal'), ('orange', 'biscuit'), ('orange', 'jam'), ('orange', 'milk'), ('orange', 'bread'), ('orange', 'tea'), ('bread', 'coffee'), ('bread', 'sugar'), ('bread', 'cereal'), ('bread', 'biscuit'), ('bread', 'jam'), ('bread', 'milk'), ('bread', 'orange'), ('bread', 'tea'), ('tea', 'coffee'), ('tea', 'sugar'), ('tea', 'cereal'), ('tea', 'biscuit'), ('tea', 'jam'), ('tea', 'milk'), ('tea', 'orange'), ('tea', 'bread')]
# 72

# %% [markdown]
# One-hot encoding transaction data
#
# Throughout the course, we will use a common pipeline for preprocessing data for use in market basket analysis. The first step is to import a pandas DataFrame and select the column that contains transactions. Each transaction in the column will be a string that consists of a number of items, each separated by a comma. The next step is to use a lambda function to split each transaction string into a list, thereby transforming the column into a list of lists.
#
# In this exercise, you'll start with the list of lists from the grocery dataset, which is available to you as transactions. You will then transform transactions into a one-hot encoded DataFrame, where each column consists of TRUE and FALSE values that indicate whether an item was included in a transaction.

# %%
# Instantiate transaction encoder and identify unique items in transactions
encoder = TransactionEncoder().fit(transactions)

# One-hot encode transactions
onehot = encoder.transform(transactions)

onehot # 20 transactions by 9 products
# Out:
# array([[ True,  True, False, False, False,  True, False, False, False],
#        [ True,  True,  True, False, False,  True, False, False, False],
#        [False,  True, False, False, False, False, False, False,  True],
#        [False,  True, False, False,  True,  True, False, False, False],
#        [ True, False, False, False, False, False, False, False,  True],
#        [False,  True, False, False, False, False, False, False,  True],
#        [False, False,  True, False, False, False, False, False,  True],
#        [ True,  True, False, False, False, False, False, False,  True],
#        [False,  True, False, False,  True, False, False, False,  True],
#        [False,  True, False, False, False,  True, False, False, False],
#        [ True, False,  True,  True, False, False,  True, False, False],
#        [ True, False,  True,  True, False, False,  True, False, False],
#        [False, False, False,  True, False, False, False,  True, False],
#        [False,  True, False,  True, False, False,  True, False, False],
#        [ True,  True, False, False, False, False, False,  True, False],
#        [False, False,  True,  True, False, False, False,  True, False],
#        [ True,  True, False, False, False, False, False,  True, False],
#        [False,  True, False,  True, False, False, False,  True, False],
#        [False,  True, False,  True, False, False, False,  True, False],
#        [False, False,  True,  True, False,  True, False, False,  True]])

# %%
# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_)

onehot
# Out:
#     biscuit  bread  cereal  coffee    jam   milk  orange  sugar    tea
# 0      True   True   False   False  False   True   False  False  False
# 1      True   True    True   False  False   True   False  False  False
# 2     False   True   False   False  False  False   False  False   True
# 3     False   True   False   False   True   True   False  False  False
# 4      True  False   False   False  False  False   False  False   True
# 5     False   True   False   False  False  False   False  False   True
# 6     False  False    True   False  False  False   False  False   True
# 7      True   True   False   False  False  False   False  False   True
# 8     False   True   False   False   True  False   False  False   True
# 9     False   True   False   False  False   True   False  False  False
# 10     True  False    True    True  False  False    True  False  False
# 11     True  False    True    True  False  False    True  False  False
# 12    False  False   False    True  False  False   False   True  False
# 13    False   True   False    True  False  False    True  False  False
# 14     True   True   False   False  False  False   False   True  False
# 15    False  False    True    True  False  False   False   True  False
# 16     True   True   False   False  False  False   False   True  False
# 17    False   True   False    True  False  False   False   True  False
# 18    False   True   False    True  False  False   False   True  False
# 19    False  False    True    True  False   True   False  False   True

# %% [markdown]
# Computing the support metric
#
# In the previous exercise, you one-hot encoded a small grocery store's transactions as the DataFrame onehot. In this exercise, you'll make use of that DataFrame and the support metric to help the store's owner. First, she has asked you to identify frequently purchased items, which you'll do by computing support at the item-level. And second, she asked you to check whether the rule {jam} --> {bread} has a support of over 0.05

# %%
# Compute the support
support = onehot.mean()
support
# Out:
# biscuit    0.40
# bread      0.65
# cereal     0.30
# coffee     0.40
# jam        0.10
# milk       0.25
# orange     0.15
# sugar      0.30
# tea        0.35
# dtype: float64

# %%
# Add a jam+bread column to the DataFrame onehot
onehot['jam+bread'] = np.logical_and(onehot['jam'], onehot['bread'])
onehot
# Out:
#     biscuit  bread  cereal  coffee    jam   milk  orange  sugar    tea  \
# 0      True   True   False   False  False   True   False  False  False
# 1      True   True    True   False  False   True   False  False  False
# 2     False   True   False   False  False  False   False  False   True
# 3     False   True   False   False   True   True   False  False  False
# 4      True  False   False   False  False  False   False  False   True
# 5     False   True   False   False  False  False   False  False   True
# 6     False  False    True   False  False  False   False  False   True
# 7      True   True   False   False  False  False   False  False   True
# 8     False   True   False   False   True  False   False  False   True
# 9     False   True   False   False  False   True   False  False  False
# 10     True  False    True    True  False  False    True  False  False
# 11     True  False    True    True  False  False    True  False  False
# 12    False  False   False    True  False  False   False   True  False
# 13    False   True   False    True  False  False    True  False  False
# 14     True   True   False   False  False  False   False   True  False
# 15    False  False    True    True  False  False   False   True  False
# 16     True   True   False   False  False  False   False   True  False
# 17    False   True   False    True  False  False   False   True  False
# 18    False   True   False    True  False  False   False   True  False
# 19    False  False    True    True  False   True   False  False   True
#
#     jam+bread
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False

# %%
# Compute the support
support = onehot.mean()
support
# Out:
# biscuit      0.40
# bread        0.65
# cereal       0.30
# coffee       0.40
# jam          0.10
# milk         0.25
# orange       0.15
# sugar        0.30
# tea          0.35
# jam+bread    0.10
# dtype: float64

# %% [markdown]
# Recommending books with support
#
# A library wants to get members to read more and has decided to use market basket analysis to figure out how. They approach you to do the analysis and ask that you use the five most highly-rated books from the goodbooks-10k dataset, which was introduced in the video. You are given the data in one-hot encoded format in a pandas DataFrame called books.
#
# Each column in the DataFrame corresponds to a book and has the value TRUE if the book is contained in a reader's library and is rated highly. To make things simpler, we'll work with shortened book names: Hunger, Potter, and Twilight.

# %%
books = pd.read_csv('books.csv', index_col = 0)
books.reset_index(drop=True, inplace=True)
books
# Out:
#          Hunger  Potter  Twilight
# 0         FALSE    True     False
# 1         FALSE    True      True
# 2         FALSE   False     False
# 3         FALSE    True     False
# 4         FALSE   False     False
# ...         ...     ...       ...
# 8045  5   False   False     False
# 8046  6   False   False     False
# 8047  7   False   False      True
# 8048  8    True   False      True
# 8049  9   False   False     False
#
# [8050 rows x 3 columns]

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Hunger    8050 non-null   object
#  1   Potter    8050 non-null   bool
#  2   Twilight  8050 non-null   bool
# dtypes: bool(2), object(1)
# memory usage: 78.7+ KB

# %%
# remove wrong character to the 'Hunger' column and transform it to boolean
books['Hunger'] = books['Hunger'].apply(lambda x: True if 'true' in str(x).lower() else (False if 'false' in str(x).lower() else x))
books
# Out:
#       Hunger  Potter  Twilight
# 0      False    True     False
# 1      False    True      True
# 2      False   False     False
# 3      False    True     False
# 4      False   False     False
# ...      ...     ...       ...
# 8045   False   False     False
# 8046   False   False     False
# 8047   False   False      True
# 8048    True   False      True
# 8049   False   False     False
#
# [8050 rows x 3 columns]

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Hunger    8050 non-null   bool
#  1   Potter    8050 non-null   bool
#  2   Twilight  8050 non-null   bool
# dtypes: bool(3)
# memory usage: 23.7 KB

# %%
# Recall that support is the share of TRUE entries in the column of books.

# Compute support for Hunger and Potter
supportHP = np.logical_and(books['Hunger'], books['Potter']).mean()

# Compute support for Hunger and Twilight
supportHT = np.logical_and(books['Hunger'], books['Twilight']).mean()

# Compute support for Potter and Twilight
supportPT = np.logical_and(books['Potter'], books['Twilight']).mean()

# Print support values
print("Hunger Games and Harry Potter: %.2f" % supportHP)
print("Hunger Games and Twilight: %.2f" % supportHT)
print("Harry Potter and Twilight: %.2f" % supportPT)
# Out:
# Hunger Games and Harry Potter: 0.12
# Hunger Games and Twilight: 0.09
# Harry Potter and Twilight: 0.14

# %% [markdown]
# Refining support with confidence
#
# After reporting your findings from the previous exercise, the library asks you about the direction of the relationship. Should they use Harry Potter to promote Twilight or Twilight to promote Harry Potter?
#
# After thinking about this, you decide to compute the confidence metric, which has a direction, unlike support. You'll compute it for both {Potter} --> {Twilight} and {Twilight} --> {Potter}.

# %%
# Recall that the confidence of "if X then Y" is: support(X & Y) / support(X)

# Compute support for Potter and Twilight
supportPT = np.logical_and(books['Potter'], books['Twilight']).mean()

# Compute support for Potter
supportP = books['Potter'].mean()

# Compute support for Twilight
supportT = books['Twilight'].mean()

print('supportP', supportP, 'supportT', supportT)
# Out:
# supportP 0.47751552795031055 supportT 0.2567701863354037

# %%
# Compute confidence for both rules
confidencePT = supportPT / supportP
confidenceTP = supportPT / supportT

# Print results
print('{0:.2f}, {1:.2f}'.format(confidencePT, confidenceTP))

# Even though the support is identical for the two association rules, the confidence is much higher for Twilight -> Harry Potter, since Harry Potter has a higher support than Twilight.
# Out:
# 0.29, 0.55

# %% [markdown]
# Further refinement with lift
#
# Once again, you report your results to the library: Use Twilight to promote Harry Potter, since the rule has a higher confidence metric. The library thanks you for the suggestion, but asks you to confirm that this is a meaningful relationship using another metric.
#
# You recall that lift may be useful here. If lift is less than 1, this means that Harry Potter and Twilight are paired together less frequently than we would expect if the pairings occurred by random chance.

# %%
# Remember that lift is computed for items X and Y as: support(X & Y) / [support(X) * support(Y)]

# Compute lift
lift = supportPT / (supportP * supportT)

lift

# As it turns out, lift is greater than 1.0. This could give us some confidence that the association rule we recommended did not arise by random chance.
# Out:
# 1.146881247209129

# %% [markdown]
# Computing conviction
#
# After hearing about the useful advice you provided to the library, the founder of a small ebook selling start-up approaches you for consulting services. As a test of your abilities, she asks you if you are able to compute conviction for the rule {Potter} --> {Hunger}, so she can decide whether to place the books next to each other on the company's website.

# %%
# The conviction of "if X then Y" is computed as follows: support(X) * support(NOT Y) / support(X and NOT Y).

# Compute support for Potter AND Hunger
supportPH = np.logical_and(books['Potter'], books['Hunger']).mean()

# Compute support for NOT Hunger
supportnH = 1.0 - books['Hunger'].mean()

# Compute support for Potter and NOT Hunger
supportPnH = supportP - supportPH

# Compute and print conviction for Potter -> Hunger
conviction = supportP * supportnH / supportPnH
print("Conviction: %.2f" % conviction)

# Notice that the value of conviction is than 1, suggesting that the rule ``if Potter then Hunger'' is not supported.
# Out:
# Conviction: 0.92

# %% [markdown]
# Computing conviction with a function
#
# After successful completion of her trial project, the ebook start-up's founder decides to hire you for a much bigger project. She asks you if you are able to compute conviction for every pair of books in the goodreads-10k dataset, so she can use that information to decide which books to locate closer together on the website.
#
# You agree to take the job, but realize that you need more a efficient way to compute conviction, since you will need to compute it many times. You decide to write a function that computes it. It will take two columns of a pandas DataFrame as an input, one antecedent and one consequent, and output the conviction metric.

# %%
def conviction(antecedent, consequent):
    
    # Compute support for antecedent AND consequent
    supportAC = np.logical_and(antecedent, consequent).mean()

    # Compute support for antecedent
    supportA = antecedent.mean()

    # Compute support for NOT consequent
    supportnC = 1.0 - consequent.mean()

    # Compute support for antecedent and NOT consequent
    supportAnC = supportA - supportAC

    # Return conviction
    return supportA * supportnC / supportAnC

# %% [markdown]
# Promoting ebooks with conviction
#
# In the previous exercise, we defined a function to compute conviction. We were asked to apply that function to all two-book permutations of the goodreads-10k dataset. In this exercise, we'll test the function by applying it to the three most popular books, which we used in earlier exercises: The Hunger Games, Harry Potter, and Twilight.

# %%
potter = books['Potter']
twilight = books['Twilight']
hunger = books['Hunger']

# %%
# Compute conviction for twilight -> potter and potter -> twilight
convictionTP = conviction(twilight, potter)
convictionPT = conviction(potter, twilight)

# Compute conviction for twilight -> hunger and hunger -> twilight
convictionTH = conviction(twilight, hunger)
convictionHT = conviction(hunger, twilight)

# Compute conviction for potter -> hunger and hunger -> potter
convictionPH = conviction(potter, hunger)
convictionHP = conviction(hunger,potter)

# Print results
print('Harry Potter -> Twilight: ', convictionHT)
print('Twilight -> Potter: ', convictionTP)
# Out:
# Harry Potter -> Twilight:  1.0315274939515657
# Twilight -> Potter:  1.1550539077290998

# %% [markdown]
# Computing association and dissociation
#
# The library has returned to you once again about your recommendation to promote Harry Potter using Twilight. They're worried that the two might be dissociated, which could have a negative impact on their promotional effort. They ask you to verify that this is not the case.
#
# You immediately think of Zhang's metric, which measures association and dissociation continuously. Association is positive and dissociation is negative.

# %%
# Compute the support of Twilight and Harry Potter
supportT = books['Twilight'].mean()
supportP = books['Potter'].mean()

# Compute the support of both books
supportTP = np.logical_and(books['Twilight'],books['Potter']).mean()

# Complete the expressions for the numerator and denominator
numerator = supportTP - supportT*supportP
denominator = max(supportTP*(1-supportT), supportT*(supportP-supportTP))

# Compute and print Zhang's metric
zhang = numerator / denominator
zhang

# the association rule ``if Twilight then Harry Potter'' proved robust. It had a positive value for Zhang's metric, indicating that the two books are not dissociated.
# Out:
# 0.17231567178855997

# %% [markdown]
# Defining Zhang's metric
#
# In general, when we want to perform a task many times, we'll write a function, rather than coding up each individual instance. In this exercise, we'll define a function for Zhang's metric that takes an antecedent and consequent and outputs the metric itself. When the problems we solve become increasingly complicated in the following chapter, having a convenient means of computing a metric will greatly simplify things.

# %%
# Define a function to compute Zhang's metric
def zhang(antecedent, consequent):
    # Compute the support of each book
    supportA = antecedent.mean()
    supportC = consequent.mean()

    # Compute the support of both books
    supportAC = np.logical_and(antecedent, consequent).mean()

    # Complete the expressions for the numerator and denominator
    numerator = supportAC - supportA*supportC
    denominator = max(supportAC*(1-supportA), supportA*(supportC-supportAC))

    # Return Zhang's metric
    return numerator / denominator

# %% [markdown]
# Applying Zhang's metric
#
# The founder of the ebook start-up has returned for additional consulting services. She has sent you a list of itemsets she's investigating and has asked you to determine whether any of them contain items that are dissociated. When you're finished, she has asked that you add the metric you use to a column in the rules DataFrame, which is available to you, and currently contains columns for antecedents and consequents.

# %%
books_5 = pd.read_csv('books_5.csv', index_col = 0)
books_5.reset_index(drop=True, inplace=True)

# remove wrong character to the 'Hunger' column and transform it to boolean
books_5['Hunger'] = books_5['Hunger'].apply(lambda x: True if 'true' in str(x).lower() else (False if 'false' in str(x).lower() else x))
books_5
# Out:
#       Hunger  Potter  Twilight  Mockingbird  Gatsby
# 0      False    True     False         True    True
# 1      False    True      True        False    True
# 2      False   False     False         True   False
# 3      False    True     False        False    True
# 4      False   False     False        False    True
# ...      ...     ...       ...          ...     ...
# 8045   False   False     False         True    True
# 8046   False   False     False         True   False
# 8047   False   False      True        False   False
# 8048    True   False      True        False   False
# 8049   False   False     False         True   False
#
# [8050 rows x 5 columns]

# %%
itemsets = [['Potter', 'Hunger'],
 ['Twilight', 'Hunger'],
 ['Mockingbird', 'Hunger'],
 ['Gatsby', 'Hunger'],
 ['Potter', 'Twilight'],
 ['Potter', 'Mockingbird'],
 ['Potter', 'Gatsby'],
 ['Mockingbird', 'Twilight'],
 ['Gatsby', 'Twilight'],
 ['Mockingbird', 'Gatsby']]

# %%
rules = pd.DataFrame(itemsets, columns=['antecedent', 'consequent'])
rules
# Out:
#     antecedent   consequent
# 0       Potter       Hunger
# 1     Twilight       Hunger
# 2  Mockingbird       Hunger
# 3       Gatsby       Hunger
# 4       Potter     Twilight
# 5       Potter  Mockingbird
# 6       Potter       Gatsby
# 7  Mockingbird     Twilight
# 8       Gatsby     Twilight
# 9  Mockingbird       Gatsby

# %%
books_5[itemsets[0][0]]
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 8045    False
# 8046    False
# 8047    False
# 8048    False
# 8049    False
# Name: Potter, Length: 8050, dtype: bool

# %%
# Define an empty list for Zhang's metric
zhangs_metric = []

# Loop over lists in itemsets
for itemset in itemsets:
    # Extract the antecedent and consequent columns
    antecedent = books_5[itemset[0]]
    consequent = books_5[itemset[1]]

    # Complete Zhang's metric and append it to the list
    zhangs_metric.append(zhang(antecedent, consequent))
    
# Print results
rules['zhang'] = zhangs_metric

rules

# Notice that most of the items are dissociated, which suggests that they would have been a poor choice to pair together for promotional purposes.
# Out:
#     antecedent   consequent     zhang
# 0       Potter       Hunger -0.306049
# 1     Twilight       Hunger  0.109357
# 2  Mockingbird       Hunger -0.525436
# 3       Gatsby       Hunger -0.550446
# 4       Potter     Twilight  0.245118
# 5       Potter  Mockingbird -0.065537
# 6       Potter       Gatsby -0.165572
# 7  Mockingbird     Twilight -0.319008
# 8       Gatsby     Twilight -0.370875
# 9  Mockingbird       Gatsby  0.466460

# %% [markdown]
# Filtering with support and conviction
#
# In the video, we discussed the continued consulting work you are doing for the founder of an ebook selling start-up. The founder has approached you with the DataFrame rules, which contains the work of a data scientist who was previously on staff. It includes columns for antecedents and consequents, along with the performance for each of those rules with respect to a number of metrics.
#
# Your objective will be to perform multi-metric filtering on the dataset to identify potentially useful rules

# %%
rules_full = pd.read_csv('rules_full.csv', index_col = 0)
rules_full
# Out:
#                antecedents                      consequents  \
# 0                 (Potter)                         (Hunger)
# 1                 (Hunger)                         (Potter)
# 2               (Twilight)                         (Hunger)
# 3                 (Hunger)                       (Twilight)
# 4            (Mockingbird)                         (Hunger)
# ..                     ...                              ...
# 145  (Gatsby, Mockingbird)               (Potter, Twilight)
# 146               (Potter)  (Twilight, Gatsby, Mockingbird)
# 147             (Twilight)    (Potter, Gatsby, Mockingbird)
# 148               (Gatsby)  (Potter, Twilight, Mockingbird)
# 149          (Mockingbird)       (Potter, Twilight, Gatsby)
#
#      antecedent support  consequent support  support  confidence   lift  \
# 0                 0.478               0.319    0.124       0.259  0.813
# 1                 0.319               0.478    0.124       0.388  0.813
# 2                 0.257               0.319    0.089       0.347  1.088
# 3                 0.319               0.257    0.089       0.279  1.088
# 4                 0.477               0.319    0.096       0.202  0.633
# ..                  ...                 ...      ...         ...    ...
# 145               0.186               0.141    0.024       0.131  0.930
# 146               0.478               0.036    0.024       0.051  1.406
# 147               0.257               0.090    0.024       0.095  1.056
# 148               0.295               0.063    0.024       0.082  1.310
# 149               0.477               0.034    0.024       0.051  1.496
#
#      leverage  conviction
# 0    -0.02850       0.919
# 1    -0.02850       0.854
# 2     0.00725       1.043
# 3     0.00725       1.032
# 4    -0.05580       0.853
# ..        ...         ...
# 145  -0.00182       0.989
# 146   0.00703       1.016
# 147   0.00129       1.006
# 148   0.00576       1.021
# 149   0.00807       1.018
#
# [150 rows x 9 columns]

# %%
# Select the subset of rules with antecedent support greater than 0.05
rules_filt = rules_full[rules_full['antecedent support'] > 0.05]

# Select the subset of rules with a consequent support greater than 0.02
rules_filt = rules_filt[rules_filt['consequent support'] > 0.02]

# Select the subset of rules with a conviction greater than 1.01
rules_filt = rules_filt[rules_filt['conviction'] > 1.01]

rules_filt
# Out:
#                  antecedents                      consequents  \
# 2                 (Twilight)                         (Hunger)
# 3                   (Hunger)                       (Twilight)
# 8                   (Potter)                       (Twilight)
# 9                 (Twilight)                         (Potter)
# 18                  (Gatsby)                    (Mockingbird)
# ..                       ...                              ...
# 143       (Twilight, Gatsby)            (Potter, Mockingbird)
# 144  (Twilight, Mockingbird)                 (Potter, Gatsby)
# 146                 (Potter)  (Twilight, Gatsby, Mockingbird)
# 148                 (Gatsby)  (Potter, Twilight, Mockingbird)
# 149            (Mockingbird)       (Potter, Twilight, Gatsby)
#
#      antecedent support  consequent support  support  confidence   lift  \
# 2                 0.257               0.319    0.089       0.347  1.088
# 3                 0.319               0.257    0.089       0.279  1.088
# 8                 0.478               0.257    0.141       0.294  1.147
# 9                 0.257               0.478    0.141       0.548  1.147
# 18                0.295               0.477    0.186       0.630  1.323
# ..                  ...                 ...      ...         ...    ...
# 143               0.054               0.220    0.024       0.455  2.072
# 144               0.098               0.128    0.024       0.248  1.940
# 146               0.478               0.036    0.024       0.051  1.406
# 148               0.295               0.063    0.024       0.082  1.310
# 149               0.477               0.034    0.024       0.051  1.496
#
#      leverage  conviction
# 2     0.00725       1.043
# 3     0.00725       1.032
# 8     0.01800       1.053
# 9     0.01800       1.155
# 18    0.04540       1.417
# ..        ...         ...
# 143   0.01260       1.431
# 144   0.01180       1.160
# 146   0.00703       1.016
# 148   0.00576       1.021
# 149   0.00807       1.018
#
# [82 rows x 9 columns]

# %%
# The Zhang's metric can be easily added, unsing the antecendent, consequent and antecedent*consequent (support field) already defined in the table

supportA = rules_full['antecedent support']
supportC = rules_full['consequent support']
supportAC = rules_full['support']

# Complete the expressions for the numerator and denominator
numerator = supportAC - supportA*supportC
denominator = np.maximum(supportAC*(1-supportA), supportA*(supportC-supportAC))

rules_full['Zhang'] = numerator/denominator
rules_full
# Out:
#                antecedents                      consequents  \
# 0                 (Potter)                         (Hunger)
# 1                 (Hunger)                         (Potter)
# 2               (Twilight)                         (Hunger)
# 3                 (Hunger)                       (Twilight)
# 4            (Mockingbird)                         (Hunger)
# ..                     ...                              ...
# 145  (Gatsby, Mockingbird)               (Potter, Twilight)
# 146               (Potter)  (Twilight, Gatsby, Mockingbird)
# 147             (Twilight)    (Potter, Gatsby, Mockingbird)
# 148               (Gatsby)  (Potter, Twilight, Mockingbird)
# 149          (Mockingbird)       (Potter, Twilight, Gatsby)
#
#      antecedent support  consequent support  support  confidence   lift  \
# 0                 0.478               0.319    0.124       0.259  0.813
# 1                 0.319               0.478    0.124       0.388  0.813
# 2                 0.257               0.319    0.089       0.347  1.088
# 3                 0.319               0.257    0.089       0.279  1.088
# 4                 0.477               0.319    0.096       0.202  0.633
# ..                  ...                 ...      ...         ...    ...
# 145               0.186               0.141    0.024       0.131  0.930
# 146               0.478               0.036    0.024       0.051  1.406
# 147               0.257               0.090    0.024       0.095  1.056
# 148               0.295               0.063    0.024       0.082  1.310
# 149               0.477               0.034    0.024       0.051  1.496
#
#      leverage  conviction     Zhang
# 0    -0.02850       0.919 -0.305568
# 1    -0.02850       0.854 -0.252218
# 2     0.00725       1.043  0.106114
# 3     0.00725       1.032  0.115775
# 4    -0.05580       0.853 -0.527992
# ..        ...         ...       ...
# 145  -0.00182       0.989 -0.102288
# 146   0.00703       1.016  0.542146
# 147   0.00129       1.006  0.048789
# 148   0.00576       1.021  0.320035
# 149   0.00807       1.018  0.619981
#
# [150 rows x 10 columns]

# %% [markdown]
# Using multi-metric filtering to cross-promote books
#
# As a final request, the founder of the ebook selling start-up asks you to perform additional filtering. Your previous attempt returned 82 rules, but she wanted only one

# %%
# Set the lift threshold to 1.5
rules_best = rules_full[rules_full['lift'] > 1.5]

# Set the conviction threshold to 1.0
rules_best = rules_best[rules_best['conviction'] > 1.0]

# Set the threshold for Zhang's rule to 0.65
rules_best = rules_best[rules_best['Zhang'] > 0.65]

rules_best

# Print rule
# print(rules_best[['antecedents','consequents']])
# Out:
#                  antecedents               consequents  antecedent support  \
# 113    (Potter, Mockingbird)          (Gatsby, Hunger)               0.220
# 120            (Mockingbird)  (Potter, Gatsby, Hunger)               0.477
# 127  (Twilight, Mockingbird)          (Gatsby, Hunger)               0.098
# 131    (Mockingbird, Hunger)        (Twilight, Gatsby)               0.096
#
#      consequent support  support  confidence   lift  leverage  conviction  \
# 113               0.051    0.023       0.103  2.037   0.01150       1.058
# 120               0.031    0.023       0.047  1.528   0.00781       1.017
# 127               0.051    0.013       0.129  2.550   0.00770       1.090
# 131               0.054    0.013       0.132  2.458   0.00752       1.090
#
#         Zhang
# 113  0.656633
# 120  0.682767
# 127  0.682415
# 131  0.665078

# %% [markdown]
# Performing aggregation
#
# After completing minor consulting jobs for a library and an ebook seller, you've finally received your first big market basket analysis project: advising an online novelty gifts retailer on cross-promotions. Since the retailer has never previously hired a data scientist, it would like you to start the project by exploring its transaction data. It has asked you to perform aggregation for all signs in the dataset and also compute the support for this category.

# %%
online_retail = pd.read_csv('online_retail.csv')
online_retail
# Out:
#        InvoiceNo StockCode                          Description
# 0         562583    35637A      IVORY STRING CURTAIN WITH POLE
# 1         562583    35638A        PINK AND BLACK STRING CURTAIN
# 2         562583    84927F                PSYCHEDELIC TILE HOOK
# 3         562583     22425                ENAMEL COLANDER CREAM
# 4         562583     16008  SMALL FOLDING SCISSOR(POINTED EDGE)
# ...          ...       ...                                  ...
# 227755   C581229     23158          SET OF 5 LUCKY CAT MAGNETS
# 227756   C581229     22712                     CARD DOLLY GIRL
# 227757   C581229     22027              TEA PARTY BIRTHDAY CARD
# 227758   C581229     21508              VINTAGE KID DOLLY CARD
# 227759   C581229     21507              ELEPHANT BIRTHDAY CARD
#
# [227760 rows x 3 columns]

# %%
online_retail.InvoiceNo.nunique() # unique invoices
# Out:
# 9709

# %%
online_retail.StockCode.nunique() # unique items
# Out:
# 3353

# %%
online_retail.Description.nunique() # unique descriptions
# Out:
# 3460

# %%
onehot = pd.crosstab(online_retail['InvoiceNo'], online_retail['Description'])
onehot
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 549687                                    0                               0
# 550644                                    0                               0
# 552695                                    0                               0
# 553857                                    0                               0
# 557499                                    0                               0
# ...                                     ...                             ...
# C581484                                   0                               0
# C581490                                   0                               0
# C581499                                   0                               0
# C581568                                   0                               0
# C581569                                   0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 549687                        0                             0
# 550644                        0                             0
# 552695                        0                             0
# 553857                        0                             0
# 557499                        0                             0
# ...                         ...                           ...
# C581484                       0                             0
# C581490                       0                             0
# C581499                       0                             0
# C581568                       0                             0
# C581569                       0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 549687                              0                            0
# 550644                              0                            0
# 552695                              0                            0
# 553857                              0                            0
# 557499                              0                            0
# ...                               ...                          ...
# C581484                             0                            0
# C581490                             0                            0
# C581499                             0                            0
# C581568                             0                            0
# C581569                             0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 549687                              0                                 0
# 550644                              0                                 1
# 552695                              0                                 0
# 553857                              0                                 0
# 557499                              0                                 0
# ...                               ...                               ...
# C581484                             0                                 0
# C581490                             0                                 0
# C581499                             0                                 0
# C581568                             0                                 0
# C581569                             0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TRELLIS COAT RACK  ...  wet boxes  \
# InvoiceNo                                                 ...
# 549687                             0                   0  ...          0
# 550644                             0                   0  ...          0
# 552695                             0                   0  ...          0
# 553857                             0                   0  ...          0
# 557499                             0                   0  ...          0
# ...                              ...                 ...  ...        ...
# C581484                            0                   0  ...          0
# C581490                            0                   0  ...          0
# C581499                            0                   0  ...          0
# C581568                            0                   0  ...          0
# C581569                            0                   0  ...          0
#
# Description  wet pallet  wet rusty  wet?  wrongly coded 20713  \
# InvoiceNo
# 549687                0          0     0                    0
# 550644                0          0     0                    0
# 552695                0          0     0                    0
# 553857                0          0     0                    0
# 557499                0          0     0                    0
# ...                 ...        ...   ...                  ...
# C581484               0          0     0                    0
# C581490               0          0     0                    0
# C581499               0          0     0                    0
# C581568               0          0     0                    0
# C581569               0          0     0                    0
#
# Description  wrongly coded 23343  wrongly coded-23343  wrongly marked  \
# InvoiceNo
# 549687                         0                    0               0
# 550644                         0                    0               0
# 552695                         0                    0               0
# 553857                         0                    0               0
# 557499                         0                    0               0
# ...                          ...                  ...             ...
# C581484                        0                    0               0
# C581490                        0                    0               0
# C581499                        0                    0               0
# C581568                        0                    0               0
# C581569                        0                    0               0
#
# Description  wrongly marked 23343  wrongly marked carton 22804
# InvoiceNo
# 549687                          0                            0
# 550644                          0                            0
# 552695                          0                            0
# 553857                          0                            0
# 557499                          0                            0
# ...                           ...                          ...
# C581484                         0                            0
# C581490                         0                            0
# C581499                         0                            0
# C581568                         0                            0
# C581569                         0                            0
#
# [9353 rows x 3460 columns]

# %%
# Select the column headers for sign items
sign_headers = [i for i in onehot.columns if i.lower().find('sign')>=0]

len(sign_headers)
# Out:
# 173

# %%
# Select columns of sign items using sign_headers
sign_columns = onehot[sign_headers]

print(sign_columns.mean()) # very sparse columns (LOW SUPPORT)
sign_columns
# Out:
# Description
# 16 PIECE CUTLERY SET PANTRY DESIGN    0.001925
# 60 CAKE CASES DOLLY GIRL DESIGN       0.018604
# AIRLINE LOUNGE,METAL SIGN             0.013258
# AREA PATROLLED METAL SIGN             0.020528
# ASSTD DESIGN 3D PAPER STICKERS        0.001176
#                                         ...
# WRAP VINTAGE LEAF DESIGN              0.010906
# WRAP VINTAGE PETALS  DESIGN           0.000107
# YELLOW/PINK FLOWER DESIGN BIG MUG     0.000962
# YOU'RE CONFUSING ME METAL SIGN        0.019245
# ZINC BOX SIGN HOME                    0.006522
# Length: 173, dtype: float64
# Description  16 PIECE CUTLERY SET PANTRY DESIGN  \
# InvoiceNo
# 549687                                        0
# 550644                                        0
# 552695                                        0
# 553857                                        0
# 557499                                        0
# ...                                         ...
# C581484                                       0
# C581490                                       0
# C581499                                       0
# C581568                                       0
# C581569                                       0
#
# Description  60 CAKE CASES DOLLY GIRL DESIGN  AIRLINE LOUNGE,METAL SIGN  \
# InvoiceNo
# 549687                                     0                          0
# 550644                                     0                          0
# 552695                                     0                          0
# 553857                                     0                          0
# 557499                                     0                          0
# ...                                      ...                        ...
# C581484                                    0                          0
# C581490                                    0                          0
# C581499                                    0                          0
# C581568                                    0                          0
# C581569                                    0                          0
#
# Description  AREA PATROLLED METAL SIGN  ASSTD DESIGN 3D PAPER STICKERS  \
# InvoiceNo
# 549687                               0                               0
# 550644                               0                               0
# 552695                               1                               0
# 553857                               0                               0
# 557499                               0                               0
# ...                                ...                             ...
# C581484                              0                               0
# C581490                              0                               0
# C581499                              0                               0
# C581568                              0                               0
# C581569                              0                               0
#
# Description  ASSTD DESIGN RACING CAR PEN  BAKING SET SPACEBOY DESIGN  \
# InvoiceNo
# 549687                                 0                           0
# 550644                                 0                           0
# 552695                                 0                           0
# 553857                                 0                           0
# 557499                                 0                           0
# ...                                  ...                         ...
# C581484                                0                           0
# C581490                                0                           0
# C581499                                0                           0
# C581568                                0                           0
# C581569                                0                           0
#
# Description  BATHROOM METAL SIGN  BATHROOM METAL SIGN   \
# InvoiceNo
# 549687                         0                     0
# 550644                         0                     0
# 552695                         0                     0
# 553857                         0                     0
# 557499                         0                     0
# ...                          ...                   ...
# C581484                        0                     0
# C581490                        0                     0
# C581499                        0                     0
# C581568                        0                     0
# C581569                        0                     0
#
# Description  BATHROOM SET LOVE HEART DESIGN  ...  WRAP ALPHABET DESIGN  \
# InvoiceNo                                    ...
# 549687                                    0  ...                     0
# 550644                                    0  ...                     0
# 552695                                    0  ...                     0
# 553857                                    0  ...                     0
# 557499                                    0  ...                     0
# ...                                     ...  ...                   ...
# C581484                                   0  ...                     0
# C581490                                   0  ...                     0
# C581499                                   0  ...                     0
# C581568                                   0  ...                     0
# C581569                                   0  ...                     0
#
# Description  WRAP BILLBOARD FONTS DESIGN  WRAP DOILEY DESIGN  \
# InvoiceNo
# 549687                                 0                   0
# 550644                                 0                   0
# 552695                                 1                   1
# 553857                                 0                   0
# 557499                                 0                   0
# ...                                  ...                 ...
# C581484                                0                   0
# C581490                                0                   0
# C581499                                0                   0
# C581568                                0                   0
# C581569                                0                   0
#
# Description  WRAP POPPIES  DESIGN  WRAP SUMMER ROSE DESIGN  \
# InvoiceNo
# 549687                          0                        0
# 550644                          0                        0
# 552695                          1                        0
# 553857                          0                        0
# 557499                          0                        0
# ...                           ...                      ...
# C581484                         0                        0
# C581490                         0                        0
# C581499                         0                        0
# C581568                         0                        0
# C581569                         0                        0
#
# Description  WRAP VINTAGE LEAF DESIGN  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo
# 549687                              0                            0
# 550644                              0                            0
# 552695                              0                            1
# 553857                              0                            0
# 557499                              0                            0
# ...                               ...                          ...
# C581484                             0                            0
# C581490                             0                            0
# C581499                             0                            0
# C581568                             0                            0
# C581569                             0                            0
#
# Description  YELLOW/PINK FLOWER DESIGN BIG MUG  \
# InvoiceNo
# 549687                                       0
# 550644                                       0
# 552695                                       0
# 553857                                       0
# 557499                                       0
# ...                                        ...
# C581484                                      0
# C581490                                      0
# C581499                                      0
# C581568                                      0
# C581569                                      0
#
# Description  YOU'RE CONFUSING ME METAL SIGN   ZINC BOX SIGN HOME
# InvoiceNo
# 549687                                     0                   0
# 550644                                     0                   0
# 552695                                     0                   0
# 553857                                     0                   0
# 557499                                     0                   0
# ...                                      ...                 ...
# C581484                                    0                   0
# C581490                                    0                   0
# C581499                                    0                   0
# C581568                                    0                   0
# C581569                                    0                   0
#
# [9353 rows x 173 columns]

# %%
# Perform aggregation of sign items into sign category
signs = sign_columns.sum(axis = 1) >= 1.0 # set the new columns to True if at least a sub-column contains a 1

print(signs.mean()) # aggregated column less sparse (HIGHER SUPPORT)
signs
# Out:
# 0.45856944295947827
# InvoiceNo
# 549687     False
# 550644      True
# 552695      True
# 553857     False
# 557499     False
#            ...
# C581484    False
# C581490    False
# C581499    False
# C581568    False
# C581569    False
# Length: 9353, dtype: bool

# %% [markdown]
# Defining an aggregation function
#
# Surprised by the high share of sign items in its inventory, the retailer decides that it makes sense to do further aggregation for different categories to explore the data better. This seems trivial to you, but the retailer has not previously been able to perform even a basic descriptive analysis of its transaction and items.
#
# The retailer asks you to perform aggregation for the candles, bags, and boxes categories. To simplify the task, you decide to write a function. It will take a string that contains an item's category. It will then output a DataFrame that indicates whether each transaction includes items from that category.

# %%
def aggregate(item):
    # Select the column headers for sign items in onehot
    item_headers = [i for i in onehot.columns if i.lower().find(item)>=0]

    # Select columns of sign items
    item_columns = onehot[item_headers]

    # Return category of aggregated items
    return item_columns.sum(axis = 1) >= 1.0

# %%
# Aggregate items for the bags, boxes, and candles categories  
bags = aggregate('bag')
boxes = aggregate('boxes')
candles = aggregate('candles')

bags.mean(), boxes.mean(), candles.mean()
# Out:
# (0.3858654977012723, 0.07077942906019459, 0.11953383940981503)

# %% [markdown]
# Identifying frequent itemsets with Apriori
#
# The aggregation exercise you performed for the online retailer proved helpful. It offered a starting point for understanding which categories of items appear frequently in transactions. The retailer now wants to explore the individual items themselves to find out which are frequent.
#
# In this exercise, you'll apply the Apriori algorithm to the online retail dataset without aggregating first. Your objective will be to prune the itemsets using a minimum value of support and a maximum item number threshold.

# %%
# Convert the DataFrame to boolean values (True/False) and sample only some rown and columns (to let the apriori algorithm run faster)
onehot_bool = onehot.astype(bool)
# onehot_samp = onehot_bool.sample(n=1000)
# onehot_samp = onehot_samp.sample(n=500, axis=1)

# %%
# Compute frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(onehot_bool, 
                            min_support = 0.05, 
                            max_len = 3, 
                            use_colnames = True)

frequent_itemsets
# Out:
#      support                              itemsets
# 0   0.050144          (ALARM CLOCK BAKELIKE GREEN)
# 1   0.062974       (ASSORTED COLOUR BIRD ORNAMENT)
# 2   0.056987          (CHOCOLATE HOT WATER BOTTLE)
# 3   0.051748  (GARDENERS KNEELING PAD CUP OF TEA )
# 4   0.062547   (GARDENERS KNEELING PAD KEEP CALM )
# 5   0.056987              (HAND WARMER OWL DESIGN)
# 6   0.081578          (HOT WATER BOTTLE KEEP CALM)
# 7   0.056559   (HOT WATER BOTTLE TEA AND SYMPATHY)
# 8   0.066717           (JUMBO BAG 50'S CHRISTMAS )
# 9   0.050786                  (JUMBO BAG ALPHABET)
# 10  0.084999             (JUMBO BAG RED RETROSPOT)
# 11  0.071100            (JUMBO BAG VINTAGE DOILY )
# 12  0.050893              (JUMBO BAG VINTAGE LEAF)
# 13  0.057415             (LUNCH BAG  BLACK SKULL.)
# 14  0.059553             (LUNCH BAG RED RETROSPOT)
# 15  0.052497              (LUNCH BAG SUKI DESIGN )
# 16  0.058805            (LUNCH BAG VINTAGE DOILY )
# 17  0.096226     (PAPER CHAIN KIT 50'S CHRISTMAS )
# 18  0.068534   (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 19  0.065647                      (POPCORN HOLDER)
# 20  0.070779                  (RABBIT NIGHT LIGHT)
# 21  0.062868            (REGENCY CAKESTAND 3 TIER)
# 22  0.050144        (SCOTTIE DOG HOT WATER BOTTLE)
# 23  0.058163   (SET OF 3 CAKE TINS PANTRY DESIGN )
# 24  0.051641          (SET OF 3 REGENCY CAKE TINS)
# 25  0.051320                      (SPOTTY BUNTING)
# 26  0.051641                  (VINTAGE SNAP CARDS)
# 27  0.079012  (WHITE HANGING HEART T-LIGHT HOLDER)

# %% [markdown]
# Selecting a support threshold
#
# The manager of the online gift store looks at the results you provided from the previous exercise and commends you for the good work. She does, however, raise an issue: all of the itemsets you identified contain only one item. She asks whether it would be possible to use a less restrictive rule and to generate more itemsets, possibly including those with multiple items.
#
# After agreeing to do this, you think about what might explain the lack of itemsets with more than 1 item. It can't be the max_len parameter, since that was set to three. You decide it must be support and decide to test two different values, each time checking how many additional itemsets are generated.

# %%
# Compute frequent itemsets using a support of 0.03 and length of 3
frequent_itemsets_1 = apriori(onehot_bool, min_support = 0.03, 
                            max_len = 3, use_colnames = True)

# Compute frequent itemsets using a support of 0.01 and length of 3
frequent_itemsets_2 = apriori(onehot_bool, min_support = 0.01, 
                            max_len = 3, use_colnames = True)

# Print the number of freqeuent itemsets
print(len(frequent_itemsets_1), len(frequent_itemsets_2))
# Out:
# 135 2515

# %% [markdown]
# Generating association rules
#
# In the final exercise of the previous section, you computed itemsets for the novelty gift store owner using the Apriori algorithm.
# Satisfied with the descriptive work you've done, the store manager asks you to identify some association rules from those two sets of frequent itemsets you computed.

# %%
# Compute all association rules for frequent_itemsets_1
rules_1 = association_rules(frequent_itemsets_1, 
                            metric = "support", 
                         	min_threshold = 0.04)

# Compute all association rules for frequent_itemsets_2
rules_2 = association_rules(frequent_itemsets_2, 
                            metric = "support",
                        	min_threshold = 0.04)

# Print the number of association rules generated
print(len(rules_1), len(rules_2))
# Out:
# 2 2

# %%
rules_1
# Out:
#                            antecedents                          consequents  \
# 0  (PAPER CHAIN KIT VINTAGE CHRISTMAS)    (PAPER CHAIN KIT 50'S CHRISTMAS )
# 1    (PAPER CHAIN KIT 50'S CHRISTMAS )  (PAPER CHAIN KIT VINTAGE CHRISTMAS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.068534            0.096226  0.046616    0.680187  7.068657
# 1            0.096226            0.068534  0.046616    0.484444  7.068657
#
#    leverage  conviction  zhangs_metric
# 0  0.040021    2.825948       0.921698
# 1  0.040021    1.806723       0.949939

# %%
rules_2
# Out:
#                            antecedents                          consequents  \
# 0  (PAPER CHAIN KIT VINTAGE CHRISTMAS)    (PAPER CHAIN KIT 50'S CHRISTMAS )
# 1    (PAPER CHAIN KIT 50'S CHRISTMAS )  (PAPER CHAIN KIT VINTAGE CHRISTMAS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.068534            0.096226  0.046616    0.680187  7.068657
# 1            0.096226            0.068534  0.046616    0.484444  7.068657
#
#    leverage  conviction  zhangs_metric
# 0  0.040021    2.825948       0.921698
# 1  0.040021    1.806723       0.949939

# %% [markdown]
# Pruning with lift
#
# Once again, you report back to the novelty gift store manager. This time, you tell her that you identified no rules when you used a higher support threshold for the Apriori algorithm and only two rules when you used a lower threshold. She commends you for the good work, but asks you to consider using another metric to reduce the two rules to one.
#
# You remember that lift had a simple interpretation: values greater than 1 indicate that items co-occur more than we would expect if they were independently distributed across transactions. You decide to use lift, since that message will be simple to convey.

# %%
frequent_itemsets_1
# Out:
#       support                                           itemsets
# 0    0.031434                      (6 GIFT TAGS 50'S CHRISTMAS )
# 1    0.031006                   (6 GIFT TAGS VINTAGE CHRISTMAS )
# 2    0.039880                           (6 RIBBONS RUSTIC CHARM)
# 3    0.049289                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 4    0.050144                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 130  0.031755  (JUMBO BAG 50'S CHRISTMAS , JUMBO BAG VINTAGE ...
# 131  0.030685  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...
# 132  0.035604  (JUMBO BAG RED RETROSPOT, JUMBO BAG VINTAGE DO...
# 133  0.046616  (PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAI...
# 134  0.037207  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
#
# [135 rows x 2 columns]

# %%
# Compute all association rules for frequent_itemsets1
rules = association_rules(frequent_itemsets, 
                            metric = "lift", 
                         	min_threshold = 15)

rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %% [markdown]
# Pruning with confidence
#
# Once again, you've come up short: you found multiple useful rules, but can't narrow it down to one. Even worse, the two rules you found used the same itemset, but just swapped the antecedents and consequents. You decide to see whether pruning by another metric might allow you to narrow things down to a single association rule.
#
# What would be the right metric? Both lift and support are identical for all rules that can be generated from an itemset, so you decide to use confidence instead, which differs for rules produced from the same itemset.

# %%
# Compute all association rules using confidence
rules = association_rules(frequent_itemsets_2, 
                            metric = "confidence", 
                         	min_threshold = 1)

rules
# Out:
#                                     antecedents       consequents  \
# 0  (SKULL SHOULDER BAG, JAM MAKING SET PRINTED)  (DOTCOM POSTAGE)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.010906            0.019566  0.010906         1.0  51.10929
#
#    leverage  conviction  zhangs_metric
# 0  0.010692         inf       0.991244

# %% [markdown]
# Aggregation and filtering
#
# In the video, we helped a gift store manager arrange the sections in her physical retail location according to association rules. The layout of the store forced us to group sections into two pairs of product types. After applying advanced filtering techniques, we proposed the floor layout below.
#
# Boxes - Bags
# Signs - Candles
#
# The image shows the store layout that was selected in the video.
# The store manager is now asking you to generate another floorplan proposal, but with a different criterion: each pair of sections should contain one high support product and one low support product

# %%
aggregated = pd.read_csv('aggregated.csv', index_col = 0)
aggregated
# Out:
#        bag    box  candle   sign
# 0     True  False   False   True
# 1     True  False   False  False
# 2    False   True   False  False
# 3     True  False    True   True
# 4    False   True   False  False
# ..     ...    ...     ...    ...
# 366  False  False   False   True
# 367  False  False   False   True
# 368   True  False   False   True
# 369   True  False   False  False
# 370  False  False   False   True
#
# [371 rows x 4 columns]

# %%
# Apply the apriori algorithm with a minimum support of 0.0001
frequent_itemsets_aggr = apriori(aggregated, min_support = 0.0001, use_colnames = True)
frequent_itemsets_aggr
# Out:
#      support             itemsets
# 0   0.466307                (bag)
# 1   0.256065                (box)
# 2   0.088949             (candle)
# 3   0.355795               (sign)
# 4   0.021563           (bag, box)
# 5   0.010782        (bag, candle)
# 6   0.097035          (sign, bag)
# 7   0.016173        (candle, box)
# 8   0.018868          (sign, box)
# 9   0.008086       (sign, candle)
# 10  0.005391  (sign, bag, candle)

# %%
# Generate the initial set of rules using a minimum support of 0.0001
rules = association_rules(frequent_itemsets_aggr, 
                          metric = "support", min_threshold = 0.0001)

rules
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0            (bag)           (box)            0.466307            0.256065
# 1            (box)           (bag)            0.256065            0.466307
# 2            (bag)        (candle)            0.466307            0.088949
# 3         (candle)           (bag)            0.088949            0.466307
# 4           (sign)           (bag)            0.355795            0.466307
# 5            (bag)          (sign)            0.466307            0.355795
# 6         (candle)           (box)            0.088949            0.256065
# 7            (box)        (candle)            0.256065            0.088949
# 8           (sign)           (box)            0.355795            0.256065
# 9            (box)          (sign)            0.256065            0.355795
# 10          (sign)        (candle)            0.355795            0.088949
# 11        (candle)          (sign)            0.088949            0.355795
# 12     (sign, bag)        (candle)            0.097035            0.088949
# 13  (sign, candle)           (bag)            0.008086            0.466307
# 14   (bag, candle)          (sign)            0.010782            0.355795
# 15          (sign)   (bag, candle)            0.355795            0.010782
# 16           (bag)  (sign, candle)            0.466307            0.008086
# 17        (candle)     (sign, bag)            0.088949            0.097035
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 0   0.021563    0.046243  0.180590 -0.097841    0.780005      -0.894758
# 1   0.021563    0.084211  0.180590 -0.097841    0.582768      -0.859139
# 2   0.010782    0.023121  0.259940 -0.030696    0.932615      -0.842137
# 3   0.010782    0.121212  0.259940 -0.030696    0.607306      -0.757576
# 4   0.097035    0.272727  0.584866 -0.068875    0.733827      -0.524220
# 5   0.097035    0.208092  0.584866 -0.068875    0.813485      -0.570809
# 6   0.016173    0.181818  0.710048 -0.006604    0.909254      -0.309499
# 7   0.016173    0.063158  0.710048 -0.006604    0.972470      -0.354386
# 8   0.018868    0.053030  0.207097 -0.072239    0.785596      -0.855975
# 9   0.018868    0.073684  0.207097 -0.072239    0.695448      -0.837305
# 10  0.008086    0.022727  0.255510 -0.023561    0.932238      -0.818939
# 11  0.008086    0.090909  0.255510 -0.023561    0.708625      -0.761804
# 12  0.005391    0.055556  0.624579 -0.003240    0.964642      -0.399642
# 13  0.005391    0.666667  1.429672  0.001620    1.601078       0.302989
# 14  0.005391    0.500000  1.405303  0.001555    1.288410       0.291553
# 15  0.005391    0.015152  1.405303  0.001555    1.004437       0.447699
# 16  0.005391    0.011561  1.429672  0.001620    1.003515       0.563131
# 17  0.005391    0.060606  0.624579 -0.003240    0.961221      -0.397504

# %%
# Set minimum antecedent support to 0.35
rules = rules[rules['antecedent support'] > 0.35]

# Set maximum consequent support to 0.35
rules = rules[rules['consequent support'] < 0.35]

rules
# Out:
#    antecedents     consequents  antecedent support  consequent support  \
# 0        (bag)           (box)            0.466307            0.256065
# 2        (bag)        (candle)            0.466307            0.088949
# 8       (sign)           (box)            0.355795            0.256065
# 10      (sign)        (candle)            0.355795            0.088949
# 15      (sign)   (bag, candle)            0.355795            0.010782
# 16       (bag)  (sign, candle)            0.466307            0.008086
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 0   0.021563    0.046243  0.180590 -0.097841    0.780005      -0.894758
# 2   0.010782    0.023121  0.259940 -0.030696    0.932615      -0.842137
# 8   0.018868    0.053030  0.207097 -0.072239    0.785596      -0.855975
# 10  0.008086    0.022727  0.255510 -0.023561    0.932238      -0.818939
# 15  0.005391    0.015152  1.405303  0.001555    1.004437       0.447699
# 16  0.005391    0.011561  1.429672  0.001620    1.003515       0.563131

# %% [markdown]
# Applying Zhang's rule
#
# In Chapter 2, we learned that Zhang's rule is a continuous measure of association between two items that takes values in the [-1,+1] interval. A -1 value indicates a perfectly negative association and a +1 value indicates a perfectly positive association. In this exercise, you'll determine whether Zhang's rule can be used to refine a set of rules a gift store is currently using to promote products.

# %%
# Generate the initial set of rules using a minimum lift of 1.00
rules = association_rules(frequent_itemsets_aggr, metric = "lift", min_threshold = 1)

rules
# Out:
#       antecedents     consequents  antecedent support  consequent support  \
# 0  (sign, candle)           (bag)            0.008086            0.466307
# 1   (bag, candle)          (sign)            0.010782            0.355795
# 2          (sign)   (bag, candle)            0.355795            0.010782
# 3           (bag)  (sign, candle)            0.466307            0.008086
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.005391    0.666667  1.429672  0.001620    1.601078       0.302989
# 1  0.005391    0.500000  1.405303  0.001555    1.288410       0.291553
# 2  0.005391    0.015152  1.405303  0.001555    1.004437       0.447699
# 3  0.005391    0.011561  1.429672  0.001620    1.003515       0.563131

# %%
# Set antecedent support to 0.005
rules = rules[rules['antecedent support'] > 0.05]

# Set consequent support to 0.005
rules = rules[rules['consequent support'] > 0.005]

rules
# Out:
#   antecedents     consequents  antecedent support  consequent support  \
# 2      (sign)   (bag, candle)            0.355795            0.010782
# 3       (bag)  (sign, candle)            0.466307            0.008086
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 2  0.005391    0.015152  1.405303  0.001555    1.004437       0.447699
# 3  0.005391    0.011561  1.429672  0.001620    1.003515       0.563131

# %%
def zhangs_rule(rules):
    PAB = rules['support'].copy()
    PA = rules['antecedent support'].copy()
    PB = rules['consequent support'].copy()
    NUMERATOR = PAB - PA*PB
    DENOMINATOR = np.max((PAB*(1-PA).values,PA*(PB-PAB).values), axis = 0)
    return NUMERATOR / DENOMINATOR

# %%
# Compute Zhang's rule
rules['zhang'] = zhangs_rule(rules)
rules
# Out:
#   antecedents     consequents  antecedent support  consequent support  \
# 2      (sign)   (bag, candle)            0.355795            0.010782
# 3       (bag)  (sign, candle)            0.466307            0.008086
#
#     support  confidence      lift  leverage  conviction  zhangs_metric  \
# 2  0.005391    0.015152  1.405303  0.001555    1.004437       0.447699
# 3  0.005391    0.011561  1.429672  0.001620    1.003515       0.563131
#
#       zhang
# 2  0.447699
# 3  0.563131

# %%
# Set the lower bound for Zhang's rule to 0.98
rules = rules[rules['zhang'] > 0.5]
print(rules[['antecedents', 'consequents']])
# Out:
#   antecedents     consequents
# 3       (bag)  (sign, candle)

# %% [markdown]
# Advanced filtering with multiple metrics
#
# Earlier, we used data from an online novelty gift store to find antecedents that could be used to promote a targeted consequent. Since the set of potential rules was large, we had to rely on the Apriori algorithm and multi-metric filtering to narrow it down. In this exercise, we'll examine the full set of rules and find a useful one, rather than targeting a particular antecedent.

# %%
frequent_itemsets_2
# Out:
#        support                                           itemsets
# 0     0.012723                   ( 50'S CHRISTMAS GIFT BAG LARGE)
# 1     0.013258                               ( DOLLY GIRL BEAKER)
# 2     0.010050                         ( RED SPOT GIFT BAG LARGE)
# 3     0.014113                           (10 COLOUR SPACEBOY PEN)
# 4     0.010906                  (12 MESSAGE CARDS WITH ENVELOPES)
# ...        ...                                                ...
# 2510  0.017000  (SET OF 3 WOODEN TREE DECORATIONS, SET OF 3 WO...
# 2511  0.010906  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 2512  0.015182  (SET OF 3 WOODEN TREE DECORATIONS, SET OF 3 WO...
# 2513  0.010157  (WOOD STOCKING CHRISTMAS SCANDISPOT, WOODEN ST...
# 2514  0.021811  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...
#
# [2515 rows x 2 columns]

# %%
# Recover association rules using a minium support threshold of 0.001
rules = association_rules(frequent_itemsets_2, metric = 'support', min_threshold = 0.001)
rules
# Out:
#                                             antecedents  \
# 0                     (SET 12 COLOUR PENCILS SPACEBOY )
# 1                       (12 PENCIL SMALL TUBE WOODLAND)
# 2                  (WOOD 2 DRAWER CABINET WHITE FINISH)
# 3                 (3 DRAWER ANTIQUE WHITE WOOD CABINET)
# 4                                  (VINTAGE SNAP CARDS)
# ...                                                 ...
# 5111  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 5112  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 5113               (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 5114               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 5115              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
#
#                                             consequents  antecedent support  \
# 0                       (12 PENCIL SMALL TUBE WOODLAND)            0.027371
# 1                     (SET 12 COLOUR PENCILS SPACEBOY )            0.021597
# 2                 (3 DRAWER ANTIQUE WHITE WOOD CABINET)            0.027371
# 3                  (WOOD 2 DRAWER CABINET WHITE FINISH)            0.020956
# 4                         (4 TRADITIONAL SPINNING TOPS)            0.051641
# ...                                                 ...                 ...
# 5111               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.023201
# 5112               (WOODEN TREE CHRISTMAS SCANDINAVIAN)            0.037207
# 5113  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...            0.029723
# 5114  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...            0.047364
# 5115  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...            0.047364
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.021597  0.011013    0.402344  18.629312  0.010421
# 1               0.027371  0.011013    0.509901  18.629312  0.010421
# 2               0.020956  0.012082    0.441406  21.063636  0.011508
# 3               0.027371  0.012082    0.576531  21.063636  0.011508
# 4               0.023094  0.011013    0.213251   9.233945  0.009820
# ...                  ...       ...         ...        ...       ...
# 5111            0.047364  0.021811    0.940092  19.848041  0.020712
# 5112            0.029723  0.021811    0.586207  19.722277  0.020705
# 5113            0.037207  0.021811    0.733813  19.722277  0.020705
# 5114            0.023201  0.021811    0.460497  19.848041  0.020712
# 5115            0.025981  0.021811    0.460497  17.724382  0.020581
#
#       conviction  zhangs_metric
# 0       1.637066       0.972952
# 1       1.984556       0.967210
# 2       1.752694       0.979330
# 3       2.296811       0.972913
# 4       1.241699       0.940260
# ...          ...            ...
# 5111   15.901685       0.972173
# 5112    2.344836       0.985982
# 5113    3.616978       0.978376
# 5114    1.810552       0.996832
# 5115    1.805399       0.990495
#
# [5116 rows x 10 columns]

# %%
# Apply a 0.002 antecedent support threshold, 0.60 confidence threshold, and 2.50 lift threshold
filtered_rules = rules[(rules['antecedent support'] > 0.02) &
						(rules['consequent support'] > 0.02) &
						(rules['confidence'] > 0.8) &
						(rules['lift'] > 29)]

filtered_rules
# Out:
#                                             antecedents  \
# 5088  (SET OF 3 WOODEN STOCKING DECORATION, SET OF 3...
#
#                              consequents  antecedent support  \
# 5088  (SET OF 3 WOODEN TREE DECORATIONS)            0.021063
#
#       consequent support  support  confidence       lift  leverage  \
# 5088            0.027799    0.017    0.807107  29.034108  0.016414
#
#       conviction  zhangs_metric
# 5088    5.040097       0.986333

# %% [markdown]
# Visualizing itemset support
#
# A content-streaming start-up has approached you for consulting services. To keep licensing fees low, they want to assemble a narrow library of movies that all appeal to the same audience. While they'll provide a smaller selection of content than the big players in the industry, they'll also be able to offer a low subscription fee.
#
# You decide to use the MovieLens data and a heatmap for this project. Using a simple support-based heatmap will allow you to identify individual titles that have high support with other titles.

# %%
ratings = pd.read_csv('movielens_movies.csv')
ratings
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %%
ratings['genres_split'] = ratings.genres.apply(lambda row: row.split('|'))
ratings
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
#                                             genres_split
# 0      [Adventure, Animation, Children, Comedy, Fantasy]
# 1                         [Adventure, Children, Fantasy]
# 2                                      [Comedy, Romance]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 27273                                           [Comedy]
# 27274                                           [Comedy]
# 27275                                        [Adventure]
# 27276                               [(no genres listed)]
# 27277                       [Adventure, Fantasy, Horror]
#
# [27278 rows x 4 columns]

# %%
encoder
# Out:
# TransactionEncoder()

# %%
onehot = encoder.fit(ratings.genres_split).transform(ratings.genres_split)
print(onehot.shape)
print(encoder.columns_)
onehot
# Out:
# (27278, 20)
# ['(no genres listed)', 'Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
# array([[False, False,  True, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False,  True, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [False, False,  True, ..., False, False, False]])

# %%
onehot_df = pd.DataFrame(onehot, columns = encoder.columns_, index = ratings.title)
onehot_df
# Out:
#                                     (no genres listed)  Action  Adventure  \
# title
# Toy Story (1995)                                 False   False       True
# Jumanji (1995)                                   False   False       True
# Grumpier Old Men (1995)                          False   False      False
# Waiting to Exhale (1995)                         False   False      False
# Father of the Bride Part II (1995)               False   False      False
# ...                                                ...     ...        ...
# Kein Bund für's Leben (2007)                     False   False      False
# Feuer, Eis & Dosenbier (2002)                    False   False      False
# The Pirates (2014)                               False   False       True
# Rentun Ruusu (2001)                               True   False      False
# Innocence (2014)                                 False   False       True
#
#                                     Animation  Children  Comedy  Crime  \
# title
# Toy Story (1995)                         True      True    True  False
# Jumanji (1995)                          False      True   False  False
# Grumpier Old Men (1995)                 False     False    True  False
# Waiting to Exhale (1995)                False     False    True  False
# Father of the Bride Part II (1995)      False     False    True  False
# ...                                       ...       ...     ...    ...
# Kein Bund für's Leben (2007)            False     False    True  False
# Feuer, Eis & Dosenbier (2002)           False     False    True  False
# The Pirates (2014)                      False     False   False  False
# Rentun Ruusu (2001)                     False     False   False  False
# Innocence (2014)                        False     False   False  False
#
#                                     Documentary  Drama  Fantasy  Film-Noir  \
# title
# Toy Story (1995)                          False  False     True      False
# Jumanji (1995)                            False  False     True      False
# Grumpier Old Men (1995)                   False  False    False      False
# Waiting to Exhale (1995)                  False   True    False      False
# Father of the Bride Part II (1995)        False  False    False      False
# ...                                         ...    ...      ...        ...
# Kein Bund für's Leben (2007)              False  False    False      False
# Feuer, Eis & Dosenbier (2002)             False  False    False      False
# The Pirates (2014)                        False  False    False      False
# Rentun Ruusu (2001)                       False  False    False      False
# Innocence (2014)                          False  False     True      False
#
#                                     Horror   IMAX  Musical  Mystery  Romance  \
# title
# Toy Story (1995)                     False  False    False    False    False
# Jumanji (1995)                       False  False    False    False    False
# Grumpier Old Men (1995)              False  False    False    False     True
# Waiting to Exhale (1995)             False  False    False    False     True
# Father of the Bride Part II (1995)   False  False    False    False    False
# ...                                    ...    ...      ...      ...      ...
# Kein Bund für's Leben (2007)         False  False    False    False    False
# Feuer, Eis & Dosenbier (2002)        False  False    False    False    False
# The Pirates (2014)                   False  False    False    False    False
# Rentun Ruusu (2001)                  False  False    False    False    False
# Innocence (2014)                      True  False    False    False    False
#
#                                     Sci-Fi  Thriller    War  Western
# title
# Toy Story (1995)                     False     False  False    False
# Jumanji (1995)                       False     False  False    False
# Grumpier Old Men (1995)              False     False  False    False
# Waiting to Exhale (1995)             False     False  False    False
# Father of the Bride Part II (1995)   False     False  False    False
# ...                                    ...       ...    ...      ...
# Kein Bund für's Leben (2007)         False     False  False    False
# Feuer, Eis & Dosenbier (2002)        False     False  False    False
# The Pirates (2014)                   False     False  False    False
# Rentun Ruusu (2001)                  False     False  False    False
# Innocence (2014)                     False     False  False    False
#
# [27278 rows x 20 columns]

# %%
categories_per_title = onehot_df.sum(axis = 1) # .sort_values(ascending = False)
categories_per_title
# Out:
# title
# Toy Story (1995)                      5
# Jumanji (1995)                        3
# Grumpier Old Men (1995)               2
# Waiting to Exhale (1995)              3
# Father of the Bride Part II (1995)    1
#                                      ..
# Kein Bund für's Leben (2007)          1
# Feuer, Eis & Dosenbier (2002)         1
# The Pirates (2014)                    1
# Rentun Ruusu (2001)                   1
# Innocence (2014)                      3
# Length: 27278, dtype: int64

# %%
titlee_with_most_categories = categories_per_title >= 5
titlee_with_most_categories
# Out:
# title
# Toy Story (1995)                       True
# Jumanji (1995)                        False
# Grumpier Old Men (1995)               False
# Waiting to Exhale (1995)              False
# Father of the Bride Part II (1995)    False
#                                       ...
# Kein Bund für's Leben (2007)          False
# Feuer, Eis & Dosenbier (2002)         False
# The Pirates (2014)                    False
# Rentun Ruusu (2001)                   False
# Innocence (2014)                      False
# Length: 27278, dtype: bool

# %%
onehot_filt = onehot_df[titlee_with_most_categories]
onehot_filt
# Out:
#                                                     (no genres listed)  \
# title
# Toy Story (1995)                                                 False
# Money Train (1995)                                               False
# Copycat (1995)                                                   False
# City of Lost Children, The (Cité des enfants pe...               False
# Pocahontas (1995)                                                False
# ...                                                                ...
# Cardcaptor Sakura: The Sealed Card (2000)                        False
# Berserk: The Golden Age Arc - The Egg of the Ki...               False
# The Amazing Screw-On Head (2006)                                 False
# Home (2015)                                                      False
# Brother Bear 2 (2006)                                            False
#
#                                                     Action  Adventure  \
# title
# Toy Story (1995)                                     False       True
# Money Train (1995)                                    True      False
# Copycat (1995)                                       False      False
# City of Lost Children, The (Cité des enfants pe...   False       True
# Pocahontas (1995)                                    False      False
# ...                                                    ...        ...
# Cardcaptor Sakura: The Sealed Card (2000)            False       True
# Berserk: The Golden Age Arc - The Egg of the Ki...    True       True
# The Amazing Screw-On Head (2006)                      True       True
# Home (2015)                                          False      False
# Brother Bear 2 (2006)                                False       True
#
#                                                     Animation  Children  \
# title
# Toy Story (1995)                                         True      True
# Money Train (1995)                                      False     False
# Copycat (1995)                                          False     False
# City of Lost Children, The (Cité des enfants pe...      False     False
# Pocahontas (1995)                                        True      True
# ...                                                       ...       ...
# Cardcaptor Sakura: The Sealed Card (2000)                True     False
# Berserk: The Golden Age Arc - The Egg of the Ki...       True     False
# The Amazing Screw-On Head (2006)                         True     False
# Home (2015)                                              True      True
# Brother Bear 2 (2006)                                    True      True
#
#                                                     Comedy  Crime  \
# title
# Toy Story (1995)                                      True  False
# Money Train (1995)                                    True   True
# Copycat (1995)                                       False   True
# City of Lost Children, The (Cité des enfants pe...   False  False
# Pocahontas (1995)                                    False  False
# ...                                                    ...    ...
# Cardcaptor Sakura: The Sealed Card (2000)             True  False
# Berserk: The Golden Age Arc - The Egg of the Ki...   False  False
# The Amazing Screw-On Head (2006)                      True  False
# Home (2015)                                           True  False
# Brother Bear 2 (2006)                                 True  False
#
#                                                     Documentary  Drama  \
# title
# Toy Story (1995)                                          False  False
# Money Train (1995)                                        False   True
# Copycat (1995)                                            False   True
# City of Lost Children, The (Cité des enfants pe...        False   True
# Pocahontas (1995)                                         False   True
# ...                                                         ...    ...
# Cardcaptor Sakura: The Sealed Card (2000)                 False  False
# Berserk: The Golden Age Arc - The Egg of the Ki...        False  False
# The Amazing Screw-On Head (2006)                          False  False
# Home (2015)                                               False  False
# Brother Bear 2 (2006)                                     False  False
#
#                                                     Fantasy  Film-Noir  \
# title
# Toy Story (1995)                                       True      False
# Money Train (1995)                                    False      False
# Copycat (1995)                                        False      False
# City of Lost Children, The (Cité des enfants pe...     True      False
# Pocahontas (1995)                                     False      False
# ...                                                     ...        ...
# Cardcaptor Sakura: The Sealed Card (2000)              True      False
# Berserk: The Golden Age Arc - The Egg of the Ki...     True      False
# The Amazing Screw-On Head (2006)                      False      False
# Home (2015)                                            True      False
# Brother Bear 2 (2006)                                  True      False
#
#                                                     Horror   IMAX  Musical  \
# title
# Toy Story (1995)                                     False  False    False
# Money Train (1995)                                   False  False    False
# Copycat (1995)                                        True  False    False
# City of Lost Children, The (Cité des enfants pe...   False  False    False
# Pocahontas (1995)                                    False  False     True
# ...                                                    ...    ...      ...
# Cardcaptor Sakura: The Sealed Card (2000)            False  False    False
# Berserk: The Golden Age Arc - The Egg of the Ki...    True  False    False
# The Amazing Screw-On Head (2006)                     False  False    False
# Home (2015)                                          False  False    False
# Brother Bear 2 (2006)                                False  False    False
#
#                                                     Mystery  Romance  Sci-Fi  \
# title
# Toy Story (1995)                                      False    False   False
# Money Train (1995)                                    False    False   False
# Copycat (1995)                                         True    False   False
# City of Lost Children, The (Cité des enfants pe...     True    False    True
# Pocahontas (1995)                                     False     True   False
# ...                                                     ...      ...     ...
# Cardcaptor Sakura: The Sealed Card (2000)             False     True   False
# Berserk: The Golden Age Arc - The Egg of the Ki...    False    False   False
# The Amazing Screw-On Head (2006)                      False    False    True
# Home (2015)                                           False    False    True
# Brother Bear 2 (2006)                                 False    False   False
#
#                                                     Thriller    War  Western
# title
# Toy Story (1995)                                       False  False    False
# Money Train (1995)                                      True  False    False
# Copycat (1995)                                          True  False    False
# City of Lost Children, The (Cité des enfants pe...     False  False    False
# Pocahontas (1995)                                      False  False    False
# ...                                                      ...    ...      ...
# Cardcaptor Sakura: The Sealed Card (2000)              False  False    False
# Berserk: The Golden Age Arc - The Egg of the Ki...     False  False    False
# The Amazing Screw-On Head (2006)                       False  False    False
# Home (2015)                                            False  False    False
# Brother Bear 2 (2006)                                  False  False    False
#
# [586 rows x 20 columns]

# %%
onehot_filt_T = onehot_filt.T
onehot_filt_T
# Out:
# title               Toy Story (1995)  Money Train (1995)  Copycat (1995)  \
# (no genres listed)             False               False           False
# Action                         False                True           False
# Adventure                       True               False           False
# Animation                       True               False           False
# Children                        True               False           False
# Comedy                          True                True           False
# Crime                          False                True            True
# Documentary                    False               False           False
# Drama                          False                True            True
# Fantasy                         True               False           False
# Film-Noir                      False               False           False
# Horror                         False               False            True
# IMAX                           False               False           False
# Musical                        False               False           False
# Mystery                        False               False            True
# Romance                        False               False           False
# Sci-Fi                         False               False           False
# Thriller                       False                True            True
# War                            False               False           False
# Western                        False               False           False
#
# title               City of Lost Children, The (Cité des enfants perdus, La) (1995)  \
# (no genres listed)                                              False
# Action                                                          False
# Adventure                                                        True
# Animation                                                       False
# Children                                                        False
# Comedy                                                          False
# Crime                                                           False
# Documentary                                                     False
# Drama                                                            True
# Fantasy                                                          True
# Film-Noir                                                       False
# Horror                                                          False
# IMAX                                                            False
# Musical                                                         False
# Mystery                                                          True
# Romance                                                         False
# Sci-Fi                                                           True
# Thriller                                                        False
# War                                                             False
# Western                                                         False
#
# title               Pocahontas (1995)  Bad Boys (1995)  Strange Days (1995)  \
# (no genres listed)              False            False                False
# Action                          False             True                 True
# Adventure                       False            False                False
# Animation                        True            False                False
# Children                         True            False                False
# Comedy                          False             True                False
# Crime                           False             True                 True
# Documentary                     False            False                False
# Drama                            True             True                 True
# Fantasy                         False            False                False
# Film-Noir                       False            False                False
# Horror                          False            False                False
# IMAX                            False            False                False
# Musical                          True            False                False
# Mystery                         False            False                 True
# Romance                          True            False                False
# Sci-Fi                          False            False                 True
# Thriller                        False             True                 True
# War                             False            False                False
# Western                         False            False                False
#
# title               Kid in King Arthur's Court, A (1995)  \
# (no genres listed)                                 False
# Action                                             False
# Adventure                                           True
# Animation                                          False
# Children                                            True
# Comedy                                              True
# Crime                                              False
# Documentary                                        False
# Drama                                              False
# Fantasy                                             True
# Film-Noir                                          False
# Horror                                             False
# IMAX                                               False
# Musical                                            False
# Mystery                                            False
# Romance                                             True
# Sci-Fi                                             False
# Thriller                                           False
# War                                                False
# Western                                            False
#
# title               Lion King, The (1994)  True Lies (1994)  ...  Pan (1995)  \
# (no genres listed)                  False             False  ...       False
# Action                              False              True  ...        True
# Adventure                            True              True  ...        True
# Animation                            True             False  ...       False
# Children                             True             False  ...       False
# Comedy                              False              True  ...       False
# Crime                               False             False  ...       False
# Documentary                         False             False  ...       False
# Drama                                True             False  ...        True
# Fantasy                             False             False  ...        True
# Film-Noir                           False             False  ...       False
# Horror                              False             False  ...       False
# IMAX                                 True             False  ...       False
# Musical                              True             False  ...       False
# Mystery                             False             False  ...       False
# Romance                             False              True  ...        True
# Sci-Fi                              False             False  ...       False
# Thriller                            False              True  ...       False
# War                                 False             False  ...       False
# Western                             False             False  ...       False
#
# title               Honey, We Shrunk Ourselves (1997)  \
# (no genres listed)                              False
# Action                                           True
# Adventure                                        True
# Animation                                       False
# Children                                         True
# Comedy                                           True
# Crime                                           False
# Documentary                                     False
# Drama                                           False
# Fantasy                                         False
# Film-Noir                                       False
# Horror                                          False
# IMAX                                            False
# Musical                                         False
# Mystery                                         False
# Romance                                         False
# Sci-Fi                                           True
# Thriller                                        False
# War                                             False
# Western                                         False
#
# title               The Stone Council (2006)  Run All Night (2015)  \
# (no genres listed)                     False                 False
# Action                                 False                  True
# Adventure                               True                 False
# Animation                              False                 False
# Children                               False                 False
# Comedy                                 False                 False
# Crime                                   True                  True
# Documentary                            False                 False
# Drama                                   True                  True
# Fantasy                                 True                 False
# Film-Noir                              False                 False
# Horror                                 False                 False
# IMAX                                   False                 False
# Musical                                False                 False
# Mystery                                 True                  True
# Romance                                False                 False
# Sci-Fi                                 False                 False
# Thriller                                True                  True
# War                                    False                 False
# Western                                False                 False
#
# title               Digging Up the Marrow (2014)  \
# (no genres listed)                         False
# Action                                     False
# Adventure                                  False
# Animation                                  False
# Children                                   False
# Comedy                                     False
# Crime                                      False
# Documentary                                False
# Drama                                       True
# Fantasy                                     True
# Film-Noir                                  False
# Horror                                      True
# IMAX                                       False
# Musical                                    False
# Mystery                                     True
# Romance                                    False
# Sci-Fi                                     False
# Thriller                                    True
# War                                        False
# Western                                    False
#
# title               Cardcaptor Sakura: The Sealed Card (2000)  \
# (no genres listed)                                      False
# Action                                                  False
# Adventure                                                True
# Animation                                                True
# Children                                                False
# Comedy                                                   True
# Crime                                                   False
# Documentary                                             False
# Drama                                                   False
# Fantasy                                                  True
# Film-Noir                                               False
# Horror                                                  False
# IMAX                                                    False
# Musical                                                 False
# Mystery                                                 False
# Romance                                                  True
# Sci-Fi                                                  False
# Thriller                                                False
# War                                                     False
# Western                                                 False
#
# title               Berserk: The Golden Age Arc - The Egg of the King (2012)  \
# (no genres listed)                                              False
# Action                                                           True
# Adventure                                                        True
# Animation                                                        True
# Children                                                        False
# Comedy                                                          False
# Crime                                                           False
# Documentary                                                     False
# Drama                                                           False
# Fantasy                                                          True
# Film-Noir                                                       False
# Horror                                                           True
# IMAX                                                            False
# Musical                                                         False
# Mystery                                                         False
# Romance                                                         False
# Sci-Fi                                                          False
# Thriller                                                        False
# War                                                             False
# Western                                                         False
#
# title               The Amazing Screw-On Head (2006)  Home (2015)  \
# (no genres listed)                             False        False
# Action                                          True        False
# Adventure                                       True        False
# Animation                                       True         True
# Children                                       False         True
# Comedy                                          True         True
# Crime                                          False        False
# Documentary                                    False        False
# Drama                                          False        False
# Fantasy                                        False         True
# Film-Noir                                      False        False
# Horror                                         False        False
# IMAX                                           False        False
# Musical                                        False        False
# Mystery                                        False        False
# Romance                                        False        False
# Sci-Fi                                          True         True
# Thriller                                       False        False
# War                                            False        False
# Western                                        False        False
#
# title               Brother Bear 2 (2006)
# (no genres listed)                  False
# Action                              False
# Adventure                            True
# Animation                            True
# Children                             True
# Comedy                               True
# Crime                               False
# Documentary                         False
# Drama                               False
# Fantasy                              True
# Film-Noir                           False
# Horror                              False
# IMAX                                False
# Musical                             False
# Mystery                             False
# Romance                             False
# Sci-Fi                              False
# Thriller                            False
# War                                 False
# Western                             False
#
# [20 rows x 586 columns]

# %%
# Compute frequent itemsets using a minimum support of 0.07
frequent_itemsets = apriori(onehot_filt_T, min_support = 0.35, 
                            use_colnames = True, max_len = 3)

frequent_itemsets
# Out:
#     support                                           itemsets
# 0      0.35                                     (Mulan (1998))
# 1      0.35                  (Who Framed Roger Rabbit? (1988))
# 2      0.35                             (Osmosis Jones (2001))
# 3      0.40                                  (Motorama (1991))
# 4      0.35                             (Interstate 60 (2002))
# 5      0.40  (Wonderful World of the Brothers Grimm, The (1...
# 6      0.40  (Patlabor: The Movie (Kidô keisatsu patorebâ: ...
# 7      0.35  (Revolutionary Girl Utena: Adolescence of Uten...
# 8      0.35                               (Svidd Neger (2003))
# 9      0.35                                    (Robots (2005))
# 10     0.35                                     (Pulse (2006))
# 11     0.35                                       (She (1965))
# 12     0.35  (Aqua Teen Hunger Force Colon Movie Film for T...
# 13     0.35                                 (Enchanted (2007))
# 14     0.35        (Aelita: The Queen of Mars (Aelita) (1924))
# 15     0.35            (Hero: Love Story of a Spy, The (2003))
# 16     0.35                   (Lucky: No Time For Love (2005))
# 17     0.40  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 18     0.40  (Lupin III: First Contact (Rupan Sansei: Faasu...
# 19     0.35                                 (Inception (2010))
# 20     0.50                                    (Rubber (2010))
# 21     0.35                                   (Tangled (2010))
# 22     0.35                     (Kaho Naa... Pyaar Hai (2000))
# 23     0.35                           (Mars Needs Moms (2011))
# 24     0.35  (Glamorous Life of Sachiko Hanai, The (Hatsujô...
# 25     0.35                            (Whip Hand, The (1951))
# 26     0.35  (Wonderful World of the Brothers Grimm, The (1...
# 27     0.35  (Osmosis Jones (2001), Lupin III: Sweet Lost N...
# 28     0.35  (Osmosis Jones (2001), Lupin III: First Contac...
# 29     0.35            (Motorama (1991), Interstate 60 (2002))
# 30     0.35  (Wonderful World of the Brothers Grimm, The (1...
# 31     0.35  (Hero: Love Story of a Spy, The (2003), Lucky:...
# 32     0.40  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 33     0.35  (Osmosis Jones (2001), Lupin III: Sweet Lost N...

# %%
# Compute the association rules
rules = association_rules(frequent_itemsets, metric = 'support', 
                          min_threshold = 0.0)
rules
# Out:
#                                           antecedents  \
# 0   (Wonderful World of the Brothers Grimm, The (1...
# 1                                      (Mulan (1998))
# 2                              (Osmosis Jones (2001))
# 3   (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 4                              (Osmosis Jones (2001))
# 5   (Lupin III: First Contact (Rupan Sansei: Faasu...
# 6                                   (Motorama (1991))
# 7                              (Interstate 60 (2002))
# 8   (Wonderful World of the Brothers Grimm, The (1...
# 9                                  (Enchanted (2007))
# 10            (Hero: Love Story of a Spy, The (2003))
# 11                   (Lucky: No Time For Love (2005))
# 12  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 13  (Lupin III: First Contact (Rupan Sansei: Faasu...
# 14  (Osmosis Jones (2001), Lupin III: Sweet Lost N...
# 15  (Osmosis Jones (2001), Lupin III: First Contac...
# 16  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 17                             (Osmosis Jones (2001))
# 18  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 19  (Lupin III: First Contact (Rupan Sansei: Faasu...
#
#                                           consequents  antecedent support  \
# 0                                      (Mulan (1998))                0.40
# 1   (Wonderful World of the Brothers Grimm, The (1...                0.35
# 2   (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.35
# 3                              (Osmosis Jones (2001))                0.40
# 4   (Lupin III: First Contact (Rupan Sansei: Faasu...                0.35
# 5                              (Osmosis Jones (2001))                0.40
# 6                              (Interstate 60 (2002))                0.40
# 7                                   (Motorama (1991))                0.35
# 8                                  (Enchanted (2007))                0.40
# 9   (Wonderful World of the Brothers Grimm, The (1...                0.35
# 10                   (Lucky: No Time For Love (2005))                0.35
# 11            (Hero: Love Story of a Spy, The (2003))                0.35
# 12  (Lupin III: First Contact (Rupan Sansei: Faasu...                0.40
# 13  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.40
# 14  (Lupin III: First Contact (Rupan Sansei: Faasu...                0.35
# 15  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.35
# 16                             (Osmosis Jones (2001))                0.40
# 17  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.35
# 18  (Osmosis Jones (2001), Lupin III: First Contac...                0.40
# 19  (Osmosis Jones (2001), Lupin III: Sweet Lost N...                0.40
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 1                 0.40     0.35       1.000  2.500000    0.2100         inf
# 2                 0.40     0.35       1.000  2.500000    0.2100         inf
# 3                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 4                 0.40     0.35       1.000  2.500000    0.2100         inf
# 5                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 6                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 7                 0.40     0.35       1.000  2.500000    0.2100         inf
# 8                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 9                 0.40     0.35       1.000  2.500000    0.2100         inf
# 10                0.35     0.35       1.000  2.857143    0.2275         inf
# 11                0.35     0.35       1.000  2.857143    0.2275         inf
# 12                0.40     0.40       1.000  2.500000    0.2400         inf
# 13                0.40     0.40       1.000  2.500000    0.2400         inf
# 14                0.40     0.35       1.000  2.500000    0.2100         inf
# 15                0.40     0.35       1.000  2.500000    0.2100         inf
# 16                0.35     0.35       0.875  2.500000    0.2100         5.2
# 17                0.40     0.35       1.000  2.500000    0.2100         inf
# 18                0.35     0.35       0.875  2.500000    0.2100         5.2
# 19                0.35     0.35       0.875  2.500000    0.2100         5.2
#
#     zhangs_metric
# 0        1.000000
# 1        0.923077
# 2        0.923077
# 3        1.000000
# 4        0.923077
# 5        1.000000
# 6        1.000000
# 7        0.923077
# 8        1.000000
# 9        0.923077
# 10       1.000000
# 11       1.000000
# 12       1.000000
# 13       1.000000
# 14       0.923077
# 15       0.923077
# 16       1.000000
# 17       0.923077
# 18       1.000000
# 19       1.000000

# %%
# Replace frozen sets with strings
rules['antecedents'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))
rules['consequents'] = rules['consequents'].apply(lambda a: ','.join(list(a)))

# Transform data to matrix format and generate heatmap
pivot = rules.pivot(index='consequents', columns='antecedents', values='support')
pivot
# Out:
# antecedents                                         Enchanted (2007)  \
# consequents
# Enchanted (2007)                                                 NaN
# Hero: Love Story of a Spy, The (2003)                            NaN
# Interstate 60 (2002)                                             NaN
# Lucky: No Time For Love (2005)                                   NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...               NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...               NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...               NaN
# Motorama (1991)                                                  NaN
# Mulan (1998)                                                     NaN
# Osmosis Jones (2001)                                             NaN
# Osmosis Jones (2001),Lupin III: First Contact (...               NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...               NaN
# Wonderful World of the Brothers Grimm, The (1962)               0.35
#
# antecedents                                         Hero: Love Story of a Spy, The (2003)  \
# consequents
# Enchanted (2007)                                                                      NaN
# Hero: Love Story of a Spy, The (2003)                                                 NaN
# Interstate 60 (2002)                                                                  NaN
# Lucky: No Time For Love (2005)                                                       0.35
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                    NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                    NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                    NaN
# Motorama (1991)                                                                       NaN
# Mulan (1998)                                                                          NaN
# Osmosis Jones (2001)                                                                  NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                    NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                    NaN
# Wonderful World of the Brothers Grimm, The (1962)                                     NaN
#
# antecedents                                         Interstate 60 (2002)  \
# consequents
# Enchanted (2007)                                                     NaN
# Hero: Love Story of a Spy, The (2003)                                NaN
# Interstate 60 (2002)                                                 NaN
# Lucky: No Time For Love (2005)                                       NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                   NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   NaN
# Motorama (1991)                                                     0.35
# Mulan (1998)                                                         NaN
# Osmosis Jones (2001)                                                 NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                   NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                   NaN
# Wonderful World of the Brothers Grimm, The (1962)                    NaN
#
# antecedents                                         Lucky: No Time For Love (2005)  \
# consequents
# Enchanted (2007)                                                               NaN
# Hero: Love Story of a Spy, The (2003)                                         0.35
# Interstate 60 (2002)                                                           NaN
# Lucky: No Time For Love (2005)                                                 NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                             NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                             NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                             NaN
# Motorama (1991)                                                                NaN
# Mulan (1998)                                                                   NaN
# Osmosis Jones (2001)                                                           NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                             NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                             NaN
# Wonderful World of the Brothers Grimm, The (1962)                              NaN
#
# antecedents                                         Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                               0.40
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                             0.35
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                               0.35
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                               0.40
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                             0.35
# Osmosis Jones (2001),Lupin III: First Contact (...                                               0.35
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008),Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                             0.35
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Motorama (1991)  \
# consequents
# Enchanted (2007)                                                NaN
# Hero: Love Story of a Spy, The (2003)                           NaN
# Interstate 60 (2002)                                           0.35
# Lucky: No Time For Love (2005)                                  NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...              NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...              NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...              NaN
# Motorama (1991)                                                 NaN
# Mulan (1998)                                                    NaN
# Osmosis Jones (2001)                                            NaN
# Osmosis Jones (2001),Lupin III: First Contact (...              NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...              NaN
# Wonderful World of the Brothers Grimm, The (1962)               NaN
#
# antecedents                                         Mulan (1998)  \
# consequents
# Enchanted (2007)                                             NaN
# Hero: Love Story of a Spy, The (2003)                        NaN
# Interstate 60 (2002)                                         NaN
# Lucky: No Time For Love (2005)                               NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...           NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...           NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...           NaN
# Motorama (1991)                                              NaN
# Mulan (1998)                                                 NaN
# Osmosis Jones (2001)                                         NaN
# Osmosis Jones (2001),Lupin III: First Contact (...           NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...           NaN
# Wonderful World of the Brothers Grimm, The (1962)           0.35
#
# antecedents                                         Osmosis Jones (2001)  \
# consequents
# Enchanted (2007)                                                     NaN
# Hero: Love Story of a Spy, The (2003)                                NaN
# Interstate 60 (2002)                                                 NaN
# Lucky: No Time For Love (2005)                                       NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                  0.35
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                  0.35
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                  0.35
# Motorama (1991)                                                      NaN
# Mulan (1998)                                                         NaN
# Osmosis Jones (2001)                                                 NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                   NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                   NaN
# Wonderful World of the Brothers Grimm, The (1962)                    NaN
#
# antecedents                                         Osmosis Jones (2001),Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                               0.35
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Osmosis Jones (2001),Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                               0.35
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Wonderful World of the Brothers Grimm, The (1962)
# consequents
# Enchanted (2007)                                                                                 0.35
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                     0.35
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN

# %%
sns.heatmap(pivot)

# Format and display plot
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# Heatmaps with lift
#
# The founder likes the heatmap you've produced for her streaming service. After discussing the project further, however, you decide that that it is important to examine other metrics before making a final decision on which movies to license. In particular, the founder suggests that you select a metric that tells you whether the support values are higher than we would expect given the films' individual support values.
#
# You recall that lift does this well and decide to use it as a metric. You also remember that lift has an important threshold at 1.0 and decide that it is important to replace the colorbar with annotations, so you can determine whether a value is greater than 1.0.

# %%
# Transform the DataFrame of rules into a matrix using the lift metric
pivot = rules.pivot(index = 'consequents', 
                   columns = 'antecedents', values= 'lift')

pivot
# Out:
# antecedents                                         Enchanted (2007)  \
# consequents
# Enchanted (2007)                                                 NaN
# Hero: Love Story of a Spy, The (2003)                            NaN
# Interstate 60 (2002)                                             NaN
# Lucky: No Time For Love (2005)                                   NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...               NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...               NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...               NaN
# Motorama (1991)                                                  NaN
# Mulan (1998)                                                     NaN
# Osmosis Jones (2001)                                             NaN
# Osmosis Jones (2001),Lupin III: First Contact (...               NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...               NaN
# Wonderful World of the Brothers Grimm, The (1962)                2.5
#
# antecedents                                         Hero: Love Story of a Spy, The (2003)  \
# consequents
# Enchanted (2007)                                                                      NaN
# Hero: Love Story of a Spy, The (2003)                                                 NaN
# Interstate 60 (2002)                                                                  NaN
# Lucky: No Time For Love (2005)                                                   2.857143
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                    NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                    NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                    NaN
# Motorama (1991)                                                                       NaN
# Mulan (1998)                                                                          NaN
# Osmosis Jones (2001)                                                                  NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                    NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                    NaN
# Wonderful World of the Brothers Grimm, The (1962)                                     NaN
#
# antecedents                                         Interstate 60 (2002)  \
# consequents
# Enchanted (2007)                                                     NaN
# Hero: Love Story of a Spy, The (2003)                                NaN
# Interstate 60 (2002)                                                 NaN
# Lucky: No Time For Love (2005)                                       NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                   NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   NaN
# Motorama (1991)                                                      2.5
# Mulan (1998)                                                         NaN
# Osmosis Jones (2001)                                                 NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                   NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                   NaN
# Wonderful World of the Brothers Grimm, The (1962)                    NaN
#
# antecedents                                         Lucky: No Time For Love (2005)  \
# consequents
# Enchanted (2007)                                                               NaN
# Hero: Love Story of a Spy, The (2003)                                     2.857143
# Interstate 60 (2002)                                                           NaN
# Lucky: No Time For Love (2005)                                                 NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                             NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                             NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                             NaN
# Motorama (1991)                                                                NaN
# Mulan (1998)                                                                   NaN
# Osmosis Jones (2001)                                                           NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                             NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                             NaN
# Wonderful World of the Brothers Grimm, The (1962)                              NaN
#
# antecedents                                         Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              2.5
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                2.5
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              2.5
# Osmosis Jones (2001),Lupin III: First Contact (...                                                2.5
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008),Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              2.5
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Motorama (1991)  \
# consequents
# Enchanted (2007)                                                NaN
# Hero: Love Story of a Spy, The (2003)                           NaN
# Interstate 60 (2002)                                            2.5
# Lucky: No Time For Love (2005)                                  NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...              NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...              NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...              NaN
# Motorama (1991)                                                 NaN
# Mulan (1998)                                                    NaN
# Osmosis Jones (2001)                                            NaN
# Osmosis Jones (2001),Lupin III: First Contact (...              NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...              NaN
# Wonderful World of the Brothers Grimm, The (1962)               NaN
#
# antecedents                                         Mulan (1998)  \
# consequents
# Enchanted (2007)                                             NaN
# Hero: Love Story of a Spy, The (2003)                        NaN
# Interstate 60 (2002)                                         NaN
# Lucky: No Time For Love (2005)                               NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...           NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...           NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...           NaN
# Motorama (1991)                                              NaN
# Mulan (1998)                                                 NaN
# Osmosis Jones (2001)                                         NaN
# Osmosis Jones (2001),Lupin III: First Contact (...           NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...           NaN
# Wonderful World of the Brothers Grimm, The (1962)            2.5
#
# antecedents                                         Osmosis Jones (2001)  \
# consequents
# Enchanted (2007)                                                     NaN
# Hero: Love Story of a Spy, The (2003)                                NaN
# Interstate 60 (2002)                                                 NaN
# Lucky: No Time For Love (2005)                                       NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                   2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                   2.5
# Motorama (1991)                                                      NaN
# Mulan (1998)                                                         NaN
# Osmosis Jones (2001)                                                 NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                   NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                   NaN
# Wonderful World of the Brothers Grimm, The (1962)                    NaN
#
# antecedents                                         Osmosis Jones (2001),Lupin III: First Contact (Rupan Sansei: Faasuto Kontakuto) (2002)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Osmosis Jones (2001),Lupin III: Sweet Lost Night (Rupan Sansei: Sweet Lost Night) (2008)  \
# consequents
# Enchanted (2007)                                                                                  NaN
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                2.5
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      NaN
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN
#
# antecedents                                         Wonderful World of the Brothers Grimm, The (1962)
# consequents
# Enchanted (2007)                                                                                  2.5
# Hero: Love Story of a Spy, The (2003)                                                             NaN
# Interstate 60 (2002)                                                                              NaN
# Lucky: No Time For Love (2005)                                                                    NaN
# Lupin III: First Contact (Rupan Sansei: Faasuto...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Lupin III: Sweet Lost Night (Rupan Sansei: Swee...                                                NaN
# Motorama (1991)                                                                                   NaN
# Mulan (1998)                                                                                      2.5
# Osmosis Jones (2001)                                                                              NaN
# Osmosis Jones (2001),Lupin III: First Contact (...                                                NaN
# Osmosis Jones (2001),Lupin III: Sweet Lost Nigh...                                                NaN
# Wonderful World of the Brothers Grimm, The (1962)                                                 NaN

# %%
# Generate a heatmap with annotations on and the colorbar off
sns.heatmap(pivot, annot = True, cbar = False)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Pruning with scatterplots
#
# After viewing your streaming service proposal from the previous exercise, the founder realizes that her initial plan may have been too narrow. Rather than focusing on initial titles, she asks you to focus on general patterns in the association rules and then perform pruning accordingly. Your goal should be to identify a large set of strong associations.
#
# Fortunately, you've just learned how to generate scatterplots. You decide to start by plotting support and confidence, since all optimal rules according to many common metrics are located on the confidence-support border.

# %%
# Apply the Apriori algorithm with another support value
frequent_itemsets = apriori(onehot_df.T, min_support = 0.2, 
                            use_colnames = True, max_len = 2)

frequent_itemsets.shape
# Out:
# (71444, 2)

# %%
# Generate association rules without performing additional pruning
rules = association_rules(frequent_itemsets, metric = 'support', 
                          min_threshold = 0)

rules
# Out:
#                                               antecedents  \
# 0                  (Kid in King Arthur's Court, A (1995))
# 1                                      (Toy Story (1995))
# 2                                      (Toy Story (1995))
# 3                              (Super Mario Bros. (1993))
# 4                                      (Toy Story (1995))
# ...                                                   ...
# 138027        (Cardcaptor Sakura: The Sealed Card (2000))
# 138028                            (Brother Bear 2 (2006))
# 138029                                      (Home (2015))
# 138030                            (Brother Bear 2 (2006))
# 138031  (Mickey, Donald, Goofy: The Three Musketeers (...
#
#                                               consequents  antecedent support  \
# 0                                      (Toy Story (1995))                0.25
# 1                  (Kid in King Arthur's Court, A (1995))                0.25
# 2                              (Super Mario Bros. (1993))                0.25
# 3                                      (Toy Story (1995))                0.30
# 4                                (Pagemaster, The (1994))                0.25
# ...                                                   ...                 ...
# 138027                            (Brother Bear 2 (2006))                0.25
# 138028                                      (Home (2015))                0.25
# 138029                            (Brother Bear 2 (2006))                0.25
# 138030  (Mickey, Donald, Goofy: The Three Musketeers (...                0.25
# 138031                            (Brother Bear 2 (2006))                0.20
#
#         consequent support  support  confidence      lift  leverage  \
# 0                     0.25      0.2    0.800000  3.200000    0.1375
# 1                     0.25      0.2    0.800000  3.200000    0.1375
# 2                     0.30      0.2    0.800000  2.666667    0.1250
# 3                     0.25      0.2    0.666667  2.666667    0.1250
# 4                     0.25      0.2    0.800000  3.200000    0.1375
# ...                    ...      ...         ...       ...       ...
# 138027                0.25      0.2    0.800000  3.200000    0.1375
# 138028                0.25      0.2    0.800000  3.200000    0.1375
# 138029                0.25      0.2    0.800000  3.200000    0.1375
# 138030                0.20      0.2    0.800000  4.000000    0.1500
# 138031                0.25      0.2    1.000000  4.000000    0.1500
#
#         conviction  zhangs_metric
# 0             3.75       0.916667
# 1             3.75       0.916667
# 2             3.50       0.833333
# 3             2.25       0.892857
# 4             3.75       0.916667
# ...            ...            ...
# 138027        3.75       0.916667
# 138028        3.75       0.916667
# 138029        3.75       0.916667
# 138030        4.00       1.000000
# 138031         inf       0.937500
#
# [138032 rows x 10 columns]

# %%
# Generate scatterplot using support and confidence
sns.scatterplot(x = "support", y = "confidence", data = rules)
plt.show()
# Out:
# C:\Users\Alienware\miniconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Alienware\miniconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Optimality of the support-confidence border
#
# You return to the founder with the scatterplot produced in the previous exercise and ask whether she would like you to use pruning to recover the support-confidence border. You tell her about the Bayardo-Agrawal result, but she seems skeptical and asks whether you can demonstrate this in an example.
#
# Recalling that scatterplots can scale the size of dots according to a third metric, you decide to use that to demonstrate optimality of the support-confidence border. You will show this by scaling the dot size using the lift metric, which was one of the metrics to which Bayardo-Agrawal applies.

# %%
# Generate scatterplot using support and confidence
sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules)
plt.show() 

# being lift = confidence / support of consequent, we can notice that the lift increases in the:

# Upper Left Corner: Represents rules with high confidence but low support, which can have high lift values due to the strong association between antecedents and consequents despite their rarity.

# Upper Right Corner: Ideally represents both high support and high confidence, but high lift might not be as pronounced if the support for the consequent is also high.
# Out:
# C:\Users\Alienware\miniconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Alienware\miniconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Alienware\miniconda3\envs\py310\lib\site-packages\seaborn\_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Using parallel coordinates to visualize rules
#
# Your visual demonstration in the previous exercise convinced the founder that the supply-confidence border is worthy of further exploration. She now suggests that you extract part of the border and visualize it. Since the rules that fall on the border are strong with respect to most common metrics, she argues that you should simply visualize whether a rule exists, rather than the intensity of the rule according to some metric.
#
# You realize that a parallel coordinates plot is ideal for such cases.

# %%
# Compute the frequent itemsets
frequent_itemsets = apriori(onehot_df.T, min_support = 0.35, 
                         use_colnames = True, max_len = 2)

frequent_itemsets
# Out:
#     support                                           itemsets
# 0      0.35                                     (Mulan (1998))
# 1      0.35                  (Who Framed Roger Rabbit? (1988))
# 2      0.35                             (Osmosis Jones (2001))
# 3      0.40                                  (Motorama (1991))
# 4      0.35                             (Interstate 60 (2002))
# 5      0.40  (Wonderful World of the Brothers Grimm, The (1...
# 6      0.40  (Patlabor: The Movie (Kidô keisatsu patorebâ: ...
# 7      0.35  (Revolutionary Girl Utena: Adolescence of Uten...
# 8      0.35                               (Svidd Neger (2003))
# 9      0.35                                    (Robots (2005))
# 10     0.35                                     (Pulse (2006))
# 11     0.35                                       (She (1965))
# 12     0.35  (Aqua Teen Hunger Force Colon Movie Film for T...
# 13     0.35                                 (Enchanted (2007))
# 14     0.35        (Aelita: The Queen of Mars (Aelita) (1924))
# 15     0.35            (Hero: Love Story of a Spy, The (2003))
# 16     0.35                   (Lucky: No Time For Love (2005))
# 17     0.40  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 18     0.40  (Lupin III: First Contact (Rupan Sansei: Faasu...
# 19     0.35                                 (Inception (2010))
# 20     0.50                                    (Rubber (2010))
# 21     0.35                                   (Tangled (2010))
# 22     0.35                     (Kaho Naa... Pyaar Hai (2000))
# 23     0.35                           (Mars Needs Moms (2011))
# 24     0.35  (Glamorous Life of Sachiko Hanai, The (Hatsujô...
# 25     0.35                            (Whip Hand, The (1951))
# 26     0.35  (Wonderful World of the Brothers Grimm, The (1...
# 27     0.35  (Osmosis Jones (2001), Lupin III: Sweet Lost N...
# 28     0.35  (Osmosis Jones (2001), Lupin III: First Contac...
# 29     0.35            (Motorama (1991), Interstate 60 (2002))
# 30     0.35  (Wonderful World of the Brothers Grimm, The (1...
# 31     0.35  (Hero: Love Story of a Spy, The (2003), Lucky:...
# 32     0.40  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...

# %%
# Compute rules from the frequent itemsets with the confidence metric
rules = association_rules(frequent_itemsets, metric = 'confidence', 
                          min_threshold = 0)

rules
# Out:
#                                           antecedents  \
# 0   (Wonderful World of the Brothers Grimm, The (1...
# 1                                      (Mulan (1998))
# 2                              (Osmosis Jones (2001))
# 3   (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 4                              (Osmosis Jones (2001))
# 5   (Lupin III: First Contact (Rupan Sansei: Faasu...
# 6                                   (Motorama (1991))
# 7                              (Interstate 60 (2002))
# 8   (Wonderful World of the Brothers Grimm, The (1...
# 9                                  (Enchanted (2007))
# 10            (Hero: Love Story of a Spy, The (2003))
# 11                   (Lucky: No Time For Love (2005))
# 12  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...
# 13  (Lupin III: First Contact (Rupan Sansei: Faasu...
#
#                                           consequents  antecedent support  \
# 0                                      (Mulan (1998))                0.40
# 1   (Wonderful World of the Brothers Grimm, The (1...                0.35
# 2   (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.35
# 3                              (Osmosis Jones (2001))                0.40
# 4   (Lupin III: First Contact (Rupan Sansei: Faasu...                0.35
# 5                              (Osmosis Jones (2001))                0.40
# 6                              (Interstate 60 (2002))                0.40
# 7                                   (Motorama (1991))                0.35
# 8                                  (Enchanted (2007))                0.40
# 9   (Wonderful World of the Brothers Grimm, The (1...                0.35
# 10                   (Lucky: No Time For Love (2005))                0.35
# 11            (Hero: Love Story of a Spy, The (2003))                0.35
# 12  (Lupin III: First Contact (Rupan Sansei: Faasu...                0.40
# 13  (Lupin III: Sweet Lost Night (Rupan Sansei: Sw...                0.40
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 1                 0.40     0.35       1.000  2.500000    0.2100         inf
# 2                 0.40     0.35       1.000  2.500000    0.2100         inf
# 3                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 4                 0.40     0.35       1.000  2.500000    0.2100         inf
# 5                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 6                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 7                 0.40     0.35       1.000  2.500000    0.2100         inf
# 8                 0.35     0.35       0.875  2.500000    0.2100         5.2
# 9                 0.40     0.35       1.000  2.500000    0.2100         inf
# 10                0.35     0.35       1.000  2.857143    0.2275         inf
# 11                0.35     0.35       1.000  2.857143    0.2275         inf
# 12                0.40     0.40       1.000  2.500000    0.2400         inf
# 13                0.40     0.40       1.000  2.500000    0.2400         inf
#
#     zhangs_metric
# 0        1.000000
# 1        0.923077
# 2        0.923077
# 3        1.000000
# 4        0.923077
# 5        1.000000
# 6        1.000000
# 7        0.923077
# 8        1.000000
# 9        0.923077
# 10       1.000000
# 11       1.000000
# 12       1.000000
# 13       1.000000

# %%
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent: list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent: list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# %%
# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(rules)
coords
# Out:
#                                            antecedent  \
# 0   Wonderful World of the Brothers Grimm, The (1962)
# 1                                        Mulan (1998)
# 2                                Osmosis Jones (2001)
# 3   Lupin III: Sweet Lost Night (Rupan Sansei: Swe...
# 4                                Osmosis Jones (2001)
# 5   Lupin III: First Contact (Rupan Sansei: Faasut...
# 6                                     Motorama (1991)
# 7                                Interstate 60 (2002)
# 8   Wonderful World of the Brothers Grimm, The (1962)
# 9                                    Enchanted (2007)
# 10              Hero: Love Story of a Spy, The (2003)
# 11                     Lucky: No Time For Love (2005)
# 12  Lupin III: Sweet Lost Night (Rupan Sansei: Swe...
# 13  Lupin III: First Contact (Rupan Sansei: Faasut...
#
#                                            consequent  rule
# 0                                        Mulan (1998)     0
# 1   Wonderful World of the Brothers Grimm, The (1962)     1
# 2   Lupin III: Sweet Lost Night (Rupan Sansei: Swe...     2
# 3                                Osmosis Jones (2001)     3
# 4   Lupin III: First Contact (Rupan Sansei: Faasut...     4
# 5                                Osmosis Jones (2001)     5
# 6                                Interstate 60 (2002)     6
# 7                                     Motorama (1991)     7
# 8                                    Enchanted (2007)     8
# 9   Wonderful World of the Brothers Grimm, The (1962)     9
# 10                     Lucky: No Time For Love (2005)    10
# 11              Hero: Love Story of a Spy, The (2003)    11
# 12  Lupin III: First Contact (Rupan Sansei: Faasut...    12
# 13  Lupin III: Sweet Lost Night (Rupan Sansei: Swe...    13

# %%
# Generate parallel coordinates plot
parallel_coordinates(coords, 'rule')
plt.legend([])
plt.show()

# %%
# Generate parallel coordinates plot
parallel_coordinates(coords, 'rule', colormap = 'ocean')
plt.legend([])
plt.show()
