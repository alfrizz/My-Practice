# %%
"""
This sample demonstrates how to subscribe to market scanner data from TWS/IB Gateway using the IB API.
The scanner subscription uses filtering options to retrieve specific data—in this case, top open percentage gain 
for US stocks—by specifying instrument type, location, scan code, and additional filter options.
"""

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.tag_value import TagValue  # For specifying scanner filter options as key-value pairs
from ibapi.scanner import ScannerSubscription  # ScannerSubscription object holds our scanning criteria

# %%
class TestApp(EClient, EWrapper):
    """
    TestApp class that demonstrates how to request market scanner data.
    
    It creates a scanner subscription for stocks ("STK") on major US exchanges and applies filters:
      - Only stocks with trading volume above 10,000.
      - Only stocks with market cap below a specified threshold.
      - Only stocks priced above $1 to exclude penny stocks.
    """
    
    def __init__(self):
        # Initialize EClient, passing self as the wrapper.
        EClient.__init__(self, self)

        
    def nextValidId(self, orderId: int):
        """
        Callback method that is invoked when TWS sends the next valid order ID.
        This method sets up the market scanner subscription using our desired parameters and filter options.
        The sub object sets the general scope (which kind of instruments, in which geographic area, with which overall scan strategy), 
        while the filter_options list adds specific, numerical constraints that narrow down the results even more.
        
        Args:
            orderId (int): The next valid order ID provided by TWS. Used here as the scanner request ID.
        """
        # Create a ScannerSubscription object to hold our scanning criteria.
        sub = ScannerSubscription()
        
        # Specify the instrument type we are interested in.
        # "STK" indicates that we are scanning for stock instruments.
        sub.instrument = "STK"
        
        # Set the location code to filter for major US exchanges.
        # "STK.US.MAJOR" filters to include exchanges such as NYSE, NASDAQ, and AMEX.
        sub.locationCode = "STK.US.MAJOR"
        
        # Specify the scan code to use.
        # "TOP_OPEN_PERC_GAIN" requests data for stocks with the top percentage gains at market open.
        sub.scanCode = "TOP_OPEN_PERC_GAIN"
        
        # Define a list to hold any additional scan options; in this example, we leave it empty.
        scan_options = []
        
        # Build a list of filter options using TagValue objects.
        # These filters narrow down the returned data based on specified criteria.
        filter_options = [
            # Include only stocks with a trading volume over 10,000 shares.
            TagValue("volumeAbove", "10000"),
            # Include only stocks with a market capitalization below a defined threshold (e.g., below 1 billion).
            TagValue("marketCapBelow1e6", "1000"), # you only want stocks with a market capitalization below 1,000 million dollars (or $1 billion)
            # Include only stocks with a price greater than $1 to avoid very low-priced stocks.
            TagValue("priceAbove", "1")
        ]
        
        # Send the scanner subscription request using our orderId, the subscription object, 
        # and both the scan and filter options.
        self.reqScannerSubscription(orderId, sub, scan_options, filter_options)

        
    def scannerData(self, reqId, rank, contractDetails, distance, benchmark, projection, legsStr):
        """
        Callback method invoked for each market scanner result received from TWS.
        
        Args:
            reqId (int): The request ID corresponding to our scanner subscription.
            rank (int): The rank of the result in the scanner list (e.g., 0 is the top result).
            contractDetails: Detailed information on the trading contract that matched the scanner criteria.
            distance (str): A metric representing how far the contract’s parameter is from a reference value.
            benchmark (str): A benchmark metric for additional data context.
            projection (str): A projection field; its meaning may vary based on the scan code used.
            legsStr (str): For complex instruments (like combo orders), additional leg details (often empty for stocks).
        """
        # Print the retrieved scanner data in a formatted string.
        print(f"scannerData. reqId: {reqId}, rank: {rank}, contractDetails: {contractDetails}, "
              f"distance: {distance}, benchmark: {benchmark}, projection: {projection}, legsStr: {legsStr}.")

    
    def scannerDataEnd(self, reqId):
        """
        Callback method indicating that the full set of scanner results has been sent.
        
        Args:
            reqId (int): The scanner subscription request ID for which data transmission is now complete.
        """
        # Inform the user that all scanner data has been received for the given request ID.
        print("ScannerDataEnd for reqId:", reqId)
        
        # Cancel the scanner subscription to prevent future duplicate data or conflicts.
        self.cancelScannerSubscription(reqId)
        
        # Disconnect from TWS/IB Gateway as the data retrieval is complete.
        self.disconnect()

# %%
"""
Main function for the scanner subscription example.

This function:
  - Instantiates the TestApp.
  - Connects to TWS/IB Gateway.
  - Begins the scanner data request process via the message loop.
"""
port = 7496  # Typical port for connecting to TWS (7496 for IB Gateway live trading)
clientId = 11

# Create an instance of the TestApp and connect to TWS.
app = TestApp()
app.connect("127.0.0.1", port, clientId)

# Begin processing messages from TWS (this call is blocking until disconnect).
app.run()
# Out:
# ERROR -1 1746635825487 2104 Market data farm connection is OK:cashfarm
# ERROR -1 1746635825487 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1746635825487 2104 Market data farm connection is OK:eufarm
# ERROR -1 1746635825487 2104 Market data farm connection is OK:usopt
# ERROR -1 1746635825487 2104 Market data farm connection is OK:usfarm
# ERROR -1 1746635825487 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 1746635825497 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 1746635825497 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 1746635825497 2158 Sec-def data farm connection is OK:secdefeu
# scannerData. reqId: 1, rank: 0, contractDetails: ConId: 781686697, Symbol: STRZ, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: STRZ, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 1, contractDetails: ConId: 741203871, Symbol: GPUS, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: GPUS, TradingClass: GPUS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,GPUS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 2, contractDetails: ConId: 751744948, Symbol: ONEG, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: ONEG, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 3, contractDetails: ConId: 713217155, Symbol: ASST, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: ASST, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 4, contractDetails: ConId: 646534810, Symbol: NCMI, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: NCMI, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 5, contractDetails: ConId: 697517273, Symbol: MTEN, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: MTEN, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 6, contractDetails: ConId: 754102247, Symbol: TOPP, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: TOPP, TradingClass: TOPP, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,TOPP,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 7, contractDetails: ConId: 766139493, Symbol: BIYA, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BIYA, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 8, contractDetails: ConId: 779063010, Symbol: CIGL, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: CIGL, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 9, contractDetails: ConId: 777715195, Symbol: GENVR, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: GENVR, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 10, contractDetails: ConId: 462277065, Symbol: PRCH, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: PRCH, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 11, contractDetails: ConId: 654711260, Symbol: FTK, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: FTK, TradingClass: FTK, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,FTK,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 12, contractDetails: ConId: 660143785, Symbol: OCG, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: OCG, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 13, contractDetails: ConId: 781264644, Symbol: SDM, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: SDM, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 14, contractDetails: ConId: 4815677, Symbol: NSYS, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: NSYS, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 15, contractDetails: ConId: 455592457, Symbol: EOSE, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: EOSE, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 16, contractDetails: ConId: 532790286, Symbol: BWNB, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BWNB, TradingClass: BWNB, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,BWNB,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 17, contractDetails: ConId: 759148404, Symbol: EPWK, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: EPWK, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 18, contractDetails: ConId: 775836403, Symbol: CUPR, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: CUPR, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 19, contractDetails: ConId: 768816891, Symbol: IVF, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: IVF, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 20, contractDetails: ConId: 776352706, Symbol: BULL, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BULL, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 21, contractDetails: ConId: 756909161, Symbol: HAO, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: HAO, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 22, contractDetails: ConId: 143288167, Symbol: PARR, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: PARR, TradingClass: PARR, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,PARR,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 23, contractDetails: ConId: 751897216, Symbol: RAIN, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: RAIN, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 24, contractDetails: ConId: 280540825, Symbol: GPMT, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: GPMT, TradingClass: GPMT, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,GPMT,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 25, contractDetails: ConId: 634819668, Symbol: OPAD, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: OPAD, TradingClass: OPAD, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,OPAD,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 26, contractDetails: ConId: 313673854, Symbol: QVCGB, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: QVCGB, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 27, contractDetails: ConId: 471245494, Symbol: BWSN, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BWSN, TradingClass: BWSN, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,BWSN,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 28, contractDetails: ConId: 713604569, Symbol: PHIO, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: PHIO, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 29, contractDetails: ConId: 766500057, Symbol: MCRP, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: MCRP, TradingClass: MCRP, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,MCRP,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 30, contractDetails: ConId: 347411991, Symbol: APYX, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: APYX, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 31, contractDetails: ConId: 758095570, Symbol: BBNX, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BBNX, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 32, contractDetails: ConId: 771558851, Symbol: WFF, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: WFF, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 33, contractDetails: ConId: 180352934, Symbol: APPS, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: APPS, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 34, contractDetails: ConId: 690219197, Symbol: NTHI, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: NTHI, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 35, contractDetails: ConId: 723653290, Symbol: RITR, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: RITR, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 36, contractDetails: ConId: 605552357, Symbol: COYA, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: COYA, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 37, contractDetails: ConId: 597690534, Symbol: PSHG, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: PSHG, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 38, contractDetails: ConId: 759331662, Symbol: HCAI, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: HCAI, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 39, contractDetails: ConId: 426545710, Symbol: LPRO, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: LPRO, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 40, contractDetails: ConId: 658417904, Symbol: VVPR, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: VVPR, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 41, contractDetails: ConId: 771759969, Symbol: NMAX, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: NMAX, TradingClass: NMAX, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMAX,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 42, contractDetails: ConId: 105021020, Symbol: GALT, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: GALT, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 43, contractDetails: ConId: 14270526, Symbol: DENN, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: DENN, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 44, contractDetails: ConId: 518269918, Symbol: NVNO, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: NVNO, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 45, contractDetails: ConId: 469015102, Symbol: LDI, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: LDI, TradingClass: LDI, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,LDI,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 46, contractDetails: ConId: 152388751, Symbol: HRTG, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: HRTG, TradingClass: HRTG, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,HRTG,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 47, contractDetails: ConId: 768185574, Symbol: HIMZ, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: HIMZ, TradingClass: NMS, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,NMS,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 48, contractDetails: ConId: 500073318, Symbol: BAFN, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: BAFN, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# scannerData. reqId: 1, rank: 49, contractDetails: ConId: 751482785, Symbol: OST, SecType: STK, LastTradeDateOrContractMonth: , Strike: 0, Right: , Multiplier: , Exchange: SMART, PrimaryExchange: , Currency: USD, LocalSymbol: OST, TradingClass: SCM, IncludeExpired: False, SecIdType: , SecId: , Description: , IssuerId: Combo:,SCM,0,,,0,0,,,,,,,,,,0,,,,0,None,,,,,,,,False,False,0,False,,,,,False,,,,,None, distance: , benchmark: , projection: , legsStr: .
# ScannerDataEnd for reqId: 1
