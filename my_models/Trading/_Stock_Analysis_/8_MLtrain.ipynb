# %%
# %matplotlib inline

# 1) Wipe out your namespace
# %reset -f

# 2) Clear Jupyter’s stored outputs (and inputs if you like)
try:
    Out.clear()
except NameError:
    pass

try:
    In.clear()
except NameError:
    pass

# 3) Force Python GC
import gc
gc.collect()

# 4) Free any GPU buffers
import torch
if torch.cuda.is_available():
    torch.cuda.empty_cache()

import importlib
from libs import params, trades, feats, plots, models_core, models_custom
importlib.reload(params)
importlib.reload(trades)
importlib.reload(feats)
importlib.reload(plots)
importlib.reload(models_core)
importlib.reload(models_custom)
# Out:
# <module 'libs.models_custom' from '/workspace/my_models/Trading/_Stock_Analysis_/libs/models_custom.py'>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy  as np
import math
import matplotlib.pyplot as plt

import datetime as dt
import os
from typing import Sequence, List, Tuple, Optional, Union

import torch.nn as nn
from torch.nn import MSELoss, Dropout
import torch.nn.functional as Funct
from torch_lr_finder import LRFinder
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, ReduceLROnPlateau, OneCycleLR
from torch.amp import GradScaler

from tqdm import tqdm

# %%
df_feat_sel = pd.read_csv(params.feat_all_csv, index_col=0, parse_dates=True)[params.features_cols_tick + ['close_raw'] + [params.label_col]]
    
df_feat_sel
# Out:
#                      dist_low_28  dist_low_60  dist_low_30  in_sess_time  \
# 2009-01-02 11:02:00     0.000000     0.000000     0.000000           0.0
# 2009-01-02 11:03:00     0.000000     0.000000     0.000000           0.0
# 2009-01-02 11:04:00     0.000000     0.000000     0.000000           0.0
# 2009-01-02 11:05:00     0.000000     0.000000     0.000000           0.0
# 2009-01-02 11:06:00     0.000000     0.000000     0.000000           0.0
# ...                          ...          ...          ...           ...
# 2025-06-18 20:56:00     0.300101     0.280394     0.291636           1.0
# 2025-06-18 20:57:00     0.226194     0.255810     0.257364           1.0
# 2025-06-18 20:58:00     0.186583     0.249691     0.253677           1.0
# 2025-06-18 20:59:00     0.076846     0.173946     0.111072           1.0
# 2025-06-18 21:00:00     0.153457     0.226826     0.147870           0.0
#
#                      dist_high_60  dist_high_30  dist_high_28  minute_time  \
# 2009-01-02 11:02:00      0.000000      0.000000      0.000000     0.000000
# 2009-01-02 11:03:00      0.000000      0.000000      0.000000     0.001672
# 2009-01-02 11:04:00      0.000000      0.000000      0.000000     0.003345
# 2009-01-02 11:05:00      0.000000      0.000000      0.000000     0.005017
# 2009-01-02 11:06:00      0.000000      0.000000      0.000000     0.006689
# ...                           ...           ...           ...          ...
# 2025-06-18 20:56:00      0.000000      0.000000      0.000000     0.993311
# 2025-06-18 20:57:00      0.024866      0.034485      0.035650     0.994983
# 2025-06-18 20:58:00      0.025755      0.035717      0.036924     0.996655
# 2025-06-18 20:59:00      0.102355      0.141947      0.146743     0.998328
# 2025-06-18 21:00:00      0.048878      0.067784      0.070074     1.000000
#
#                      hour_time  ret_std_z_90    adx_60       rsi  volume_z_60  \
# 2009-01-02 11:02:00        0.0      0.500000  0.000000  1.000000     0.411992
# 2009-01-02 11:03:00        0.0      0.500000  0.000000  1.000000     0.411992
# 2009-01-02 11:04:00        0.0      0.500000  0.000000  1.000000     0.411992
# 2009-01-02 11:05:00        0.0      0.500000  0.000000  1.000000     0.411992
# 2009-01-02 11:06:00        0.0      0.500000  0.000000  1.000000     0.411992
# ...                        ...           ...       ...       ...          ...
# 2025-06-18 20:56:00        0.9      0.506339  0.097797  0.672166     0.658362
# 2025-06-18 20:57:00        0.9      0.506537  0.099996  0.616686     0.722596
# 2025-06-18 20:58:00        0.9      0.505883  0.102159  0.614734     0.777983
# 2025-06-18 20:59:00        0.9      0.510834  0.102810  0.475401     1.000000
# 2025-06-18 21:00:00        1.0      0.512952  0.102894  0.551738     1.000000
#
#                      volume_z_90  sma_pct_14  atr_z_90    adx_90       adx  \
# 2009-01-02 11:02:00     0.500000    0.506758  0.304301  0.000000  0.000000
# 2009-01-02 11:03:00     0.500000    0.506758  0.304301  0.000000  0.000000
# 2009-01-02 11:04:00     0.500000    0.506758  0.304301  0.000000  0.000000
# 2009-01-02 11:05:00     0.500000    0.506758  0.304301  0.000000  0.000000
# 2009-01-02 11:06:00     0.500000    0.506758  0.304301  0.000000  0.000000
# ...                          ...         ...       ...       ...       ...
# 2025-06-18 20:56:00     0.686971    0.656052  1.000000  0.086120  0.301944
# 2025-06-18 20:57:00     0.730582    0.595837  1.000000  0.086780  0.328685
# 2025-06-18 20:58:00     0.762197    0.584611  1.000000  0.087434  0.353515
# 2025-06-18 20:59:00     1.000000    0.433098  1.000000  0.087420  0.348960
# 2025-06-18 21:00:00     1.000000    0.527665  1.000000  0.087152  0.336212
#
#                      eng_bb_mid  obv_diff_14  eng_rsi  volume_z_30  eng_vwap  \
# 2009-01-02 11:02:00    0.488140     0.543793      1.0     0.297955  0.498899
# 2009-01-02 11:03:00    0.488140     0.543793      1.0     0.297955  0.498899
# 2009-01-02 11:04:00    0.488140     0.543793      1.0     0.297955  0.498899
# 2009-01-02 11:05:00    0.488140     0.543793      1.0     0.297955  0.498899
# 2009-01-02 11:06:00    0.488140     0.543793      1.0     0.297955  0.498899
# ...                         ...          ...      ...          ...       ...
# 2025-06-18 20:56:00    0.346778     1.000000      0.0     0.643415  0.609765
# 2025-06-18 20:57:00    0.393739     1.000000      0.0     0.656971  0.543041
# 2025-06-18 20:58:00    0.401111     0.618773      0.0     0.723026  0.532451
# 2025-06-18 20:59:00    0.525103     0.000000      0.0     1.000000  0.387827
# 2025-06-18 21:00:00    0.443518     1.000000      0.0     1.000000  0.531586
#
#                         z_obv  obv_diff_30  z_vwap_dev_60   plus_di  \
# 2009-01-02 11:02:00  0.725846     0.556579       0.503264  0.000000
# 2009-01-02 11:03:00  0.725846     0.556579       0.503264  0.000000
# 2009-01-02 11:04:00  0.725846     0.556579       0.503264  0.000000
# 2009-01-02 11:05:00  0.725846     0.556579       0.503264  0.000000
# 2009-01-02 11:06:00  0.725846     0.556579       0.503264  0.000000
# ...                       ...          ...            ...       ...
# 2025-06-18 20:56:00  0.852825     1.000000       0.597521  0.363125
# 2025-06-18 20:57:00  0.665858     1.000000       0.516897  0.347207
# 2025-06-18 20:58:00  0.483993     0.812074       0.499061  0.336272
# 2025-06-18 20:59:00  0.083396     0.000000       0.307718  0.290578
# 2025-06-18 21:00:00  0.999281     1.000000       0.493876  0.249733
#
#                      z_vwap_dev  vol_z_90  z_vwap_dev_90  sma_pct_60  \
# 2009-01-02 11:02:00    0.500425  0.242801       0.497760    0.513064
# 2009-01-02 11:03:00    0.500425  0.242801       0.497760    0.513064
# 2009-01-02 11:04:00    0.500425  0.242801       0.497760    0.513064
# 2009-01-02 11:05:00    0.500425  0.242801       0.497760    0.513064
# 2009-01-02 11:06:00    0.500425  0.242801       0.497760    0.513064
# ...                         ...       ...            ...         ...
# 2025-06-18 20:56:00    0.736275  0.480153       0.591207    0.667179
# 2025-06-18 20:57:00    0.491409  0.520239       0.522370    0.639408
# 2025-06-18 20:58:00    0.460581  0.542052       0.510919    0.634417
# 2025-06-18 20:59:00    0.111796  0.912705       0.365014    0.558126
# 2025-06-18 21:00:00    0.487135  0.993878       0.510762    0.605921
#
#                      obv_pct_30  bb_w_z_60  obv_diff_60  vol_z_60    roc_14  \
# 2009-01-02 11:02:00    1.000000   0.500000     0.570492  0.275382  0.499819
# 2009-01-02 11:03:00    1.000000   0.500000     0.570492  0.275382  0.499819
# 2009-01-02 11:04:00    1.000000   0.500000     0.570492  0.275382  0.499819
# 2009-01-02 11:05:00    1.000000   0.500000     0.570492  0.275382  0.499819
# 2009-01-02 11:06:00    1.000000   0.500000     0.570492  0.275382  0.499819
# ...                         ...        ...          ...       ...       ...
# 2025-06-18 20:56:00    0.444061   0.499509     0.948175  0.499924  0.645625
# 2025-06-18 20:57:00    0.413893   0.503922     0.808967  0.540398  0.588800
# 2025-06-18 20:58:00    0.381288   0.508275     0.670537  0.562923  0.574106
# 2025-06-18 20:59:00    0.204805   0.508983     0.000000  0.921172  0.511555
# 2025-06-18 21:00:00    1.000000   0.508772     1.000000  0.993884  0.579056
#
#                      vol_spike_90  obv_pct_14    rsi_30  sma_pct_28  \
# 2009-01-02 11:02:00      0.016029    1.000000  1.000000    0.507099
# 2009-01-02 11:03:00      0.016029    1.000000  1.000000    0.507099
# 2009-01-02 11:04:00      0.016029    1.000000  1.000000    0.507099
# 2009-01-02 11:05:00      0.016029    1.000000  1.000000    0.507099
# 2009-01-02 11:06:00      0.016029    1.000000  1.000000    0.507099
# ...                           ...         ...       ...         ...
# 2025-06-18 20:56:00      0.059299    0.553185  0.611989    0.654394
# 2025-06-18 20:57:00      0.068167    0.480309  0.586018    0.610994
# 2025-06-18 20:58:00      0.074245    0.398117  0.585100    0.602050
# 2025-06-18 20:59:00      0.248129    0.140193  0.513575    0.494405
# 2025-06-18 21:00:00      0.839183    1.000000  0.553012    0.562835
#
#                      vwap_dev_pct_30  plus_di_30  vol_spike_60  \
# 2009-01-02 11:02:00         0.496075    0.000000      0.021626
# 2009-01-02 11:03:00         0.496075    0.000000      0.021626
# 2009-01-02 11:04:00         0.496075    0.000000      0.021626
# 2009-01-02 11:05:00         0.496075    0.000000      0.021626
# 2009-01-02 11:06:00         0.496075    0.000000      0.021626
# ...                              ...         ...           ...
# 2025-06-18 20:56:00         0.623620    0.309665      0.067671
# 2025-06-18 20:57:00         0.573865    0.304077      0.077489
# 2025-06-18 20:58:00         0.560798    0.299030      0.084831
# 2025-06-18 20:59:00         0.442230    0.276979      0.273948
# 2025-06-18 21:00:00         0.525826    0.255220      0.822176
#
#                      vwap_dev_pct_90  vwap_dev_pct_60  plus_di_90  eng_macd  \
# 2009-01-02 11:02:00         0.491801         0.488882    0.000000  0.493704
# 2009-01-02 11:03:00         0.491801         0.488882    0.000000  0.493704
# 2009-01-02 11:04:00         0.491801         0.488882    0.000000  0.493704
# 2009-01-02 11:05:00         0.491801         0.488882    0.000000  0.493704
# 2009-01-02 11:06:00         0.491801         0.488882    0.000000  0.493704
# ...                              ...              ...         ...       ...
# 2025-06-18 20:56:00         0.625174         0.636449    0.250233  0.585090
# 2025-06-18 20:57:00         0.594789         0.598111    0.249332  0.573551
# 2025-06-18 20:58:00         0.588625         0.586119    0.247687  0.558519
# 2025-06-18 20:59:00         0.503804         0.486902    0.240255  0.481714
# 2025-06-18 21:00:00         0.532375         0.525925    0.232375  0.473695
#
#                      z_vwap_dev_30  minus_di  ret_std_z_30  sma_pct_90  \
# 2009-01-02 11:02:00       0.500929  0.000000      0.350760    0.512800
# 2009-01-02 11:03:00       0.500929  0.000000      0.350760    0.512800
# 2009-01-02 11:04:00       0.500929  0.000000      0.350760    0.512800
# 2009-01-02 11:05:00       0.500929  0.000000      0.350760    0.512800
# 2009-01-02 11:06:00       0.500929  0.000000      0.350760    0.512800
# ...                            ...       ...           ...         ...
# 2025-06-18 20:56:00       0.647712  0.074852      0.338545    0.639106
# 2025-06-18 20:57:00       0.517537  0.067044      0.325423    0.617814
# 2025-06-18 20:58:00       0.484478  0.064933      0.301070    0.615775
# 2025-06-18 20:59:00       0.156146  0.160021      0.425341    0.553240
# 2025-06-18 21:00:00       0.474788  0.176984      0.451698    0.595382
#
#                      bb_w_z_30  vwap_dev_pct_z_30    z_bb_w  \
# 2009-01-02 11:02:00   0.500000           0.500000  0.490700
# 2009-01-02 11:03:00   0.500000           0.500000  0.490700
# 2009-01-02 11:04:00   0.500000           0.500000  0.490700
# 2009-01-02 11:05:00   0.500000           0.500000  0.490700
# 2009-01-02 11:06:00   0.500000           0.500000  0.490700
# ...                        ...                ...       ...
# 2025-06-18 20:56:00   0.511353           0.528397  0.695481
# 2025-06-18 20:57:00   0.517347           0.501106  0.736925
# 2025-06-18 20:58:00   0.522203           0.496472  0.753462
# 2025-06-18 20:59:00   0.521858           0.431658  0.724748
# 2025-06-18 21:00:00   0.520302           0.495437  0.693995
#
#                      vwap_dev_pct_z_60  obv_sma_60  body_pct    roc_28  \
# 2009-01-02 11:02:00           0.500000    0.303259  0.489109  0.504537
# 2009-01-02 11:03:00           0.500000    0.305367  0.489109  0.504537
# 2009-01-02 11:04:00           0.500000    0.307476  0.489109  0.504537
# 2009-01-02 11:05:00           0.500000    0.309585  0.489109  0.504537
# 2009-01-02 11:06:00           0.500000    0.311694  0.489109  0.504537
# ...                                ...         ...       ...       ...
# 2025-06-18 20:56:00           0.519877    0.540655  0.576730  0.674170
# 2025-06-18 20:57:00           0.500007    0.544333  0.401547  0.652690
# 2025-06-18 20:58:00           0.496507    0.547100  0.485864  0.630406
# 2025-06-18 20:59:00           0.448695    0.543973  0.203532  0.541675
# 2025-06-18 21:00:00           0.496094    0.582783  0.463135  0.587424
#
#                           ret    eng_ma  vwap_dev_pct_z_90   close_raw  \
# 2009-01-02 11:02:00  0.500548  0.502857           0.500000    3.069643
# 2009-01-02 11:03:00  0.500548  0.502857           0.500000    3.069643
# 2009-01-02 11:04:00  0.500548  0.502857           0.500000    3.069643
# 2009-01-02 11:05:00  0.500548  0.502857           0.500000    3.069643
# 2009-01-02 11:06:00  0.500548  0.502857           0.500000    3.069643
# ...                       ...       ...                ...         ...
# 2025-06-18 20:56:00  0.583747  0.586764           0.521378  196.815000
# 2025-06-18 20:57:00  0.407424  0.584584           0.503404  196.675000
# 2025-06-18 20:58:00  0.497220  0.582494           0.500151  196.670000
# 2025-06-18 20:59:00  0.214314  0.580069           0.461120  196.240000
# 2025-06-18 21:00:00  0.700683  0.584041           0.499883  196.540000
#
#                            signal
# 2009-01-02 11:02:00  2.712386e-12
# 2009-01-02 11:03:00  3.073542e-12
# 2009-01-02 11:04:00  3.482881e-12
# 2009-01-02 11:05:00  3.946510e-12
# 2009-01-02 11:06:00  4.472090e-12
# ...                           ...
# 2025-06-18 20:56:00  0.000000e+00
# 2025-06-18 20:57:00  0.000000e+00
# 2025-06-18 20:58:00  0.000000e+00
# 2025-06-18 20:59:00  2.777037e-02
# 2025-06-18 21:00:00  0.000000e+00
#
# [2480459 rows x 63 columns]

# %%
_, best_optuna_params = params.load_target_sign_optuna_record(sig_type = "target")

train_loader, val_loader, test_loader, end_times_tr, end_times_val, end_times_te = models_core.model_core_pipeline(
    df             = df_feat_sel,
    look_back      = params.hparams["LOOK_BACK"],
    sess_start     = params.sess_start_shift,
    train_prop     = params.train_prop,
    val_prop       = params.val_prop,
    train_batch    = params.hparams["TRAIN_BATCH"],
    train_workers  = params.hparams["TRAIN_WORKERS"],
    prefetch_factor= params.hparams["TRAIN_PREFETCH_FACTOR"],
    signal_thresh  = best_optuna_params["buy_thresh"],
    return_thresh  = params.return_thresh_tick
)
# Out:
# Preparing days:   0%|          | 0/4141 [00:00<?, ?it/s]
# N_total: 2116051 look_back: 60 F: 61
# Estimated X_buf size: 30.98 GB — using RAM (in-memory) (thresh 56 GiB)
# Writing days:   0%|          | 0/4141 [00:00<?, ?it/s]
# Creating DayWindowDatasets:   0%|          | 0/3 [00:00<?, ?split/s]

# %%
# for name, ld, tm in zip(
#     ["train","val","test"],
#     [train_loader, val_loader, test_loader],
#     [end_times_tr, end_times_val, end_times_te]
# ):
#     models_core.summarize_split(name, ld, tm)

# %%
importlib.reload(models_custom) #############
importlib.reload(params) #############

model = models_custom.ModelClass(
    n_feats             = len(params.features_cols_tick),
    short_units         = params.hparams["SHORT_UNITS"],
    long_units          = params.hparams["LONG_UNITS"],
    transformer_d_model = params.hparams["TRANSFORMER_D_MODEL"],
    transformer_layers  = params.hparams["TRANSFORMER_LAYERS"],
    dropout_short       = params.hparams["DROPOUT_SHORT"],
    dropout_long        = params.hparams["DROPOUT_LONG"],
    dropout_trans       = params.hparams["DROPOUT_TRANS"],
    pred_hidden         = params.hparams["PRED_HIDDEN"],
    look_back           = params.hparams["LOOK_BACK"],

    # Gating flags
    use_conv            = params.hparams["USE_CONV"],
    use_tcn             = params.hparams["USE_TCN"],
    use_short_lstm      = params.hparams["USE_SHORT_LSTM"],
    use_transformer     = params.hparams["USE_TRANSFORMER"],
    use_long_lstm       = params.hparams["USE_LONG_LSTM"],
    use_delta           = params.hparams["USE_DELTA"],
    flatten_mode        = params.hparams["FLATTEN_MODE"]
)

model.feature_names = params.features_cols_tick # for logging
model.to(params.device)  
    
model
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:375: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# ModelClass(
#   (conv): Identity()
#   (bn): Identity()
#   (relu): ReLU()
#   (tcn): Identity()
#   (ln_short): Identity()
#   (do_short): Identity()
#   (input_proj): Linear(in_features=61, out_features=61, bias=True)
#   (feature_proj): Linear(in_features=61, out_features=64, bias=True)
#   (pos_enc): PositionalEncoding(
#     (dropout): Dropout(p=0.03, inplace=False)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (linear1): Linear(in_features=64, out_features=256, bias=True)
#         (dropout): Dropout(p=0.03, inplace=False)
#         (linear2): Linear(in_features=256, out_features=64, bias=True)
#         (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.03, inplace=False)
#         (dropout2): Dropout(p=0.03, inplace=False)
#       )
#     )
#   )
#   (short2long): Identity()
#   (ln_proj): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (do_proj): Dropout(p=0.1, inplace=False)
#   (ln_long): Identity()
#   (do_long): Identity()
#   (ln_flat): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (head_flat): Sequential(
#     (0): ParametrizedLinear(
#       in_features=64, out_features=96, bias=True
#       (parametrizations): ModuleDict(
#         (weight): ParametrizationList(
#           (0): _WeightNorm()
#         )
#       )
#     )
#     (1): ReLU()
#     (2): ParametrizedLinear(
#       in_features=96, out_features=1, bias=True
#       (parametrizations): ModuleDict(
#         (weight): ParametrizationList(
#           (0): _WeightNorm()
#         )
#       )
#     )
#   )
#   (attn_pool): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
y_train = np.concatenate([batch[1].cpu().numpy().ravel() for batch in train_loader])
y_val = np.concatenate([batch[1].cpu().numpy().ravel() for batch in val_loader])

# Visualize the true‐signal distributions on train vs. validation
plt.hist(y_train, bins=50, alpha=0.5, label="train true")
plt.hist(y_val,   bins=50, alpha=0.5, label="val true")
plt.xlabel("Signal value")
plt.ylabel("Count")
plt.title("True Signal Distribution: Train vs. Validation")
plt.legend()
plt.tight_layout()
plt.show()

# %%
base_lr = params.hparams["ONECYCLE_MAX_LR"]
head_lr = base_lr * params.hparams["HEAD_LR_PCT"] # if we want to reduce the learning rate applied to the head

params_map = dict(model.named_parameters())
head_param = params_map["head_flat.2.bias"] # select the correct head name for the lr reduction
backbone_params = [p for n,p in params_map.items() if n != "head_flat.2.bias"]

optimizer = AdamW(
    [
        {"params": backbone_params, "lr": base_lr},
        {"params": [head_param],       "lr": head_lr},
    ],
    weight_decay = params.hparams["WEIGHT_DECAY"]
)


batches_per_epoch = len(train_loader)
total_steps = batches_per_epoch * params.hparams["MAX_EPOCHS"]

scheduler = OneCycleLR(
  optimizer,
  max_lr           = params.hparams["ONECYCLE_MAX_LR"],
  total_steps      = total_steps,
  pct_start        = params.hparams["ONECYCLE_PCT_START"],
  div_factor       = params.hparams["ONECYCLE_DIV_FACTOR"],
  final_div_factor = params.hparams["ONECYCLE_FINAL_DIV"],
  anneal_strategy  = params.hparams["ONECYCLE_STRATEGY"],
)
optimizer.scheduler = scheduler # necessary to log sched_field

if getattr(scheduler, "total_steps", None) != total_steps:
    raise RuntimeError(f"Scheduler total_steps mismatch: scheduler={getattr(scheduler,'total_steps',None)} expected={total_steps}")

# %%
importlib.reload(models_core) #############
importlib.reload(plots) #############

n_days = len(train_loader.dataset)
print(f"Training sees {n_days} unique trading days per epoch.\n")

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Model parameters: total={total_params:,}, trainable={trainable_params:,}\n")

print('Using HyperParameters:\n', params.hparams)

best_val_rmse  = models_custom.model_training_loop(
    model               = model,
    optimizer           = optimizer,
    scheduler           = scheduler,
    scaler              = GradScaler(),
    train_loader        = train_loader,
    val_loader          = val_loader
)
# Out:
# Training sees 2912 unique trading days per epoch.
#
# Model parameters: total=164,457, trainable=164,457
#
# Using HyperParameters:
#  {'USE_CONV': False, 'CONV_K': 3, 'CONV_DILATION': 1, 'CONV_CHANNELS': 64, 'USE_TCN': False, 'TCN_LAYERS': 1, 'TCN_KERNEL': 3, 'TCN_CHANNELS': 64, 'USE_SHORT_LSTM': False, 'SHORT_UNITS': 64, 'DROPOUT_SHORT': 0.1, 'USE_TRANSFORMER': True, 'TRANSFORMER_D_MODEL': 64, 'TRANSFORMER_LAYERS': 3, 'TRANSFORMER_HEADS': 4, 'TRANSFORMER_FF_MULT': 4, 'DROPOUT_TRANS': 0.03, 'USE_LONG_LSTM': False, 'LONG_UNITS': 64, 'DROPOUT_LONG': 0.1, 'FLATTEN_MODE': 'attn', 'PRED_HIDDEN': 96, 'ALPHA_SMOOTH': 0, 'WARMUP_STEPS': 3, 'USE_HUBER': False, 'HUBER_DELTA': 0.1, 'USE_DELTA': False, 'LAMBDA_DELTA': 0.1, 'MAX_EPOCHS': 90, 'EARLY_STOP_PATIENCE': 9, 'WEIGHT_DECAY': 3e-06, 'CLIPNORM': 3, 'ONECYCLE_MAX_LR': 0.0003, 'HEAD_LR_PCT': 1, 'ONECYCLE_DIV_FACTOR': 10, 'ONECYCLE_FINAL_DIV': 100, 'ONECYCLE_PCT_START': 0.1, 'ONECYCLE_STRATEGY': 'cos', 'TRAIN_BATCH': 16, 'VAL_BATCH': 1, 'TRAIN_WORKERS': 8, 'TRAIN_PREFETCH_FACTOR': 4, 'LOOK_BACK': 60, 'MICRO_SAMPLE_K': 16}
# Epoch 1 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 01  TRAIN→ RMSE=0.11782, R²=-0.317 |  VALID→ RMSE=0.11088, R²=0.049 |  lr=3.81e-05 |  loss=1.38811e-02 |  improved=True
# Epoch 2 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 02  TRAIN→ RMSE=0.10070, R²=0.038 |  VALID→ RMSE=0.11381, R²=-0.002 |  lr=6.15e-05 |  loss=1.01415e-02 |  improved=False
# Epoch 3 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 03  TRAIN→ RMSE=0.10134, R²=0.025 |  VALID→ RMSE=0.11717, R²=-0.062 |  lr=9.74e-05 |  loss=1.02699e-02 |  improved=False
# Epoch 4 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 04  TRAIN→ RMSE=0.09948, R²=0.061 |  VALID→ RMSE=0.10885, R²=0.084 |  lr=1.41e-04 |  loss=9.89664e-03 |  improved=True
# Epoch 5 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 05  TRAIN→ RMSE=0.09888, R²=0.072 |  VALID→ RMSE=0.11264, R²=0.019 |  lr=1.88e-04 |  loss=9.77811e-03 |  improved=False
# Epoch 6 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 06  TRAIN→ RMSE=0.09841, R²=0.081 |  VALID→ RMSE=0.11304, R²=0.012 |  lr=2.32e-04 |  loss=9.68425e-03 |  improved=False
# Epoch 7 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 07  TRAIN→ RMSE=0.09763, R²=0.095 |  VALID→ RMSE=0.11123, R²=0.043 |  lr=2.68e-04 |  loss=9.53127e-03 |  improved=False
# Epoch 8 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 08  TRAIN→ RMSE=0.09655, R²=0.115 |  VALID→ RMSE=0.11022, R²=0.061 |  lr=2.92e-04 |  loss=9.32149e-03 |  improved=False
# Epoch 9 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 09  TRAIN→ RMSE=0.09583, R²=0.128 |  VALID→ RMSE=0.10932, R²=0.076 |  lr=3.00e-04 |  loss=9.18403e-03 |  improved=False
# Epoch 10 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 10  TRAIN→ RMSE=0.09554, R²=0.134 |  VALID→ RMSE=0.10856, R²=0.089 |  lr=3.00e-04 |  loss=9.12792e-03 |  improved=True
# Epoch 11 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 11  TRAIN→ RMSE=0.09529, R²=0.138 |  VALID→ RMSE=0.10807, R²=0.097 |  lr=3.00e-04 |  loss=9.08019e-03 |  improved=True
# Epoch 12 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 12  TRAIN→ RMSE=0.09516, R²=0.141 |  VALID→ RMSE=0.10821, R²=0.095 |  lr=2.99e-04 |  loss=9.05461e-03 |  improved=False
# Epoch 13 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 13  TRAIN→ RMSE=0.09504, R²=0.143 |  VALID→ RMSE=0.10816, R²=0.095 |  lr=2.98e-04 |  loss=9.03212e-03 |  improved=False
# Epoch 14 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 14  TRAIN→ RMSE=0.09492, R²=0.145 |  VALID→ RMSE=0.10798, R²=0.098 |  lr=2.97e-04 |  loss=9.00925e-03 |  improved=True
# Epoch 15 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 15  TRAIN→ RMSE=0.09485, R²=0.146 |  VALID→ RMSE=0.10793, R²=0.099 |  lr=2.96e-04 |  loss=8.99667e-03 |  improved=True
# Epoch 16 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 16  TRAIN→ RMSE=0.09477, R²=0.148 |  VALID→ RMSE=0.10765, R²=0.104 |  lr=2.95e-04 |  loss=8.98171e-03 |  improved=True
# Epoch 17 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 17  TRAIN→ RMSE=0.09465, R²=0.150 |  VALID→ RMSE=0.10773, R²=0.103 |  lr=2.93e-04 |  loss=8.95782e-03 |  improved=False
# Epoch 18 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 18  TRAIN→ RMSE=0.09463, R²=0.150 |  VALID→ RMSE=0.10790, R²=0.100 |  lr=2.91e-04 |  loss=8.95423e-03 |  improved=False
# Epoch 19 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 19  TRAIN→ RMSE=0.09453, R²=0.152 |  VALID→ RMSE=0.10792, R²=0.099 |  lr=2.89e-04 |  loss=8.93683e-03 |  improved=False
# Epoch 20 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 20  TRAIN→ RMSE=0.09448, R²=0.153 |  VALID→ RMSE=0.10790, R²=0.100 |  lr=2.87e-04 |  loss=8.92613e-03 |  improved=False
# Epoch 21 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 21  TRAIN→ RMSE=0.09442, R²=0.154 |  VALID→ RMSE=0.10760, R²=0.105 |  lr=2.84e-04 |  loss=8.91606e-03 |  improved=True
# Epoch 22 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 22  TRAIN→ RMSE=0.09434, R²=0.155 |  VALID→ RMSE=0.10735, R²=0.109 |  lr=2.81e-04 |  loss=8.89933e-03 |  improved=True
# Epoch 23 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 23  TRAIN→ RMSE=0.09427, R²=0.157 |  VALID→ RMSE=0.10722, R²=0.111 |  lr=2.78e-04 |  loss=8.88659e-03 |  improved=True
# Epoch 24 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 24  TRAIN→ RMSE=0.09424, R²=0.157 |  VALID→ RMSE=0.10708, R²=0.113 |  lr=2.75e-04 |  loss=8.88197e-03 |  improved=True
# Epoch 25 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 25  TRAIN→ RMSE=0.09416, R²=0.159 |  VALID→ RMSE=0.10664, R²=0.121 |  lr=2.72e-04 |  loss=8.86608e-03 |  improved=True
# Epoch 26 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 26  TRAIN→ RMSE=0.09412, R²=0.159 |  VALID→ RMSE=0.10680, R²=0.118 |  lr=2.69e-04 |  loss=8.85800e-03 |  improved=False
# Epoch 27 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 27  TRAIN→ RMSE=0.09405, R²=0.160 |  VALID→ RMSE=0.10604, R²=0.131 |  lr=2.65e-04 |  loss=8.84599e-03 |  improved=True
# Epoch 28 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 28  TRAIN→ RMSE=0.09394, R²=0.162 |  VALID→ RMSE=0.10575, R²=0.135 |  lr=2.61e-04 |  loss=8.82500e-03 |  improved=True
# Epoch 29 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 29  TRAIN→ RMSE=0.09389, R²=0.163 |  VALID→ RMSE=0.10622, R²=0.128 |  lr=2.57e-04 |  loss=8.81617e-03 |  improved=False
# Epoch 30 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 30  TRAIN→ RMSE=0.09386, R²=0.164 |  VALID→ RMSE=0.10548, R²=0.140 |  lr=2.53e-04 |  loss=8.80890e-03 |  improved=True
# Epoch 31 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 31  TRAIN→ RMSE=0.09374, R²=0.166 |  VALID→ RMSE=0.10515, R²=0.145 |  lr=2.49e-04 |  loss=8.78743e-03 |  improved=True
# Epoch 32 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 32  TRAIN→ RMSE=0.09367, R²=0.167 |  VALID→ RMSE=0.10470, R²=0.152 |  lr=2.44e-04 |  loss=8.77321e-03 |  improved=True
# Epoch 33 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 33  TRAIN→ RMSE=0.09360, R²=0.169 |  VALID→ RMSE=0.10466, R²=0.153 |  lr=2.40e-04 |  loss=8.76035e-03 |  improved=True
# Epoch 34 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 34  TRAIN→ RMSE=0.09356, R²=0.169 |  VALID→ RMSE=0.10470, R²=0.152 |  lr=2.35e-04 |  loss=8.75384e-03 |  improved=False
# Epoch 35 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 35  TRAIN→ RMSE=0.09349, R²=0.171 |  VALID→ RMSE=0.10458, R²=0.154 |  lr=2.30e-04 |  loss=8.73969e-03 |  improved=True
# Epoch 36 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 36  TRAIN→ RMSE=0.09348, R²=0.171 |  VALID→ RMSE=0.10439, R²=0.157 |  lr=2.25e-04 |  loss=8.73787e-03 |  improved=True
# Epoch 37 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 37  TRAIN→ RMSE=0.09346, R²=0.171 |  VALID→ RMSE=0.10438, R²=0.158 |  lr=2.20e-04 |  loss=8.73445e-03 |  improved=True
# Epoch 38 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 38  TRAIN→ RMSE=0.09339, R²=0.172 |  VALID→ RMSE=0.10417, R²=0.161 |  lr=2.15e-04 |  loss=8.72217e-03 |  improved=True
# Epoch 39 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 39  TRAIN→ RMSE=0.09331, R²=0.174 |  VALID→ RMSE=0.10402, R²=0.163 |  lr=2.10e-04 |  loss=8.70600e-03 |  improved=True
# Epoch 40 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 40  TRAIN→ RMSE=0.09323, R²=0.175 |  VALID→ RMSE=0.10424, R²=0.160 |  lr=2.04e-04 |  loss=8.69159e-03 |  improved=False
# Epoch 41 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 41  TRAIN→ RMSE=0.09321, R²=0.175 |  VALID→ RMSE=0.10413, R²=0.162 |  lr=1.99e-04 |  loss=8.68801e-03 |  improved=False
# Epoch 42 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 42  TRAIN→ RMSE=0.09313, R²=0.177 |  VALID→ RMSE=0.10406, R²=0.163 |  lr=1.93e-04 |  loss=8.67300e-03 |  improved=False
# Epoch 43 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 43  TRAIN→ RMSE=0.09306, R²=0.178 |  VALID→ RMSE=0.10406, R²=0.163 |  lr=1.88e-04 |  loss=8.65998e-03 |  improved=False
# Epoch 44 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 44  TRAIN→ RMSE=0.09299, R²=0.179 |  VALID→ RMSE=0.10414, R²=0.161 |  lr=1.82e-04 |  loss=8.64687e-03 |  improved=False
# Epoch 45 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 45  TRAIN→ RMSE=0.09295, R²=0.180 |  VALID→ RMSE=0.10416, R²=0.161 |  lr=1.76e-04 |  loss=8.63930e-03 |  improved=False
# Epoch 46 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 46  TRAIN→ RMSE=0.09291, R²=0.181 |  VALID→ RMSE=0.10421, R²=0.160 |  lr=1.70e-04 |  loss=8.63166e-03 |  improved=False
# Epoch 47 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 47  TRAIN→ RMSE=0.09285, R²=0.182 |  VALID→ RMSE=0.10426, R²=0.159 |  lr=1.65e-04 |  loss=8.62193e-03 |  improved=False
# Epoch 48 ▶ Train:   0%|          | 0/182 [00:00<?, ?it/s]
# eval:   0%|          | 0/608 [00:00<?, ?it/s]
# Epoch 48  TRAIN→ RMSE=0.09282, R²=0.182 |  VALID→ RMSE=0.10422, R²=0.160 |  lr=1.59e-04 |  loss=8.61594e-03 |  improved=False
# ✅ Final‐best model saved: AAPL_0.10402_fin.pth
