# %%
# 1) Wipe out all Python variables
# %reset -f
# 2) Force Python’s garbage collector to run
import gc
gc.collect()

import importlib
from libs import trades, plots, params, models
importlib.reload(trades)
importlib.reload(plots)
importlib.reload(params)
importlib.reload(models)

import os
import json
import numpy as np
import pandas as pd
import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingWarmRestarts
from torch.cuda.amp import GradScaler, autocast

import optuna
from optuna.pruners import MedianPruner
from optuna.exceptions import TrialPruned
from optuna.importance import get_param_importances

from tqdm.auto import tqdm

# %%
ticker         = params.ticker
features_cols  = params.features_cols
label_col      = params.label_col
look_back      = params.look_back_tick

save_path = params.save_path
in_path   = save_path / f"{ticker}_ready.csv"
out_path  = save_path / f"{ticker}_final.csv"

# USE GPU if available, otherwise fallback to CPU
device = params.device
print("Using device:", device)

df_raw = pd.read_csv(in_path, index_col=0, parse_dates=True)
df  = models.feature_engineering(df_raw)
df.to_csv(out_path)
df
# Out:
# Using device: cuda
#                            open        high         low       close  \
# 2014-04-03 12:06:00   28.644845   28.644845   28.644845   28.644845
# 2014-04-03 12:07:00   28.639690   28.639690   28.639690   28.639690
# 2014-04-03 12:08:00   28.634534   28.634534   28.634534   28.634534
# 2014-04-03 12:09:00   28.629379   28.629379   28.629379   28.629379
# 2014-04-03 12:10:00   28.624224   28.624224   28.624224   28.624224
# ...                         ...         ...         ...         ...
# 2025-06-18 20:56:00  173.375000  173.677100  173.215000  173.565000
# 2025-06-18 20:57:00  173.565000  173.590000  173.240000  173.380000
# 2025-06-18 20:58:00  173.390000  173.410000  173.200000  173.310000
# 2025-06-18 20:59:00  173.315000  173.400000  173.230000  173.280000
# 2025-06-18 21:00:00  173.300000  174.050000  173.170000  173.609700
#
#                         volume       r_1       r_5      r_15    vol_15  \
# 2014-04-03 12:06:00     4580.0 -0.000180 -0.000180 -0.000180  0.000046
# 2014-04-03 12:07:00     4540.0 -0.000180 -0.000360 -0.000360  0.000063
# 2014-04-03 12:08:00     4500.0 -0.000180 -0.000540 -0.000540  0.000075
# 2014-04-03 12:09:00     4460.0 -0.000180 -0.000720 -0.000720  0.000082
# 2014-04-03 12:10:00     4420.0 -0.000180 -0.000900 -0.000900  0.000088
# ...                        ...       ...       ...       ...       ...
# 2025-06-18 20:56:00   621199.0  0.001124 -0.004226 -0.009661  0.001493
# 2025-06-18 20:57:00   624198.0 -0.001066 -0.005063 -0.010671  0.001487
# 2025-06-18 20:58:00   454542.0 -0.000404 -0.005811 -0.011816  0.001436
# 2025-06-18 20:59:00  1094746.0 -0.000173 -0.004434 -0.011932  0.001432
# 2025-06-18 21:00:00  7649838.0  0.001901  0.001382 -0.009290  0.001592
#
#                      volume_spike  vwap_dev     rsi_14         bid  \
# 2014-04-03 12:06:00      0.568641 -0.000178   0.000000   28.636251
# 2014-04-03 12:07:00      0.570338 -0.000355   0.000000   28.631098
# 2014-04-03 12:08:00      0.574408 -0.000531   0.000000   28.625944
# 2014-04-03 12:09:00      0.581017 -0.000705   0.000000   28.620791
# 2014-04-03 12:10:00      0.590413 -0.000878   0.000000   28.615637
# ...                           ...       ...        ...         ...
# 2025-06-18 20:56:00      2.462713  1.257638  17.019768  173.512900
# 2025-06-18 20:57:00      2.154838  1.255215  11.648165  173.328000
# 2025-06-18 20:58:00      1.439161  1.254293  11.384870  173.258000
# 2025-06-18 20:59:00      2.836382  1.253874  11.830567  173.228000
# 2025-06-18 21:00:00      8.568493  1.257962  22.962317  173.557600
#
#                             ask  signal_smooth
# 2014-04-03 12:06:00   28.653438       0.348124
# 2014-04-03 12:07:00   28.648282       0.350528
# 2014-04-03 12:08:00   28.643125       0.352926
# 2014-04-03 12:09:00   28.637968       0.355320
# 2014-04-03 12:10:00   28.632811       0.357710
# ...                         ...            ...
# 2025-06-18 20:56:00  173.617100       0.002995
# 2025-06-18 20:57:00  173.432000       0.002906
# 2025-06-18 20:58:00  173.362000       0.005611
# 2025-06-18 20:59:00  173.332000       0.006685
# 2025-06-18 21:00:00  173.661800       0.003506
#
# [1856408 rows x 15 columns]

# %%
# ──────────────────────────────────────────────────────────────────────────────
# Build LSTM input tensors (disk-backed memmaps)
#    Returns five tensors on `device`:
#      X        : (N, look_back, F)
#      y        : (N,)
#      raw_close: (N,)
#      raw_bid  : (N,)
#      raw_ask  : (N,)
# ──────────────────────────────────────────────────────────────────────────────
X, y, raw_close, raw_bid, raw_ask = models.build_lstm_tensors(
    df             = df,
    look_back      = look_back,
    features_cols  = features_cols,
    label_col      = label_col,
    regular_start  = params.regular_start_pred
)

print("Shapes:")
print("  X         =", X.shape,    "(samples, look_back, features)")
print("  y         =", y.shape,    "(samples,)")
print("  raw_close =", raw_close.shape)
print("  raw_bid   =", raw_bid.shape)
print("  raw_ask   =", raw_ask.shape)
# Out:
# Shapes:
#   X         = torch.Size([1348808, 180, 12]) (samples, look_back, features)
#   y         = torch.Size([1348808]) (samples,)
#   raw_close = torch.Size([1348808])
#   raw_bid   = torch.Size([1348808])
#   raw_ask   = torch.Size([1348808])

# %%
# ──────────────────────────────────────────────────────────────────────────────
#    (We use the helper `chronological_split` that returns)
#      (X_tr, y_tr),
#      (X_val, y_val),
#      (X_te, y_te, raw_close_te, raw_bid_te, raw_ask_te)
# ──────────────────────────────────────────────────────────────────────────────
(X_tr, y_tr), \
(X_val, y_val), \
(X_te, y_te, raw_close_te, raw_bid_te, raw_ask_te), \
samples_per_day, day_id_tr, day_id_val, day_id_te = models.chronological_split(
    X, y, raw_close, raw_bid, raw_ask, df,
    look_back       = look_back,
    regular_start   = params.regular_start_pred,
    train_prop      = params.train_prop,
    val_prop        = params.val_prop,
    train_batch     = params.hparams['TRAIN_BATCH']
)

print("Shapes:")
print("  X_tr        =", X_tr.shape)
print("  y_tr        =", y_tr.shape)
print("  raw_close_te=", raw_close_te.shape)
print("  raw_bid_te  =", raw_bid_te.shape)
print("  raw_ask_te  =", raw_ask_te.shape)
# Out:
# Shapes:
#   X_tr        = torch.Size([881299, 180, 12])
#   y_tr        = torch.Size([881299])
#   raw_close_te= torch.Size([239319])
#   raw_bid_te  = torch.Size([239319])
#   raw_ask_te  = torch.Size([239319])

# %%
# -----------------------------------------------------------------------------
#  Build DataLoaders over calendar‐days
# -----------------------------------------------------------------------------
train_loader, val_loader, test_loader = models.split_to_day_datasets(
    # Training split arrays (from chronological_split)
    X_tr, y_tr, day_id_tr,
    # Validation split arrays
    X_val, y_val, day_id_val,
    # Test split arrays + raw prices for post‐tracking
    X_te, y_te, day_id_te, raw_close_te, raw_bid_te, raw_ask_te,
    # Original minute‐bar DataFrame for weekday mapping
    df=df,
    train_batch=params.hparams['TRAIN_BATCH'],
    train_workers=params.hparams['NUM_WORKERS']
)

baseline_val_rmse = models.naive_rmse(val_loader)
print(f"\nBaseline (zero‐forecast) RMSE on validation = {baseline_val_rmse:.6f}")
# Out:
# ▶️ Entered split_to_day_datasets
# 1) building weekday arrays
#    Weekdays counts → tr=881299, val=228190, te=239319
# 2) moving all splits to CPU
#    CPU casts done
# 3) zero-bas­ing day_id for val & test
#    val_day_id ∈ [0..413], total days=414
#    te_day_id  ∈ [0..421], total days=422
# 4) instantiating DayWindowDatasets
#    ds_tr days: 1984
#    ds_val days: 414
#    ds_te days: 422
# 5) building DataLoaders
#    train_loader ready
#    val_loader ready
#    test_loader ready
#
# Baseline (zero‐forecast) RMSE on validation = 0.516034

# %%
# ──────────────────────────────────────────────────────────────────────────────
# Optuna objective definition
# ──────────────────────────────────────────────────────────────────────────────
def objective_train(trial):

    hp = {
        # ── Architecture ────────────────────────────────────────
        "DROPOUT_SHORT"     : trial.suggest_categorical(
            "DROPOUT_SHORT", [0.20, 0.25, 0.30, 0.35, 0.40]
        ),
        "DROPOUT_LONG"      : trial.suggest_categorical(
            "DROPOUT_LONG", [0.30, 0.35, 0.40, 0.45, 0.50]
        ),
        "ATT_HEADS"         : trial.suggest_categorical(
            "ATT_HEADS", [4, 8]
        ),
        "ATT_DROPOUT"       : trial.suggest_categorical(
            "ATT_DROPOUT", [0.10, 0.15, 0.20, 0.25, 0.30]
        ),

        # ── Optimizer & Scheduler ──────────────────────────────
        "INITIAL_LR"        : trial.suggest_float(
            "INITIAL_LR", 1e-3, 1e-2
        ),
        "ETA_MIN"           : trial.suggest_float(
            "ETA_MIN", 1e-5, 1e-4
        ),
        "WEIGHT_DECAY"      : trial.suggest_categorical(
            "WEIGHT_DECAY", [3e-5, 1e-4, 3e-4, 1e-3, 3e-3]
        ),
        "CLIPNORM"          : trial.suggest_categorical(
            "CLIPNORM",
            [0.50, 0.70, 0.90, 1.00]
        ),
        "LR_EPOCHS_WARMUP"  : trial.suggest_categorical(
            "LR_EPOCHS_WARMUP",
            [1, 3, 5]
        ),
    }

    print(f"\n▶ Trial {trial.number} starting with:\n{hp}\n")

    # Build model
    model = models.DualMemoryLSTM(
        n_feats       = len(features_cols),
        short_units   = params.hparams["SHORT_UNITS"],
        long_units    = params.hparams["LONG_UNITS"],
        dropout_short = hp["DROPOUT_SHORT"],
        dropout_long  = hp["DROPOUT_LONG"],
        att_heads     = hp["ATT_HEADS"],
        att_drop      = hp["ATT_DROPOUT"],
    ).to(device)

    # Build optimizer + schedulers + scaler
    optimizer, plateau_sched, _ , scaler, clipnorm = \
        models.make_optimizer_and_scheduler(
            model            = model,
            initial_lr       = hp["INITIAL_LR"],
            weight_decay     = hp["WEIGHT_DECAY"],
            clipnorm         = hp["CLIPNORM"]
        )

    cosine_sched = CosineAnnealingWarmRestarts(
        optimizer, 
        T_0=params.hparams['T_0'], 
        T_mult=params.hparams['T_MULT'], 
        eta_min=hp['ETA_MIN']
    )

    # Run training & return best validation RMSE
    best_rmse = models.custom_stateful_training_loop(
        model               = model,
        optimizer           = optimizer,
        cosine_sched        = cosine_sched,
        plateau_sched       = plateau_sched,
        scaler              = scaler,
        train_loader        = train_loader,
        val_loader          = val_loader,
        max_epochs          = params.hparams["MAX_EPOCHS"],
        early_stop_patience = params.hparams["EARLY_STOP_PATIENCE"],
        baseline_val_rmse   = baseline_val_rmse,
        clipnorm            = clipnorm,
        device              = device,
    )

    del model
    del optimizer
    del plateau_sched
    del cosine_sched
    del scaler

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    
    return best_rmse

# %%
# ----------------------------------------------------------
# create ONE figure
# ----------------------------------------------------------
# build blank figure & line
fig, ax = plt.subplots(figsize=(7,3))
line, = ax.plot([], [], "bo-")
ax.set(xlabel="Trial #", ylabel="Objective",
       title="Optuna optimization progress")
ax.grid(True)

# display once and grab the handle
handle = display(fig, display_id=True)
plt.close(fig)

# ask plots.py for a callback bound to these objects
live_cb = plots.make_live_plot_callback(fig, ax, line, handle)

# %%
# ──────────────────────────────────────────────────────────────────────────────
#  Create Optuna study and run optimization
# ──────────────────────────────────────────────────────────────────────────────

study = optuna.create_study(
    storage="sqlite:///optuna_study.db",    # Point it at an SQLite file so it writes out each result immediately instead of buffering in RAM
    load_if_exists=True,
    direction="minimize",
    pruner=MedianPruner(n_startup_trials=6, n_warmup_steps=12),
)

def cleanup_cb(study, trial):
    # Python‐side
    gc.collect()
    # CUDA‐side (no‐op on CPU only)
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        
study.optimize(
    objective_train,
    n_trials = 120,
    n_jobs   = 1,
    callbacks=[live_cb, cleanup_cb],
)

# ──────────────────────────────────────────────────────────────────────────────
#  Print out the best hyperparameters & result
# ──────────────────────────────────────────────────────────────────────────────
print("Best hyperparameters:", study.best_params)
print("Best validation RMSE:", study.best_value)

# ──────────────────────────────────────────────────────────────────────────────
#  Compute and print parameter importances
# ──────────────────────────────────────────────────────────────────────────────
imps = get_param_importances(study)
print("\nHyperparameter importances (higher ⇒ more impact on RMSE):")
for name, score in sorted(imps.items(), key=lambda x: x[1], reverse=True):
    print(f"  {name:20s} : {score:.3f}")

# ──────────────────────────────────────────────────────────────────────────────
#  Dump study results to JSON
# ──────────────────────────────────────────────────────────────────────────────
# 1) Build your session‐only DataFrame once
session_df = df.between_time(params.regular_start,
                             params.regular_end)

# 2) Derive the trading‐day boundaries
first_day = session_df.index.normalize().min()
last_day  = session_df.index.normalize().max()

# 3) Format your file name
start_date = first_day.strftime("%Y%m%d")
end_date   = last_day.strftime("%Y%m%d")
file_name  = f"{ticker}_{start_date}-{end_date}_optuna_model_hpars.json"
file_path  = os.path.join(results_folder, file_name)


# ------------------------------------------------------------------
# Dump study results (including importances)
# ------------------------------------------------------------------

with open(file_path, "w") as f:
    json.dump(
        {
            "best_params": study.best_params,
            "best_value" : study.best_value,
            "importances": imps,
            "trials": [
                {"number": t.number, "value": t.value, "params": t.params, 
                 "state": t.state.name}
                for t in study.trials
            ],
        },
        f,
        indent=4,
    )

print(f"\nOptuna results (and importances) saved to: {file_path}")
# Out:
# [I 2025-07-25 16:56:15,970] A new study created in RDB with name: no-name-a0a314ca-fd97-4acc-82dd-62fecd4d3278
# ▶ Trial 0 starting with:
# {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.001730904843033882, 'ETA_MIN': 1.3281899792580446e-05, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2798 • val=0.2998 • lr=1.73e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2051 • val=0.3156 • lr=1.73e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2246 • val=0.2980 • lr=1.72e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1954 • val=0.2939 • lr=1.71e-03
# Saved full model + hparams to dfs training/GOOGL_0.2939.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1954 • val=0.2765 • lr=1.70e-03
# Saved full model + hparams to dfs training/GOOGL_0.2765.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1881 • val=0.2732 • lr=1.69e-03
# Saved full model + hparams to dfs training/GOOGL_0.2732.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1851 • val=0.2703 • lr=1.67e-03
# Saved full model + hparams to dfs training/GOOGL_0.2703.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1831 • val=0.2717 • lr=1.66e-03
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1876 • val=0.2799 • lr=1.64e-03
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2012 • val=0.2783 • lr=1.62e-03
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2077 • val=0.2736 • lr=1.59e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2015 • val=0.2711 • lr=1.57e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2057 • val=0.2705 • lr=1.54e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1937 • val=0.2755 • lr=1.51e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2008 • val=0.2681 • lr=1.48e-03
# Saved full model + hparams to dfs training/GOOGL_0.2681.pth
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2052 • val=0.2627 • lr=1.45e-03
# Saved full model + hparams to dfs training/GOOGL_0.2627.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1978 • val=0.2569 • lr=1.41e-03
# Saved full model + hparams to dfs training/GOOGL_0.2569.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2013 • val=0.2602 • lr=1.38e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2013 • val=0.2574 • lr=1.34e-03
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2014 • val=0.2600 • lr=1.30e-03
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2025 • val=0.2731 • lr=1.26e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1985 • val=0.2749 • lr=1.22e-03
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1948 • val=0.2756 • lr=1.18e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1933 • val=0.2692 • lr=1.14e-03
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1947 • val=0.2774 • lr=1.10e-03
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1918 • val=0.2773 • lr=1.05e-03
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1915 • val=0.2809 • lr=1.01e-03
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1900 • val=0.2824 • lr=9.63e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1891 • val=0.2862 • lr=9.18e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1879 • val=0.2906 • lr=8.73e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1863 • val=0.2939 • lr=8.28e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1852 • val=0.2981 • lr=7.83e-04
# Early stopping at epoch 32
# [I 2025-07-25 17:21:01,267] Trial 0 finished with value: 0.256881184687129 and parameters: {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.001730904843033882, 'ETA_MIN': 1.3281899792580446e-05, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 0}. Best is trial 0 with value: 0.256881184687129.
# ▶ Trial 1 starting with:
# {'DROPOUT_SHORT': 0.15, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.1, 'INITIAL_LR': 0.0004697215986826225, 'ETA_MIN': 0.00025034197079167644, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.5, 'LR_EPOCHS_WARMUP': 3}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.3318 • val=0.3071 • lr=4.70e-04
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2131 • val=0.3026 • lr=4.69e-04
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2007 • val=0.2994 • lr=4.68e-04
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1959 • val=0.3019 • lr=4.67e-04
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1996 • val=0.3045 • lr=4.66e-04
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2024 • val=0.2951 • lr=4.64e-04
# Saved full model + hparams to dfs training/GOOGL_0.2951.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.2114 • val=0.2888 • lr=4.62e-04
# Saved full model + hparams to dfs training/GOOGL_0.2888.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2024 • val=0.2895 • lr=4.60e-04
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.2069 • val=0.2854 • lr=4.58e-04
# Saved full model + hparams to dfs training/GOOGL_0.2854.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2015 • val=0.2852 • lr=4.55e-04
# Saved full model + hparams to dfs training/GOOGL_0.2852.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2026 • val=0.2817 • lr=4.52e-04
# Saved full model + hparams to dfs training/GOOGL_0.2817.pth
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2041 • val=0.2781 • lr=4.49e-04
# Saved full model + hparams to dfs training/GOOGL_0.2781.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2024 • val=0.2767 • lr=4.45e-04
# Saved full model + hparams to dfs training/GOOGL_0.2767.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2047 • val=0.2755 • lr=4.42e-04
# Saved full model + hparams to dfs training/GOOGL_0.2755.pth
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2063 • val=0.2747 • lr=4.38e-04
# Saved full model + hparams to dfs training/GOOGL_0.2747.pth
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2069 • val=0.2732 • lr=4.33e-04
# Saved full model + hparams to dfs training/GOOGL_0.2732.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2064 • val=0.2724 • lr=4.29e-04
# Saved full model + hparams to dfs training/GOOGL_0.2724.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2034 • val=0.2702 • lr=4.25e-04
# Saved full model + hparams to dfs training/GOOGL_0.2702.pth
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2023 • val=0.2692 • lr=4.20e-04
# Saved full model + hparams to dfs training/GOOGL_0.2692.pth
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2040 • val=0.2673 • lr=4.15e-04
# Saved full model + hparams to dfs training/GOOGL_0.2673.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2034 • val=0.2660 • lr=4.10e-04
# Saved full model + hparams to dfs training/GOOGL_0.2660.pth
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.2034 • val=0.2646 • lr=4.05e-04
# Saved full model + hparams to dfs training/GOOGL_0.2646.pth
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.2035 • val=0.2638 • lr=3.99e-04
# Saved full model + hparams to dfs training/GOOGL_0.2638.pth
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.2031 • val=0.2632 • lr=3.94e-04
# Saved full model + hparams to dfs training/GOOGL_0.2632.pth
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.2030 • val=0.2630 • lr=3.89e-04
# Saved full model + hparams to dfs training/GOOGL_0.2630.pth
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.2028 • val=0.2627 • lr=3.83e-04
# Saved full model + hparams to dfs training/GOOGL_0.2627.pth
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.2023 • val=0.2612 • lr=3.77e-04
# Saved full model + hparams to dfs training/GOOGL_0.2612.pth
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.2026 • val=0.2615 • lr=3.72e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.2021 • val=0.2608 • lr=3.66e-04
# Saved full model + hparams to dfs training/GOOGL_0.2608.pth
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.2016 • val=0.2608 • lr=3.60e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.2019 • val=0.2620 • lr=3.54e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.2022 • val=0.2636 • lr=3.49e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.2031 • val=0.2673 • lr=3.43e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.2011 • val=0.2710 • lr=3.37e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1974 • val=0.2692 • lr=3.32e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1982 • val=0.2691 • lr=3.26e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1976 • val=0.2701 • lr=3.21e-04
# Epoch 38:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 038 • train=0.1964 • val=0.2701 • lr=3.16e-04
# Epoch 39:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 039 • train=0.1961 • val=0.2709 • lr=3.10e-04
# Epoch 40:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 040 • train=0.1952 • val=0.2715 • lr=3.05e-04
# Epoch 41:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 041 • train=0.1945 • val=0.2723 • lr=3.00e-04
# Epoch 42:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 042 • train=0.1937 • val=0.2726 • lr=2.96e-04
# Epoch 43:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 043 • train=0.1931 • val=0.2732 • lr=2.91e-04
# Epoch 44:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 044 • train=0.1926 • val=0.2733 • lr=2.87e-04
# Early stopping at epoch 44
# [I 2025-07-25 17:55:21,210] Trial 1 finished with value: 0.2607859832030401 and parameters: {'DROPOUT_SHORT': 0.15, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.1, 'INITIAL_LR': 0.0004697215986826225, 'ETA_MIN': 0.00025034197079167644, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.5, 'LR_EPOCHS_WARMUP': 3}. Best is trial 0 with value: 0.256881184687129.
# ▶ Trial 2 starting with:
# {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.3, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.002917981935932681, 'ETA_MIN': 0.00024740181958924875, 'WEIGHT_DECAY': 0.0003, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 7}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2879 • val=0.3264 • lr=2.92e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2149 • val=0.3081 • lr=2.91e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.1908 • val=0.2863 • lr=2.90e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1996 • val=0.2766 • lr=2.89e-03
# Saved full model + hparams to dfs training/GOOGL_0.2766.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.2046 • val=0.2926 • lr=2.87e-03
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1885 • val=0.2673 • lr=2.85e-03
# Saved full model + hparams to dfs training/GOOGL_0.2673.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1853 • val=0.2663 • lr=2.83e-03
# Saved full model + hparams to dfs training/GOOGL_0.2663.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1830 • val=0.2704 • lr=2.80e-03
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1947 • val=0.2662 • lr=2.77e-03
# Saved full model + hparams to dfs training/GOOGL_0.2662.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1980 • val=0.2606 • lr=2.74e-03
# Saved full model + hparams to dfs training/GOOGL_0.2606.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1850 • val=0.2538 • lr=2.70e-03
# Saved full model + hparams to dfs training/GOOGL_0.2538.pth
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1798 • val=0.2620 • lr=2.66e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1857 • val=0.2731 • lr=2.62e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1948 • val=0.2661 • lr=2.58e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1902 • val=0.2752 • lr=2.53e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1956 • val=0.2753 • lr=2.48e-03
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1956 • val=0.2858 • lr=2.42e-03
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2007 • val=0.2940 • lr=2.37e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.1898 • val=0.2803 • lr=2.31e-03
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.1936 • val=0.2833 • lr=2.25e-03
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.1963 • val=0.3049 • lr=2.19e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1983 • val=0.3391 • lr=2.13e-03
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1882 • val=0.3349 • lr=2.06e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1884 • val=0.3368 • lr=2.00e-03
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1873 • val=0.3411 • lr=1.93e-03
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1863 • val=0.3322 • lr=1.86e-03
# Early stopping at epoch 26
# [I 2025-07-25 18:12:59,832] Trial 2 finished with value: 0.25382616587274803 and parameters: {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.3, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.002917981935932681, 'ETA_MIN': 0.00024740181958924875, 'WEIGHT_DECAY': 0.0003, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 7}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 3 starting with:
# {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.4, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.25, 'INITIAL_LR': 0.00039617149159120124, 'ETA_MIN': 0.0001614596926915325, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.3660 • val=0.3023 • lr=3.96e-04
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2172 • val=0.3007 • lr=3.96e-04
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2045 • val=0.3020 • lr=3.95e-04
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1991 • val=0.2998 • lr=3.94e-04
# Saved full model + hparams to dfs training/GOOGL_0.2998.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.2034 • val=0.2952 • lr=3.92e-04
# Saved full model + hparams to dfs training/GOOGL_0.2952.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2094 • val=0.2947 • lr=3.90e-04
# Saved full model + hparams to dfs training/GOOGL_0.2947.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.2120 • val=0.2926 • lr=3.88e-04
# Saved full model + hparams to dfs training/GOOGL_0.2926.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2164 • val=0.2924 • lr=3.86e-04
# Saved full model + hparams to dfs training/GOOGL_0.2924.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.2103 • val=0.2894 • lr=3.83e-04
# Saved full model + hparams to dfs training/GOOGL_0.2894.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2099 • val=0.2910 • lr=3.80e-04
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2074 • val=0.2861 • lr=3.77e-04
# Saved full model + hparams to dfs training/GOOGL_0.2861.pth
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2102 • val=0.2860 • lr=3.74e-04
# Saved full model + hparams to dfs training/GOOGL_0.2860.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2076 • val=0.2830 • lr=3.70e-04
# Saved full model + hparams to dfs training/GOOGL_0.2830.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2073 • val=0.2825 • lr=3.66e-04
# Saved full model + hparams to dfs training/GOOGL_0.2825.pth
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2057 • val=0.2799 • lr=3.62e-04
# Saved full model + hparams to dfs training/GOOGL_0.2799.pth
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2055 • val=0.2794 • lr=3.57e-04
# Saved full model + hparams to dfs training/GOOGL_0.2794.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2045 • val=0.2779 • lr=3.53e-04
# Saved full model + hparams to dfs training/GOOGL_0.2779.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2041 • val=0.2772 • lr=3.48e-04
# Saved full model + hparams to dfs training/GOOGL_0.2772.pth
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2040 • val=0.2774 • lr=3.43e-04
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2036 • val=0.2767 • lr=3.38e-04
# Saved full model + hparams to dfs training/GOOGL_0.2767.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2023 • val=0.2730 • lr=3.32e-04
# Saved full model + hparams to dfs training/GOOGL_0.2730.pth
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.2034 • val=0.2728 • lr=3.27e-04
# Saved full model + hparams to dfs training/GOOGL_0.2728.pth
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.2025 • val=0.2727 • lr=3.21e-04
# Saved full model + hparams to dfs training/GOOGL_0.2727.pth
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.2018 • val=0.2733 • lr=3.15e-04
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.2013 • val=0.2748 • lr=3.09e-04
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.2005 • val=0.2771 • lr=3.03e-04
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1988 • val=0.2787 • lr=2.97e-04
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1975 • val=0.2805 • lr=2.91e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1963 • val=0.2816 • lr=2.85e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1954 • val=0.2827 • lr=2.79e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1946 • val=0.2839 • lr=2.73e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1938 • val=0.2852 • lr=2.67e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1938 • val=0.2908 • lr=2.61e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1905 • val=0.2880 • lr=2.55e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1917 • val=0.2897 • lr=2.49e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1908 • val=0.2919 • lr=2.43e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1898 • val=0.2930 • lr=2.37e-04
# Epoch 38:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 038 • train=0.1893 • val=0.2952 • lr=2.31e-04
# Early stopping at epoch 38
# [I 2025-07-25 18:37:24,152] Trial 3 finished with value: 0.27269314568940267 and parameters: {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.4, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.25, 'INITIAL_LR': 0.00039617149159120124, 'ETA_MIN': 0.0001614596926915325, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 4 starting with:
# {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.3, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.3, 'INITIAL_LR': 0.002291649409283896, 'ETA_MIN': 0.00011406379367794873, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2768 • val=0.3321 • lr=2.29e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.1869 • val=0.2924 • lr=2.29e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2016 • val=0.2915 • lr=2.28e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.2030 • val=0.2732 • lr=2.27e-03
# Saved full model + hparams to dfs training/GOOGL_0.2732.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1942 • val=0.2869 • lr=2.25e-03
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2013 • val=0.2710 • lr=2.24e-03
# Saved full model + hparams to dfs training/GOOGL_0.2710.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1986 • val=0.2645 • lr=2.22e-03
# Saved full model + hparams to dfs training/GOOGL_0.2645.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1963 • val=0.2560 • lr=2.20e-03
# Saved full model + hparams to dfs training/GOOGL_0.2560.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1916 • val=0.2596 • lr=2.17e-03
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1957 • val=0.2591 • lr=2.15e-03
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1912 • val=0.2601 • lr=2.12e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1979 • val=0.2592 • lr=2.08e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1928 • val=0.2603 • lr=2.05e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1862 • val=0.2613 • lr=2.01e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1893 • val=0.2574 • lr=1.97e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1850 • val=0.2540 • lr=1.93e-03
# Saved full model + hparams to dfs training/GOOGL_0.2540.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1890 • val=0.2552 • lr=1.89e-03
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1922 • val=0.2547 • lr=1.84e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.1904 • val=0.2579 • lr=1.80e-03
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.1917 • val=0.2593 • lr=1.75e-03
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.1860 • val=0.2572 • lr=1.70e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1892 • val=0.2612 • lr=1.65e-03
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1886 • val=0.2581 • lr=1.59e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1965 • val=0.2682 • lr=1.54e-03
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1916 • val=0.2597 • lr=1.49e-03
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1999 • val=0.2553 • lr=1.43e-03
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1962 • val=0.2561 • lr=1.37e-03
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1888 • val=0.2587 • lr=1.32e-03
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1907 • val=0.2575 • lr=1.26e-03
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1919 • val=0.2593 • lr=1.20e-03
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1982 • val=0.2622 • lr=1.15e-03
# Early stopping at epoch 31
# [I 2025-07-25 18:57:26,634] Trial 4 finished with value: 0.2540149513847097 and parameters: {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.3, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.3, 'INITIAL_LR': 0.002291649409283896, 'ETA_MIN': 0.00011406379367794873, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 0}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 5 starting with:
# {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.25, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 5.35958511430268e-05, 'ETA_MIN': 0.00026501869339006824, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.4470 • val=0.3470 • lr=5.37e-05
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.3661 • val=0.3262 • lr=5.42e-05
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.3291 • val=0.3170 • lr=5.49e-05
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.3028 • val=0.3147 • lr=5.59e-05
# Saved full model + hparams to dfs training/GOOGL_0.3147.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.2818 • val=0.3157 • lr=5.72e-05
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2661 • val=0.3166 • lr=5.87e-05
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.2557 • val=0.3179 • lr=6.06e-05
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2486 • val=0.3195 • lr=6.27e-05
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.2428 • val=0.3201 • lr=6.51e-05
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2382 • val=0.3208 • lr=6.77e-05
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2343 • val=0.3211 • lr=7.06e-05
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2308 • val=0.3209 • lr=7.37e-05
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2280 • val=0.3206 • lr=7.71e-05
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2253 • val=0.3199 • lr=8.07e-05
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2232 • val=0.3189 • lr=8.45e-05
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2218 • val=0.3183 • lr=8.85e-05
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2201 • val=0.3172 • lr=9.27e-05
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2190 • val=0.3163 • lr=9.71e-05
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# [I 2025-07-25 19:12:18,986] Trial 5 finished with value: 0.31470251078109346 and parameters: {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.25, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 5.35958511430268e-05, 'ETA_MIN': 0.00026501869339006824, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}. Best is trial 2 with value: 0.25382616587274803.
# Epoch 019 • train=0.2179 • val=0.3155 • lr=1.02e-04
# Early stopping at epoch 19
#
# ▶ Trial 6 starting with:
# {'DROPOUT_SHORT': 0.15, 'DROPOUT_LONG': 0.4, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0007632605611606941, 'ETA_MIN': 0.00024577065004031663, 'WEIGHT_DECAY': 0.0003, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 7}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2740 • val=0.3021 • lr=7.63e-04
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2022 • val=0.2941 • lr=7.62e-04
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.1960 • val=0.2915 • lr=7.60e-04
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1932 • val=0.2889 • lr=7.58e-04
# Saved full model + hparams to dfs training/GOOGL_0.2889.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1938 • val=0.2847 • lr=7.55e-04
# Saved full model + hparams to dfs training/GOOGL_0.2847.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1985 • val=0.2800 • lr=7.51e-04
# Saved full model + hparams to dfs training/GOOGL_0.2800.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1969 • val=0.2770 • lr=7.46e-04
# Saved full model + hparams to dfs training/GOOGL_0.2770.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1973 • val=0.2725 • lr=7.41e-04
# Saved full model + hparams to dfs training/GOOGL_0.2725.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1947 • val=0.2727 • lr=7.35e-04
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1993 • val=0.2707 • lr=7.29e-04
# Saved full model + hparams to dfs training/GOOGL_0.2707.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2009 • val=0.2754 • lr=7.22e-04
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1987 • val=0.2675 • lr=7.14e-04
# Saved full model + hparams to dfs training/GOOGL_0.2675.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1975 • val=0.2662 • lr=7.06e-04
# Saved full model + hparams to dfs training/GOOGL_0.2662.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2014 • val=0.2682 • lr=6.97e-04
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1969 • val=0.2640 • lr=6.88e-04
# Saved full model + hparams to dfs training/GOOGL_0.2640.pth
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2003 • val=0.2648 • lr=6.78e-04
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2007 • val=0.2623 • lr=6.68e-04
# Saved full model + hparams to dfs training/GOOGL_0.2623.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1992 • val=0.2619 • lr=6.57e-04
# Saved full model + hparams to dfs training/GOOGL_0.2619.pth
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.1996 • val=0.2613 • lr=6.46e-04
# Saved full model + hparams to dfs training/GOOGL_0.2613.pth
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2015 • val=0.2605 • lr=6.34e-04
# Saved full model + hparams to dfs training/GOOGL_0.2605.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2028 • val=0.2608 • lr=6.22e-04
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.2034 • val=0.2596 • lr=6.10e-04
# Saved full model + hparams to dfs training/GOOGL_0.2596.pth
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.2006 • val=0.2625 • lr=5.97e-04
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.2021 • val=0.2567 • lr=5.85e-04
# Saved full model + hparams to dfs training/GOOGL_0.2567.pth
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.2008 • val=0.2604 • lr=5.72e-04
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.2015 • val=0.2583 • lr=5.59e-04
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.2017 • val=0.2589 • lr=5.45e-04
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.2014 • val=0.2600 • lr=5.32e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.2008 • val=0.2618 • lr=5.18e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1994 • val=0.2611 • lr=5.05e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1992 • val=0.2636 • lr=4.91e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1970 • val=0.2625 • lr=4.78e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1977 • val=0.2655 • lr=4.64e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1969 • val=0.2719 • lr=4.51e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1937 • val=0.2732 • lr=4.38e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1929 • val=0.2747 • lr=4.25e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1916 • val=0.2761 • lr=4.12e-04
# Epoch 38:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 038 • train=0.1905 • val=0.2781 • lr=3.99e-04
# Epoch 39:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 039 • train=0.1894 • val=0.2796 • lr=3.87e-04
# Early stopping at epoch 39
# [I 2025-07-25 19:39:04,965] Trial 6 finished with value: 0.2567168017871422 and parameters: {'DROPOUT_SHORT': 0.15, 'DROPOUT_LONG': 0.4, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0007632605611606941, 'ETA_MIN': 0.00024577065004031663, 'WEIGHT_DECAY': 0.0003, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 7}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 7 starting with:
# {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0024705357820905315, 'ETA_MIN': 9.48357298114321e-05, 'WEIGHT_DECAY': 0.003, 'CLIPNORM': 0.5, 'LR_EPOCHS_WARMUP': 3}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2601 • val=0.2950 • lr=2.47e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2027 • val=0.2926 • lr=2.46e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.1997 • val=0.2825 • lr=2.46e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1951 • val=0.2980 • lr=2.44e-03
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.2002 • val=0.3026 • lr=2.43e-03
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1955 • val=0.2737 • lr=2.41e-03
# Saved full model + hparams to dfs training/GOOGL_0.2737.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1907 • val=0.2915 • lr=2.39e-03
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1880 • val=0.2696 • lr=2.37e-03
# Saved full model + hparams to dfs training/GOOGL_0.2696.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1796 • val=0.2786 • lr=2.34e-03
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1820 • val=0.2781 • lr=2.31e-03
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1898 • val=0.2826 • lr=2.28e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1955 • val=0.2787 • lr=2.24e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1868 • val=0.2713 • lr=2.21e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1889 • val=0.2755 • lr=2.17e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2030 • val=0.2782 • lr=2.12e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1868 • val=0.2821 • lr=2.08e-03
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1882 • val=0.2615 • lr=2.03e-03
# Saved full model + hparams to dfs training/GOOGL_0.2615.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1976 • val=0.2638 • lr=1.98e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2126 • val=0.2615 • lr=1.93e-03
# Saved full model + hparams to dfs training/GOOGL_0.2615.pth
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.1961 • val=0.2628 • lr=1.88e-03
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.1937 • val=0.2628 • lr=1.82e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1992 • val=0.2727 • lr=1.77e-03
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1987 • val=0.2637 • lr=1.71e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.2052 • val=0.2910 • lr=1.65e-03
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1927 • val=0.2657 • lr=1.59e-03
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.2023 • val=0.2802 • lr=1.53e-03
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1940 • val=0.2780 • lr=1.47e-03
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1944 • val=0.2836 • lr=1.41e-03
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1917 • val=0.2811 • lr=1.35e-03
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1922 • val=0.2903 • lr=1.28e-03
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1882 • val=0.2920 • lr=1.22e-03
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1868 • val=0.2967 • lr=1.16e-03
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1846 • val=0.2956 • lr=1.10e-03
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1841 • val=0.3007 • lr=1.04e-03
# Early stopping at epoch 34
# [I 2025-07-25 20:14:18,625] Trial 7 finished with value: 0.26146952482624053 and parameters: {'DROPOUT_SHORT': 0.3, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0024705357820905315, 'ETA_MIN': 9.48357298114321e-05, 'WEIGHT_DECAY': 0.003, 'CLIPNORM': 0.5, 'LR_EPOCHS_WARMUP': 3}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 8 starting with:
# {'DROPOUT_SHORT': 0.35, 'DROPOUT_LONG': 0.2, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.1, 'INITIAL_LR': 8.230724615116337e-05, 'ETA_MIN': 0.00021925019670448738, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 3}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.4325 • val=0.3450 • lr=8.24e-05
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.3250 • val=0.3179 • lr=8.27e-05
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2843 • val=0.3131 • lr=8.31e-05
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.2613 • val=0.3141 • lr=8.38e-05
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.2478 • val=0.3141 • lr=8.46e-05
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2392 • val=0.3153 • lr=8.56e-05
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.2332 • val=0.3164 • lr=8.68e-05
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2287 • val=0.3156 • lr=8.82e-05
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.2260 • val=0.3150 • lr=8.97e-05
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2247 • val=0.3166 • lr=9.15e-05
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2229 • val=0.3190 • lr=9.33e-05
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2201 • val=0.3196 • lr=9.54e-05
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2182 • val=0.3198 • lr=9.75e-05
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2168 • val=0.3196 • lr=9.99e-05
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2156 • val=0.3198 • lr=1.02e-04
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2143 • val=0.3194 • lr=1.05e-04
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2135 • val=0.3191 • lr=1.08e-04
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2127 • val=0.3185 • lr=1.10e-04
# Early stopping at epoch 18
# [I 2025-07-25 20:26:11,106] Trial 8 finished with value: 0.31311926506235654 and parameters: {'DROPOUT_SHORT': 0.35, 'DROPOUT_LONG': 0.2, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.1, 'INITIAL_LR': 8.230724615116337e-05, 'ETA_MIN': 0.00021925019670448738, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 3}. Best is trial 2 with value: 0.25382616587274803.
# ▶ Trial 9 starting with:
# {'DROPOUT_SHORT': 0.4, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 0.0014021801129829935, 'ETA_MIN': 8.274579190800576e-05, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2419 • val=0.3254 • lr=1.40e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2043 • val=0.3034 • lr=1.40e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2055 • val=0.2980 • lr=1.39e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.2009 • val=0.2942 • lr=1.39e-03
# Saved full model + hparams to dfs training/GOOGL_0.2942.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1978 • val=0.3026 • lr=1.38e-03
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.2064 • val=0.2903 • lr=1.37e-03
# Saved full model + hparams to dfs training/GOOGL_0.2903.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1982 • val=0.2927 • lr=1.36e-03
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1898 • val=0.2842 • lr=1.35e-03
# Saved full model + hparams to dfs training/GOOGL_0.2842.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1959 • val=0.2841 • lr=1.33e-03
# Saved full model + hparams to dfs training/GOOGL_0.2841.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2000 • val=0.2745 • lr=1.31e-03
# Saved full model + hparams to dfs training/GOOGL_0.2745.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1938 • val=0.2752 • lr=1.30e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1938 • val=0.2682 • lr=1.28e-03
# Saved full model + hparams to dfs training/GOOGL_0.2682.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1925 • val=0.3009 • lr=1.26e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1953 • val=0.2687 • lr=1.23e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1988 • val=0.2726 • lr=1.21e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1991 • val=0.2666 • lr=1.18e-03
# Saved full model + hparams to dfs training/GOOGL_0.2666.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1948 • val=0.2702 • lr=1.16e-03
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1983 • val=0.2683 • lr=1.13e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2042 • val=0.2624 • lr=1.10e-03
# Saved full model + hparams to dfs training/GOOGL_0.2624.pth
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.1994 • val=0.2608 • lr=1.07e-03
# Saved full model + hparams to dfs training/GOOGL_0.2608.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2006 • val=0.2597 • lr=1.04e-03
# Saved full model + hparams to dfs training/GOOGL_0.2597.pth
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.2072 • val=0.2600 • lr=1.01e-03
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.2031 • val=0.2540 • lr=9.79e-04
# Saved full model + hparams to dfs training/GOOGL_0.2540.pth
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.2024 • val=0.2612 • lr=9.47e-04
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1983 • val=0.2534 • lr=9.14e-04
# Saved full model + hparams to dfs training/GOOGL_0.2534.pth
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.2048 • val=0.2686 • lr=8.80e-04
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1942 • val=0.2531 • lr=8.46e-04
# Saved full model + hparams to dfs training/GOOGL_0.2531.pth
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1998 • val=0.2581 • lr=8.12e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1937 • val=0.2597 • lr=7.78e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1923 • val=0.2636 • lr=7.43e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1900 • val=0.2656 • lr=7.08e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1885 • val=0.2667 • lr=6.74e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1880 • val=0.2705 • lr=6.40e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1867 • val=0.2735 • lr=6.06e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1860 • val=0.2757 • lr=5.72e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1851 • val=0.2784 • lr=5.39e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1842 • val=0.2809 • lr=5.07e-04
# Epoch 38:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 038 • train=0.1832 • val=0.2843 • lr=4.75e-04
# Epoch 39:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 039 • train=0.1819 • val=0.2877 • lr=4.43e-04
# Epoch 40:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 040 • train=0.1809 • val=0.2918 • lr=4.13e-04
# Epoch 41:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 041 • train=0.1797 • val=0.2951 • lr=3.84e-04
# Epoch 42:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 042 • train=0.1789 • val=0.2993 • lr=3.55e-04
# Early stopping at epoch 42
# [I 2025-07-25 21:09:33,269] Trial 9 finished with value: 0.2531117590337406 and parameters: {'DROPOUT_SHORT': 0.4, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 0.0014021801129829935, 'ETA_MIN': 8.274579190800576e-05, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}. Best is trial 9 with value: 0.2531117590337406.
# ▶ Trial 10 starting with:
# {'DROPOUT_SHORT': 0.4, 'DROPOUT_LONG': 0.35, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 0.0012456369465985765, 'ETA_MIN': 1.0149044832305309e-05, 'WEIGHT_DECAY': 0.0001, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2559 • val=0.3033 • lr=1.24e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2059 • val=0.3045 • lr=1.24e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.1935 • val=0.2919 • lr=1.24e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1925 • val=0.2834 • lr=1.23e-03
# Saved full model + hparams to dfs training/GOOGL_0.2834.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1936 • val=0.2786 • lr=1.22e-03
# Saved full model + hparams to dfs training/GOOGL_0.2786.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1908 • val=0.2795 • lr=1.22e-03
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1977 • val=0.2821 • lr=1.20e-03
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2023 • val=0.2886 • lr=1.19e-03
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.2028 • val=0.2753 • lr=1.18e-03
# Saved full model + hparams to dfs training/GOOGL_0.2753.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2018 • val=0.2659 • lr=1.16e-03
# Saved full model + hparams to dfs training/GOOGL_0.2659.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2010 • val=0.2665 • lr=1.15e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.2059 • val=0.2616 • lr=1.13e-03
# Saved full model + hparams to dfs training/GOOGL_0.2616.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.2043 • val=0.2628 • lr=1.11e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2023 • val=0.2620 • lr=1.09e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2037 • val=0.2640 • lr=1.07e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2011 • val=0.2611 • lr=1.04e-03
# Saved full model + hparams to dfs training/GOOGL_0.2611.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# ...
# Saved full model + hparams to dfs training/GOOGL_0.2680.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.1983 • val=0.2717 • lr=7.83e-04
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1966 • val=0.2669 • lr=7.69e-04
# Saved full model + hparams to dfs training/GOOGL_0.2669.pth
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1925 • val=0.2646 • lr=7.55e-04
# Saved full model + hparams to dfs training/GOOGL_0.2646.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1962 • val=0.2651 • lr=7.41e-04
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1906 • val=0.2651 • lr=7.25e-04
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.1906 • val=0.2651 • lr=7.10e-04
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.1903 • val=0.2633 • lr=6.93e-04
# Saved full model + hparams to dfs training/GOOGL_0.2633.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.1930 • val=0.2626 • lr=6.76e-04
# Saved full model + hparams to dfs training/GOOGL_0.2626.pth
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1977 • val=0.2684 • lr=6.59e-04
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1972 • val=0.2665 • lr=6.41e-04
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1942 • val=0.2697 • lr=6.23e-04
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1950 • val=0.2686 • lr=6.04e-04
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1947 • val=0.2682 • lr=5.85e-04
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1987 • val=0.2741 • lr=5.66e-04
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1988 • val=0.2684 • lr=5.47e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1946 • val=0.2701 • lr=5.28e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.2000 • val=0.2677 • lr=5.09e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1987 • val=0.2687 • lr=4.89e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1993 • val=0.2708 • lr=4.70e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1991 • val=0.2683 • lr=4.51e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1986 • val=0.2722 • lr=4.32e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1996 • val=0.2745 • lr=4.13e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1998 • val=0.2799 • lr=3.95e-04
# Early stopping at epoch 36
# [I 2025-07-26 06:19:55,709] Trial 27 finished with value: 0.26258286875479214 and parameters: {'DROPOUT_SHORT': 0.15, 'DROPOUT_LONG': 0.2, 'ATT_HEADS': 8, 'ATT_DROPOUT': 0.1, 'INITIAL_LR': 0.0008772884848914334, 'ETA_MIN': 0.0001392362286152964, 'WEIGHT_DECAY': 0.0003, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 7}. Best is trial 18 with value: 0.25153562492870557.
# ▶ Trial 28 starting with:
# {'DROPOUT_SHORT': 0.1, 'DROPOUT_LONG': 0.5, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0017977159308179118, 'ETA_MIN': 0.00016558152576969865, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 3}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2240 • val=0.2974 • lr=1.80e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.1974 • val=0.3121 • lr=1.79e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2020 • val=0.3200 • lr=1.79e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.2119 • val=0.2928 • lr=1.78e-03
# Saved full model + hparams to dfs training/GOOGL_0.2928.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1911 • val=0.2872 • lr=1.77e-03
# Saved full model + hparams to dfs training/GOOGL_0.2872.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1925 • val=0.2830 • lr=1.76e-03
# Saved full model + hparams to dfs training/GOOGL_0.2830.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1897 • val=0.2764 • lr=1.74e-03
# Saved full model + hparams to dfs training/GOOGL_0.2764.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1958 • val=0.2884 • lr=1.73e-03
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1890 • val=0.2673 • lr=1.71e-03
# Saved full model + hparams to dfs training/GOOGL_0.2673.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1846 • val=0.2795 • lr=1.69e-03
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1974 • val=0.2804 • lr=1.67e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1931 • val=0.2828 • lr=1.64e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1997 • val=0.2803 • lr=1.62e-03
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2053 • val=0.2667 • lr=1.59e-03
# Saved full model + hparams to dfs training/GOOGL_0.2667.pth
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2026 • val=0.2693 • lr=1.56e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1995 • val=0.2731 • lr=1.53e-03
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1985 • val=0.2658 • lr=1.50e-03
# Saved full model + hparams to dfs training/GOOGL_0.2658.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1979 • val=0.2711 • lr=1.46e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.1996 • val=0.2782 • lr=1.43e-03
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2010 • val=0.2728 • lr=1.39e-03
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.2075 • val=0.2669 • lr=1.35e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.2089 • val=0.2651 • lr=1.31e-03
# Saved full model + hparams to dfs training/GOOGL_0.2651.pth
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.2014 • val=0.2883 • lr=1.27e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1921 • val=0.2823 • lr=1.23e-03
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1940 • val=0.3019 • lr=1.19e-03
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1877 • val=0.3015 • lr=1.15e-03
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1875 • val=0.3031 • lr=1.11e-03
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1868 • val=0.3072 • lr=1.07e-03
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1853 • val=0.3094 • lr=1.03e-03
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1844 • val=0.3120 • lr=9.82e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1836 • val=0.3163 • lr=9.40e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1825 • val=0.3203 • lr=8.97e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1816 • val=0.3244 • lr=8.55e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1808 • val=0.3265 • lr=8.13e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1799 • val=0.3278 • lr=7.71e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1795 • val=0.3306 • lr=7.30e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1789 • val=0.3330 • lr=6.90e-04
# Early stopping at epoch 37
# [I 2025-07-26 06:50:50,720] Trial 28 finished with value: 0.26510937418360747 and parameters: {'DROPOUT_SHORT': 0.1, 'DROPOUT_LONG': 0.5, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0017977159308179118, 'ETA_MIN': 0.00016558152576969865, 'WEIGHT_DECAY': 0.001, 'CLIPNORM': 0.7, 'LR_EPOCHS_WARMUP': 3}. Best is trial 18 with value: 0.25153562492870557.
# ▶ Trial 29 starting with:
# {'DROPOUT_SHORT': 0.35, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 0.0014974473962274077, 'ETA_MIN': 3.198917960644579e-05, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2728 • val=0.3176 • lr=1.50e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.2039 • val=0.2919 • lr=1.49e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.2018 • val=0.3178 • lr=1.49e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.2191 • val=0.2843 • lr=1.48e-03
# Saved full model + hparams to dfs training/GOOGL_0.2843.pth
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1953 • val=0.2846 • lr=1.47e-03
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1982 • val=0.2801 • lr=1.46e-03
# Saved full model + hparams to dfs training/GOOGL_0.2801.pth
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1953 • val=0.2887 • lr=1.45e-03
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.1912 • val=0.2708 • lr=1.43e-03
# Saved full model + hparams to dfs training/GOOGL_0.2708.pth
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1986 • val=0.2712 • lr=1.42e-03
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.2022 • val=0.2703 • lr=1.40e-03
# Saved full model + hparams to dfs training/GOOGL_0.2703.pth
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.2110 • val=0.2781 • lr=1.38e-03
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1986 • val=0.2676 • lr=1.36e-03
# Saved full model + hparams to dfs training/GOOGL_0.2676.pth
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1986 • val=0.2620 • lr=1.33e-03
# Saved full model + hparams to dfs training/GOOGL_0.2620.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2042 • val=0.2635 • lr=1.31e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.1998 • val=0.2629 • lr=1.28e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.2069 • val=0.2606 • lr=1.26e-03
# Saved full model + hparams to dfs training/GOOGL_0.2606.pth
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.2018 • val=0.2595 • lr=1.23e-03
# Saved full model + hparams to dfs training/GOOGL_0.2595.pth
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.2028 • val=0.2612 • lr=1.20e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 019 • train=0.2018 • val=0.2577 • lr=1.16e-03
# Saved full model + hparams to dfs training/GOOGL_0.2577.pth
# Epoch 20:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 020 • train=0.2017 • val=0.2569 • lr=1.13e-03
# Saved full model + hparams to dfs training/GOOGL_0.2569.pth
# Epoch 21:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 021 • train=0.1993 • val=0.2622 • lr=1.10e-03
# Epoch 22:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 022 • train=0.1990 • val=0.2558 • lr=1.06e-03
# Saved full model + hparams to dfs training/GOOGL_0.2558.pth
# Epoch 23:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 023 • train=0.1985 • val=0.2614 • lr=1.03e-03
# Epoch 24:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 024 • train=0.1955 • val=0.2554 • lr=9.92e-04
# Saved full model + hparams to dfs training/GOOGL_0.2554.pth
# Epoch 25:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 025 • train=0.1990 • val=0.2658 • lr=9.55e-04
# Epoch 26:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 026 • train=0.1924 • val=0.2569 • lr=9.18e-04
# Epoch 27:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 027 • train=0.1970 • val=0.2615 • lr=8.80e-04
# Epoch 28:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 028 • train=0.1933 • val=0.2621 • lr=8.42e-04
# Epoch 29:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 029 • train=0.1933 • val=0.2655 • lr=8.04e-04
# Epoch 30:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 030 • train=0.1923 • val=0.2704 • lr=7.65e-04
# Epoch 31:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 031 • train=0.1902 • val=0.2741 • lr=7.27e-04
# Epoch 32:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 032 • train=0.1888 • val=0.2792 • lr=6.89e-04
# Epoch 33:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 033 • train=0.1871 • val=0.2822 • lr=6.51e-04
# Epoch 34:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 034 • train=0.1864 • val=0.2876 • lr=6.13e-04
# Epoch 35:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 035 • train=0.1848 • val=0.2913 • lr=5.76e-04
# Epoch 36:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 036 • train=0.1835 • val=0.2961 • lr=5.39e-04
# Epoch 37:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 037 • train=0.1822 • val=0.3005 • lr=5.03e-04
# Epoch 38:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 038 • train=0.1812 • val=0.3055 • lr=4.67e-04
# Epoch 39:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 039 • train=0.1802 • val=0.3095 • lr=4.33e-04
# Early stopping at epoch 39
# [I 2025-07-26 07:19:18,239] Trial 29 finished with value: 0.2553686388114996 and parameters: {'DROPOUT_SHORT': 0.35, 'DROPOUT_LONG': 0.45, 'ATT_HEADS': 2, 'ATT_DROPOUT': 0.2, 'INITIAL_LR': 0.0014974473962274077, 'ETA_MIN': 3.198917960644579e-05, 'WEIGHT_DECAY': 0.01, 'CLIPNORM': 0.9, 'LR_EPOCHS_WARMUP': 0}. Best is trial 18 with value: 0.25153562492870557.
# ▶ Trial 30 starting with:
# {'DROPOUT_SHORT': 0.25, 'DROPOUT_LONG': 0.25, 'ATT_HEADS': 4, 'ATT_DROPOUT': 0.15, 'INITIAL_LR': 0.0018455089054987264, 'ETA_MIN': 0.00021988782706079278, 'WEIGHT_DECAY': 0.003, 'CLIPNORM': 1.0, 'LR_EPOCHS_WARMUP': 0}
# Epoch 1:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 001 • train=0.2799 • val=0.3307 • lr=1.84e-03
# Epoch 2:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 002 • train=0.1852 • val=0.3232 • lr=1.84e-03
# Epoch 3:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 003 • train=0.1922 • val=0.2833 • lr=1.84e-03
# Epoch 4:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 004 • train=0.1987 • val=0.2907 • lr=1.83e-03
# Epoch 5:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 005 • train=0.1920 • val=0.2789 • lr=1.82e-03
# Saved full model + hparams to dfs training/GOOGL_0.2789.pth
# Epoch 6:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 006 • train=0.1988 • val=0.2825 • lr=1.81e-03
# Epoch 7:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 007 • train=0.1941 • val=0.2782 • lr=1.79e-03
# Saved full model + hparams to dfs training/GOOGL_0.2782.pth
# Epoch 8:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 008 • train=0.2000 • val=0.2826 • lr=1.78e-03
# Epoch 9:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 009 • train=0.1962 • val=0.2685 • lr=1.76e-03
# Saved full model + hparams to dfs training/GOOGL_0.2685.pth
# Epoch 10:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 010 • train=0.1947 • val=0.2717 • lr=1.74e-03
# Epoch 11:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 011 • train=0.1918 • val=0.2661 • lr=1.71e-03
# Saved full model + hparams to dfs training/GOOGL_0.2661.pth
# Epoch 12:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 012 • train=0.1966 • val=0.2810 • lr=1.69e-03
# Epoch 13:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 013 • train=0.1949 • val=0.2587 • lr=1.66e-03
# Saved full model + hparams to dfs training/GOOGL_0.2587.pth
# Epoch 14:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 014 • train=0.2009 • val=0.2759 • lr=1.64e-03
# Epoch 15:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 015 • train=0.2043 • val=0.2883 • lr=1.61e-03
# Epoch 16:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 016 • train=0.1889 • val=0.2643 • lr=1.58e-03
# Epoch 17:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 017 • train=0.1875 • val=0.2648 • lr=1.54e-03
# Epoch 18:   0%|          | 0/62 [00:00<?, ?bundle/s]
# Epoch 018 • train=0.1921 • val=0.2752 • lr=1.51e-03
# Epoch 19:   0%|          | 0/62 [00:00<?, ?bundle/s]
