# %%
"""
This sample demonstrates how to retrieve real-time account and portfolio information using the IB API.
It uses the reqAccountUpdates function to subscribe to both account values (like cash balances, margin requirements,
and net liquidity) and portfolio positions (such as individual positions, average cost, and unrealized P&L).

Important Notes:
    - Historical portfolio data is not available via the API; only current positions are retrieved.
    - When the subscription is active, TWS sends an initial batch with all account keys (for account values)
      followed by individual callbacks for portfolio positions.
    - Subsequent changes in the account (e.g., trades, changes in P&L, cash balance) trigger real-time updates.
    - This example is geared toward a single account structure. For handling multiple accounts,
      consider using reqAccountSummary or reqPositions.
        
The code below sets up the API, subscribes to updates, and then stops the subscription after a set period.
"""

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract


import threading
from threading import Timer
import time
import logging

# Configure logging to output INFO-level messages on the console
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)

# %%
class TestApp(EWrapper, EClient):
    
    def __init__(self):
        """
        Initialize the TestApp.
        This class inherits from both EWrapper (to receive data/callbacks) and 
        EClient (to send requests to TWS). The EClient constructor requires the wrapper instance (self).
        """
        EClient.__init__(self, self)

    
    def error(self, reqId, errorTime, errorCode, errorString, advancedOrderReject):
        """
        This method handles error messages from TWS.
        When an error is received (for example, if the request fails), it prints the error details.
        """
        print(f"Error - reqId: {reqId},  errorTime: {errorTime}, errorCode: {errorCode}, errorString: {errorString}, OrderReject: {advancedOrderReject}")

    
    def nextValidId(self, orderId):
        """
        Callback method that TWS calls to provide the next valid order ID.
        Once we have a valid order ID, we start the account update subscription.
        
        Parameters:
            orderId (int): The next valid order ID.
        """
        # Starting the subscription to account updates once a valid order ID has been received.
        self.start()

    
    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        """
        Callback method providing updates for each portfolio position.
        
        Parameters:
            contract (Contract): The contract details; includes symbol, security type, and exchange.
            position (float): The size of the position (number of shares or contracts).
            marketPrice (float): The current market price of the position.
            marketValue (float): The total value of the position (position size multiplied by market price).
            averageCost (float): The average price at which the position was acquired.
            unrealizedPNL (float): The unrealized profit or loss for this position.
            realizedPNL (float): The realized profit or loss since the position was opened/closed.
            accountName (str): The account identifier associated with the position.
        """
        print("UpdatePortfolio.",
              "Symbol:", contract.symbol,
              "SecType:", contract.secType,
              "Exchange:", contract.exchange,
              "Position:", position,
              "MarketPrice:", marketPrice,
              "MarketValue:", marketValue,
              "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL,
              "RealizedPNL:", realizedPNL,
              "AccountName:", accountName)

    
    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        """
        Callback method providing updates to account values.
        These include cash balances, margin data, net liquidity, and other account metrics.
        
        Parameters:
            key (str): The account data key (e.g., "CashBalance", "NetLiquidation").
            val (str): The value associated with the key.
            currency (str): The currency of the value (e.g., "USD").
            accountName (str): The account identifier.
        """
        print("UpdateAccountValue.",
              "Key:", key,
              "Value:", val,
              "Currency:", currency,
              "AccountName:", accountName)

    
    def updateAccountTime(self, timeStamp: str):
        """
        Callback method that returns a timestamp indicating when account information was updated.
        
        Parameters:
            timeStamp (str): The time at which the account information was updated.
        """
        print("UpdateAccountTime. Time:", timeStamp)

    
    def accountDownloadEnd(self, accountName: str):
        """
        Callback method called when the initial batch of account information has been completely sent.
        This marks the end of the download of all current positions and account values.
        
        Parameters:
            accountName (str): The account identifier.
        """
        print("AccountDownloadEnd. Account:", accountName)

    
    def start(self):
        """
        Starts the account update subscription.
        
        For a single account structure, the account number (ID) can be omitted (empty string).
        Passing True as the first argument subscribes to updates, so TWS will send a complete list 
        of positions along with account values. Subsequent changes will then be provided in real-time.
        """
        self.reqAccountUpdates(True, "")

    
    def stop(self):
        """
        Stops the account update subscription.
        
        Calling reqAccountUpdates with False cancels the subscription from TWS. The method also
        flags the completion and disconnects from the TWS session.
        """
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

# %%
"""
Main function to start the TestApp.

- Instantiates the TestApp.
- Connects to TWS on the default host (127.0.0.1) and port (7496).
- Uses a Timer to stop the subscription and disconnect the client after 5 seconds.
- Runs the client event loop until disconnect.
"""

port = 7496  # Typical port for connecting to TWS (7496 for IB Gateway live trading)
clientId = 9

# Create an instance of the TestApp and connect to TWS.
app = TestApp()
app.connect("127.0.0.1", port, clientId)

# Set up a timer to stop the subscription and disconnect after 5 seconds.
Timer(5, app.stop).start()

# Begin processing messages from TWS (this call is blocking until disconnect).
app.run()
# Out:
# 2025-05-07 16:21:48,097 [INFO] sent startApi
# 2025-05-07 16:21:48,097 [INFO] REQUEST startApi {}
# 2025-05-07 16:21:48,097 [INFO] SENDING startApi b'\x00\x00\x00\t\x00\x00\x00G2\x009\x00\x00'
# 2025-05-07 16:21:48,112 [INFO] ANSWER connectAck {}
# 2025-05-07 16:21:48,115 [INFO] ANSWER openOrderEnd {}
# 2025-05-07 16:21:48,175 [INFO] REQUEST reqAccountUpdates {'subscribe': True, 'acctCode': ''}
# 2025-05-07 16:21:48,175 [INFO] SENDING reqAccountUpdates b'\x00\x00\x00\t\x00\x00\x00\x062\x001\x00\x00'
# 2025-05-07 16:21:48,176 [INFO] ANSWER managedAccounts {'accountsList': 'U18112846'}
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2104, errorString: Market data farm connection is OK:cashfarm, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2104, errorString: Market data farm connection is OK:usfarm.nj, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2104, errorString: Market data farm connection is OK:eufarm, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2104, errorString: Market data farm connection is OK:usopt, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2104, errorString: Market data farm connection is OK:usfarm, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2106, errorString: HMDS data farm connection is OK:euhmds, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2106, errorString: HMDS data farm connection is OK:fundfarm, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708933, errorCode: 2106, errorString: HMDS data farm connection is OK:ushmds, OrderReject:
# Error - reqId: -1,  errorTime: 1746627708934, errorCode: 2158, errorString: Sec-def data farm connection is OK:secdefeu, OrderReject:
# UpdateAccountValue. Key: AccountCode Value: U18112846 Currency:  AccountName: U18112846
# UpdateAccountValue. Key: AccountOrGroup Value: U18112846 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: AccountOrGroup Value: U18112846 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: AccountOrGroup Value: U18112846 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: AccountReady Value: true Currency:  AccountName: U18112846
# UpdateAccountValue. Key: AccountType Value: INDIVIDUAL Currency:  AccountName: U18112846
# UpdateAccountValue. Key: AccruedCash Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: AccruedCash Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: AccruedCash Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: AccruedDividend Value: 0.05 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: AvailableFunds Value: 2918.56 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: AvailableFunds-S Value: 2742.30 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: Billable Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: BuyingPower Value: 19457.10 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: CashBalance Value: 2742.3015 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: CashBalance Value: 2402.42 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: CashBalance Value: 386.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: ColumnPrio-S Value: 1 Currency:  AccountName: U18112846
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: Currency Value: BASE Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: Currency Value: EUR Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: Currency Value: USD Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: Cushion Value: 0.977095 Currency:  AccountName: U18112846
# UpdateAccountValue. Key: EquityWithLoanValue Value: 3000.05 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: EquityWithLoanValue-S Value: 2742.20 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: ExcessLiquidity Value: 2931.33 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: ExcessLiquidity-S Value: 2742.20 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: ExchangeRate Value: 1.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: ExchangeRate Value: 1.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: ExchangeRate Value: 0.880522 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: FullAvailableFunds Value: 2918.56 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FullExcessLiquidity Value: 2931.33 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FullInitMarginReq Value: 81.49 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FullMaintMarginReq Value: 68.72 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: GrossPositionValue Value: 257.70 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: GrossPositionValue-S Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: Guarantee Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: IncentiveCoupons Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: IndianStockHaircut Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: InitMarginReq Value: 81.49 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: InitMarginReq-S Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: Leverage-S Value: 0.09 Currency:  AccountName: U18112846
# UpdateAccountValue. Key: LookAheadAvailableFunds Value: 2918.56 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: LookAheadExcessLiquidity Value: 2931.33 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: LookAheadInitMarginReq Value: 81.49 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: LookAheadMaintMarginReq Value: 68.72 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: LookAheadNextChange Value: 1746648000 Currency:  AccountName: U18112846
# UpdateAccountValue. Key: MaintMarginReq Value: 68.72 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: MaintMarginReq-S Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: NLVAndMarginInReview Value: false Currency:  AccountName: U18112846
# UpdateAccountValue. Key: NetDividend Value: 0.05 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: NetDividend Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: NetDividend Value: 0.06 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidation Value: 3000.05 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidation-S Value: 2742.20 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 3000.052 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 2402.42 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 678.7246 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: NetLiquidationUncertainty Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: OptionMarketValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: OptionMarketValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: OptionMarketValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: PASharesValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: PhysicalCertificateValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: PostExpirationExcess Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: PostExpirationMargin Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: RealCurrency Value: BASE Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: RealCurrency Value: EUR Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: RealCurrency Value: USD Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: SegmentTitle-S Value: CFD Currency:  AccountName: U18112846
# UpdateAccountValue. Key: StockMarketValue Value: 257.70 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: StockMarketValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: StockMarketValue Value: 292.66 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: TotalCashBalance Value: 2742.3015 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: TotalCashBalance Value: 2402.42 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TotalCashBalance Value: 386.00 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: TotalCashValue Value: 2742.30 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TotalCashValue-S Value: 2742.20 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TotalDebitCardPendingCharges Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: TradingType-S Value: STKNOPT Currency:  AccountName: U18112846
# UpdateAccountValue. Key: UnrealizedPnL Value: 1.57 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: UnrealizedPnL Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: UnrealizedPnL Value: 1.78 Currency: USD AccountName: U18112846
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: BASE AccountName: U18112846
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: EUR AccountName: U18112846
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: USD AccountName: U18112846
# UpdatePortfolio. Symbol: BBVA SecType: STK Exchange:  Position: 0.3805 MarketPrice: 14.1760006 MarketValue: 5.39 AverageCost: 13.48357425 UnrealizedPNL: 0.26 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:14
# UpdatePortfolio. Symbol: COOP SecType: STK Exchange:  Position: 0.026 MarketPrice: 117.884758 MarketValue: 3.07 AverageCost: 112.2576923 UnrealizedPNL: 0.15 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: DB SecType: STK Exchange:  Position: 1 MarketPrice: 26.79400065 MarketValue: 26.79 AverageCost: 27.0428 UnrealizedPNL: -0.25 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:17
# UpdatePortfolio. Symbol: LIN SecType: STK Exchange:  Position: 0.0075 MarketPrice: 445.6857605 MarketValue: 3.34 AverageCost: 458.30666665 UnrealizedPNL: -0.09 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: MUFG SecType: STK Exchange:  Position: 0.33 MarketPrice: 12.29399965 MarketValue: 4.06 AverageCost: 11.8018182 UnrealizedPNL: 0.16 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:17
# UpdatePortfolio. Symbol: NFLX SecType: STK Exchange:  Position: 0.0061 MarketPrice: 1153.368042 MarketValue: 7.04 AverageCost: 991.2295082 UnrealizedPNL: 0.99 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: NIO SecType: STK Exchange:  Position: 1.5 MarketPrice: 3.86399985 MarketValue: 5.8 AverageCost: 3.64073335 UnrealizedPNL: 0.33 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:14
# UpdatePortfolio. Symbol: NVDA SecType: STK Exchange:  Position: 1 MarketPrice: 113.25 MarketValue: 113.25 AverageCost: 113.990035 UnrealizedPNL: -0.74 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: SAN SecType: STK Exchange:  Position: 0.5 MarketPrice: 7.19399975 MarketValue: 3.6 AverageCost: 6.5954 UnrealizedPNL: 0.3 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:17
# UpdatePortfolio. Symbol: SE SecType: STK Exchange:  Position: 0.0663 MarketPrice: 143.74705505 MarketValue: 9.53 AverageCost: 122.8657617 UnrealizedPNL: 1.38 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: WBD SecType: STK Exchange:  Position: 1 MarketPrice: 8.5760002 MarketValue: 8.58 AverageCost: 8.479 UnrealizedPNL: 0.1 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdatePortfolio. Symbol: WMT SecType: STK Exchange:  Position: 1.0327 MarketPrice: 98.99394225 MarketValue: 102.23 AverageCost: 99.77379685 UnrealizedPNL: -0.81 RealizedPNL: 0.0 AccountName: U18112846
# UpdateAccountTime. Time: 16:20
# UpdateAccountTime. Time: 16:20
# AccountDownloadEnd. Account: U18112846
# 2025-05-07 16:21:53,127 [INFO] REQUEST reqAccountUpdates {'subscribe': False, 'acctCode': ''}
# 2025-05-07 16:21:53,127 [INFO] SENDING reqAccountUpdates b'\x00\x00\x00\t\x00\x00\x00\x062\x000\x00\x00'
# 2025-05-07 16:21:53,127 [INFO] disconnecting
# 2025-05-07 16:21:53,135 [INFO] ANSWER connectionClosed {}
